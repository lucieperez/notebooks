# %%
from tfob import TFOb, BHSA
# Out:
# **Locating corpus resources ...**
# <b title="local release">app:</b> <span title="rv1.8.1=#34aba7b1869bfb35234d922c71f37167be783de9 offline under C:/Users/zht702/text-fabric-data/github">~/text-fabric-data/github/etcbc/dss/app</span>
# <b title="local release">data:</b> <span title="rv1.8.3=#3bef3797b684ea151d7a8c91b0088119549d0efe offline under C:/Users/zht702/text-fabric-data/github">~/text-fabric-data/github/etcbc/dss/tf/1.8</span>
# <b title="local release">data:</b> <span title="rv1.8.3=#3bef3797b684ea151d7a8c91b0088119549d0efe offline under C:/Users/zht702/text-fabric-data/github">~/text-fabric-data/github/etcbc/dss/parallels/tf/1.8</span>
# ...

# %%
import pandas as pd

# %%
# Create a TFOb object containing the books (book level)
books = TFOb.all("book", BHSA)

# %%
# A much easier and faster way:

new_dict = {}

for book in books:
    book_name = book.book[0]
    book_words = book.to_words
    new_dict[book_name] = {
        "bo_count":len(book_words.filter(lex="BW>[")),
        "words_count":len(book_words),
    }

# %%
pd.DataFrame.from_dict(new_dict2, orient="index")
# Out:
#                bo_count  words_count
# Genesis             217        28764
# Exodus              124        23748
# Leviticus            81        17099
# Numbers              91        23188
# Deuteronomy         106        20128
# Joshua               59        14526
# Judges               95        14086
# 1_Samuel            170        18929
# 2_Samuel            148        15612
# 1_Kings             114        18685
# 2_Kings             152        17307
# Isaiah              123        22931
# Jeremiah            213        29736
# Ezekiel             191        26182
# Hosea                11         3146
# Joel                  8         1318
# Amos                 13         2780
# Obadiah               4          392
# Jonah                 5          985
# Micah                11         1895
# Nahum                 1          746
# Habakkuk              6          897
# Zephaniah             3         1037
# Haggai                8          877
# ...
