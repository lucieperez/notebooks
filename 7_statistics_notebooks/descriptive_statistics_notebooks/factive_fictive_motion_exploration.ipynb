# %%
import pandas as pd

# %%
df = pd.read_csv("data/filtered_dataset.csv").fillna("")

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_rows", None)

# %%
df.head()
# Out:
#    verb_id   lex scroll book  chapter  verse_num gcons_verb  \
# 0      915  NGC[    1QH  1QH        4         32      TGJCN
# 1     1007  NGC[    1QH  1QH        4         39     HWGCTJ
# 2     3544  <LH[    1QH  1QH       13          3      H<LJT
# 3     3717  HLK[    1QH  1QH       13         14       JLKW
# 4     4931  MHR[    1QH  1QH       16         19      JMHRW
#
#                                                                                    gcons_verse  \
# 0                                                                        W KN TGJCN W L BJNT K
# 1                                                             W KN HWGCTJ B JXD KWL >NCJ SWD J
# 2                                W M C>WL >BDWN H<LJT NJ L RWM <WLM W >THLKH B MJCWR L >JN XQR
# 3  W JLKW NXLJ BLJ<L <L KWL >GPJ RWM B >C >WKLT B KWL CN>BJ HM L HTM KWL <Y LX W JBC M PLGJ HM
# 4                                     W JMHRW <LJ RC<J <MJM B MYWQWT M W KWL H JWM JDK>W NPC J
#
#   sign_info  stem tense  \
# ...

# %%
df_mt = df[df.scroll == "MT"].copy()

# %%
extra_biblical = ["1QH", "1QS", "1QM"]
df_extra_biblical = df[df.scroll.isin(extra_biblical)].copy()

# %%
df_biblical_dss = df[(~df.scroll.isin(extra_biblical)) & (df.scroll != "MT")]

# %%
df_mt["motion_type"].value_counts(normalize=True)
# Out:
# motion_type
# factive    0.856903
# fictive    0.143097
# Name: proportion, dtype: float64

# %%
df_extra_biblical["motion_type"].value_counts(normalize=True)
# Out:
# motion_type
# factive    0.57971
# fictive    0.42029
# Name: proportion, dtype: float64

# %%
df_biblical_dss["motion_type"].value_counts(normalize=True)
# Out:
# motion_type
# factive    0.790503
# fictive    0.209497
# Name: proportion, dtype: float64
