# %%
import pandas as pd
import os

# %%
pd.set_option('display.max_columns', None)

# %%
folder_path = "data/datasets_to_check/"

# %%
csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

# %%
csv_files
# Out:
# ['1qs_1qm_1qh_all_verbs.csv',
#  '1_Chronicles_dataset.csv',
#  '1_Kings_dataset.csv',
#  '1_samuel.csv',
#  '2_Chronicles_dataset.csv',
#  '2_Kings_dataset.csv',
#  '2_Samuel_dataset.csv',
#  'Amos_dataset.csv',
#  'Daniel_dataset.csv',
#  'Deuteronomy_dataset.csv',
#  'Ecclesiastes_dataset.csv',
#  'Esther_dataset.csv',
#  'Exodus_dataset.csv',
#  'ezekiel_dataset.csv',
#  'Ezra_dataset.csv',
#  'Genesis_dataset.csv',
#  'Habakkuk_dataset.csv',
#  'Haggai_dataset.csv',
#  'Hosea_dataset.csv',
#  'isaiah_dataset.csv',
#  'Jeremiah_dataset.csv',
#  'Job_dataset.csv',
#  'Joel_dataset.csv',
#  'Jonah_dataset.csv',
#  'Joshua_dataset.csv',
#  'Judges_dataset.csv',
#  'Lamentations_dataset.csv',
#  'Leviticus_dataset.csv',
#  'Malachi_dataset.csv',
#  'Micah_dataset.csv',
#  'Nahum_dataset.csv',
#  'Nehemiah_dataset.csv',
#  'Numbers_dataset.csv',
#  'Obadiah_dataset.csv',
#  'Proverbs_dataset.csv',
#  'Psalms_dataset.csv',
#  'Ruth_dataset.csv',
#  'Song_of_songs_dataset.csv',
#  'Zechariah_dataset.csv',
#  'Zephaniah_dataset.csv']

# %%
dataframes = []

for file in csv_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    dataframes.append(df)
    
combined_df = pd.concat(dataframes, ignore_index=True, sort=False)
combined_df = combined_df.fillna("")

# %%
# Out:
#    verb_id  lex scroll book  chapter  verse_num gcons_verb  \
# 0      206  GLL    1QH  1QH        3          9   HTGWLLTJ
# 1      354  NPL    1QH  1QH        4          1      HTNPL
# 2      376  HLK    1QH  1QH        4          1     HTHLKW
# 3      447  GLH    1QH  1QH        4          4      GLJTH
# 4      709  CWB    1QH  1QH        4         19       JCWB
#
#                                          gcons_verse sign_info stem tense  \
# 0  KJ B NDH HTGWLLTJ W M SWD RMH Y>TJ W L> NLWJTJ...            hit  perf
# 1  MZMWR L MFKJL L HTNPL L PNJ >L M<FJ >L W L HBJ...            hit  infc
# 2  MZMWR L MFKJL L HTNPL L PNJ >L M<FJ >L W L HBJ...            hit  perf
# 3  >TH HW>L QDWCJM W B RZJ PL> K HWD< BWR KBWD K ...            qal  perf
# 4                            KJ W DBR K L> JCWB >XWR            qal  impf
#
#                                 gcons_clause subject     complement  \
# 0                          KJ B NDH HTGWLLTJ                  B NDH
# 1                           L HTNPL L PNJ >L               L PNJ >L
# 2                                     HTHLKW          no complement
# 3  >TH GLJTH DRKJ >MT W M<FJ R< XWKMH W >WLT     >TH  no complement
# 4                       W DBR K L> JCWB >XWR   DBR K           >XWR
#
#         cmpl_lex cmpl_translation dir_he cmpl_constr cmpl_nt cmpl_anim  \
# 0          B NDH      in impurity    0.0        prep   other    inanim
# 1     L PNH >L==                     0.0        prep
# 2  no complement
# 3  no complement
# 4           >XWR        backwards    0.0          vc     dir    inanim
#
#   cmpl_det cmpl_indiv cmpl_complex motion_type spatial_arg_type preposition_1  \
# 0      und       subs       simple     fictive         location             B
# 1      und       subs      complex                                          L
# 2
# 3
# 4      det       subs       simple     fictive       trajectory
#
#   preposition_2 preposition_3 preposition_4       comments  \
# 0
# 1                                            reconstructed
# 2
# 3
# 4
#
#   reconstructed_verse  Study_Edition preposition_5 preposition_6
# 0                      p148 col 4 19
# 1                       p150 col 5 1
# 2
# 3
# 4                      p150 col 5 24

# %%
combined_df.columns
# Out:
# Index(['verb_id', 'lex', 'scroll', 'book', 'chapter', 'verse_num',
#        'gcons_verb', 'gcons_verse', 'sign_info', 'stem', 'tense',
#        'gcons_clause', 'subject', 'complement', 'cmpl_lex', 'cmpl_translation',
#        'dir_he', 'cmpl_constr', 'cmpl_nt', 'cmpl_anim', 'cmpl_det',
#        'cmpl_indiv', 'cmpl_complex', 'motion_type', 'spatial_arg_type',
#        'preposition_1', 'preposition_2', 'preposition_3', 'preposition_4',
#        'comments', 'reconstructed_verse', 'Study_Edition', 'preposition_5',
#        'preposition_6'],
#       dtype='object')

# %%
set(combined_df.preposition_1)
# Out:
# {'',
#  ' >L',
#  '<D',
#  '<L',
#  '<L ',
#  '<L PNH/',
#  '<LJHM',
#  '<LJK',
#  '<LJKM',
#  '<M',
#  '>L',
#  '>L ',
#  '>L BJN/',
#  '>L PNH/',
#  '>LJ',
#  '>LJH',
#  '>LJK',
#  '>LJKM',
#  '>LJW',
#  '>T==',
#  '>TKM',
#  '>XR/',
#  '>YL/',
#  'B',
#  'B<D/',
#  'BH',
#  'BJN/',
#  'BK',
#  'BM',
#  'BMW',
#  'BW',
#  'K',
#  'L',
#  'L >P/',
#  'L PNH/',
#  'LHM',
#  'LHN',
#  'LHNH',
#  'LJ',
#  'LKM',
#  'LW',
#  'M',
#  'MHM',
#  'MMNH',
#  'MMNJ',
#  'MMNW',
#  'MN',
#  'MNJ',
#  'MWL/',
#  'NGD/',
#  'QDM/',
#  'TXT',
#  'TXT/'}

# %%
combined_df.to_csv("data/datasets_to_check/combined_data.csv", index=False)

# %%
df = combined_df.copy()

# %%
df[df.cmpl_lex == df.preposition_1]
# Out:
#        verb_id   lex scroll          book  chapter  verse_num gcons_verb  \
# 336     396802  NPL[     MT  1_Chronicles       10          4        JPL
# 361     397503  JRD[     MT  1_Chronicles       11         23        JRD
# 370     397976  JY>[     MT  1_Chronicles       12         18        JY>
# 371     397988  BW>[     MT  1_Chronicles       12         18       B>TM
# 377     398083  NPL[     MT  1_Chronicles       12         21       NPLW
# ...        ...   ...    ...           ...      ...        ...        ...
# 14429  2098490  <BR[  Mur88     Zephaniah        2         15       <WBR
# 14430  2040071  <BR[   4Q78     Zephaniah        2         15       <WBR
# 14431  2037670  <BR[   4Q77     Zephaniah        2         15       <WBR
# 14435  2098664  SWR[  Mur88     Zephaniah        3         11       >SJR
# 14442  2037711  BW>[   4Q77     Zephaniah        3         20       >BJ>
#
#                                              gcons_verse  \
# 336    W J>MR C>WL >L NF> KLJW CLP XRBK W DQRNJ BH PN...
# 361    W HW> HKH >T H >JC H MYRJ >JC MDH XMC B >MH W ...
# 370    W JY> DWJD L PNJHM W J<N W J>MR LHM >M L CLWM ...
# 371    W JY> DWJD L PNJHM W J<N W J>MR LHM >M L CLWM ...
# 377    B LKTW >L YJQLG NPLW <LJW M MNCH <DNX W JWZBD ...
# ...                                                  ...
# 14429  Z>T H <JR H <LJZH H JWCBT L BVX H >MRH B LBBH ...
# 14430  Z>T H <JR H <LJZH H JWCBT L BVX H >WMRH B LBBH...
# 14431  Z>T H <JR H <LJZH H JWCBT L BVX H >MRH B LBBH ...
# 14435  B JWM H HW> L> TBWCJ M KL <LJLWTJK >CR PC<T BJ...
# 14442  B <T H HJ> >BJ> >TKM W B <T QBYJ >TKM KJ >TN >...
#
#                                                sign_info stem tense  \
# 336                                                       qal  wayq
# 361                                                       qal  wayq
# 370                                                       qal  wayq
# 371                                                       qal  perf
# 377                                                       qal  perf
# ...                                                  ...  ...   ...
# 14429  111 1 111 1 00110 1 11111 1 111 0 0000 0 0000 ...  qal  ptca
# 14430  111 1 111 1 11111 1 11111 1 111 1 11111 1 1000...  qal  ptca
# 14431  001 1 111 1 11111 1 11111 1 111 0 0000 1 0111 ...  qal  ptca
# 14435  1 111 1 111 00 00000 0 10 00000000 000 0000 00...  hif  impf
# 14442  1 11 1 111 1111 1110 0 0 00 0000 0000 00 000 0...  hif  impf
#
#                                             gcons_clause  \
# 336                                           W JPL <LJH
# 361                                     W JRD >LJW B CBV
# 370                                   W JY> DWJD L PNJHM
# 371                                   >M L CLWM B>TM >LJ
# 377    NPLW <LJW M MNCH <DNX W JWZBD W JDJ<>L W MJK>L...
# ...                                                  ...
# 14429                                               None
# 14430                                               None
# 14431                                               None
# 14435                                               None
# 14442                                               None
#
#                                                  subject complement cmpl_lex  \
# 336                                                            <LJH       <L
# 361                                                            >LJW       >L
# 370                                                 DWJD    L PNJHM   L PNH/
# 371                                                             >LJ       >L
# 377    M MNCH <DNX W JWZBD W JDJ<>L W MJK>L W JWZBD W...       <LJW       <L
# ...                                                  ...        ...      ...
# 14429                                               None
# 14430                                               None
# 14431                                               None
# 14435                                               None
# 14442                                               None
#
#       cmpl_translation dir_he cmpl_constr cmpl_nt cmpl_anim cmpl_det  \
# 336        upon it/her    0.0        prep    prps    inanim      det
# 361        to him / it    0.0        prep    prps      anim      det
# 370        before them    0.0        prep    prps      anim      det
# 371              to me    0.0        prep    prps      anim      det
# 377      upon it / him    0.0        prep    prps    inanim      det
# ...                ...    ...         ...     ...       ...      ...
# 14429
# 14430
# 14431
# 14435
# 14442
#
#       cmpl_indiv cmpl_complex motion_type spatial_arg_type preposition_1  \
# 336         prsf       simple    vertical             goal            <L
# 361         prsf       simple     factive             goal            >L
# 370         prsf       simple     factive             goal        L PNH/
# 371         prsf       simple     factive             goal            >L
# 377         prsf       simple     factive             goal            <L
# ...          ...          ...         ...              ...           ...
# 14429
# 14430
# 14431
# 14435
# 14442
#
#       preposition_2 preposition_3 preposition_4              comments  \
# 336
# 361
# 370
# 371
# 377
# ...             ...           ...           ...                   ...
# 14429                                            predicate complement
# 14430                                                   reconstructed
# 14431                                                   reconstructed
# 14435                                                   reconstructed
# 14442                                                   reconstructed
#
#                                      reconstructed_verse Study_Edition  \
# 336
# 361
# 370
# 371
# 377
# ...                                                  ...           ...
# 14429  [Z>T H <JR H] <L[JZ]H [H JWCBT L BVX] H >MRH B...
# 14430  [Z>T H <JR H <LJZH H JWCBT L BVX H >WMRH B L]B...
# 14431  Z>[T H <JR H <LJZH H JWCBT L BVX] H >MRH [B] L...
# 14435  [B JWM H HW>] L> TBWCJ M [K]L <LJLWTJK >CR PC<...
# 14442  [B <T H HJ> >BJ> >TK]M W B <T QBYJ >TKM KJ >TN...
#
#       preposition_5 preposition_6
# 336
# 361
# 370
# 371
# 377
# ...             ...           ...
# 14429
# 14430
# 14431
# 14435
# 14442
#
# [2672 rows x 34 columns]
