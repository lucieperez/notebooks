# %%
import pandas as pd

# %%
df_1 = pd.read_csv('data/biblical_datasets/1_samuel/annotation_df_history/1_samuel.csv').fillna("")

# %%
df_1
# Out:
#      verb_id   lex scroll      book  chapter  verse_num gcons_verb  \
# 0     141586  <LH[     MT  1_Samuel        1          3        <LH
# 1     141672  <LH[     MT  1_Samuel        1          7       <LTH
# 2     141776  <LH[     MT  1_Samuel        1         11       J<LH
# 3    1996829  <BR[   4Q51  1_Samuel        1         11      J<BWR
# 4     141818  SWR[     MT  1_Samuel        1         14      HSJRJ
# ..       ...   ...    ...       ...      ...        ...        ...
# 957   160348  BW>[     MT  1_Samuel       31          7       JB>W
# 958   160358  BW>[     MT  1_Samuel       31          8       JB>W
# 959   160373  NPL[     MT  1_Samuel       31          8      NPLJM
# 960   160431  HLK[     MT  1_Samuel       31         12       JLKW
# 961   160448  BW>[     MT  1_Samuel       31         12       JB>W
#
#                                            gcons_verse  \
# 0    W <LH H >JC H HW> M <JRW M JMJM JMJMH L HCTXWT...
# 1    W KN J<FH CNH B CNH M DJ <LTH B BJT JHWH KN TK...
# 2    W TDR NDR W T>MR JHWH YB>WT >M R>H TR>H B <NJ ...
# 3    JHWH YB>WT >M R>H TR>H B <NJ >MTK W ZKRTNJ W L...
# 4    W J>MR >LJH <LJ <D MTJ TCTKRJN HSJRJ >T JJNK M...
# ..                                                 ...
# 957  W JR>W >NCJ JFR>L >CR B <BR H <MQ W >CR B <BR ...
# 958  W JHJ M MXRT W JB>W PLCTJM L PCV >T H XLLJM W ...
# 959  W JHJ M MXRT W JB>W PLCTJM L PCV >T H XLLJM W ...
# 960  W JQWMW KL >JC XJL W JLKW KL H LJLH W JQXW >T ...
# 961  W JQWMW KL >JC XJL W JLKW KL H LJLH W JQXW >T ...
#
#                                              sign_info stem  ...  \
# 0                                                       qal  ...
# 1                                                       qal  ...
# 2                                                       qal  ...
# 3    1111 11111 11 111 1111 1 111 1110 1 111111 1 1...  qal  ...
# 4                                                       hif  ...
# ..                                                 ...  ...  ...
# 957                                                     qal  ...
# 958                                                     qal  ...
# 959                                                     qal  ...
# 960                                                     qal  ...
# 961                                                     qal  ...
#
#     preposition_1 preposition_2 preposition_3 preposition_4 preposition_5  \
# 0              MN
# 1               B
# 2              <L
# 3
# 4              MN            <L
# ..            ...           ...           ...           ...           ...
# 957
# 958
# 959             B
# 960
# 961
#
#     preposition_6 preposition_7 comments dir_he_dss  \
# 0
# 1
# 2
# 3
# 4
# ..            ...           ...      ...        ...
# 957
# 958
# 959
# 960
# 961
#
#                                    reconstructed_verse
# 0
# 1
# 2
# 3    [JHWH YB>WT >M R>H TR>H B <NJ >MT]K [W ZKRTNJ ...
# 4
# ..                                                 ...
# 957
# 958
# 959
# 960
# 961
#
# [962 rows x 34 columns]

# %%
# Add a column with the verse plus brackets indicating reconstructed letters

def reconstruct_verse(sign_info, verse):
    rec_verse = []
    is_reconstructed = False

    for c_verse, c_sign in zip(verse, sign_info):
        if c_sign == "1" and not is_reconstructed:
            is_reconstructed = True
            rec_verse.append("[")
        if c_sign == "0" and is_reconstructed:
            is_reconstructed = False
            if rec_verse[-1] == " ":
                rec_verse.pop()
                rec_verse.extend(["]", " "])
            else:
                rec_verse.append("]")
        rec_verse.append(c_verse)

    if is_reconstructed:
        rec_verse.append("]")
    return "".join(rec_verse)

df = df_1
df["reconstructed_verse"] = ""

df["reconstructed_verse"] = df.apply(lambda row: reconstruct_verse(row.sign_info, row.gcons_verse) if row.book != "MT" else "", axis=1)

df = df_1

# %%
df
# Out:
#      verb_id   lex scroll      book  chapter  verse_num gcons_verb  \
# 0     141586  <LH[     MT  1_Samuel        1          3        <LH
# 1     141672  <LH[     MT  1_Samuel        1          7       <LTH
# 2     141776  <LH[     MT  1_Samuel        1         11       J<LH
# 3    1996829  <BR[   4Q51  1_Samuel        1         11      J<BWR
# 4     141818  SWR[     MT  1_Samuel        1         14      HSJRJ
# ..       ...   ...    ...       ...      ...        ...        ...
# 957   160348  BW>[     MT  1_Samuel       31          7       JB>W
# 958   160358  BW>[     MT  1_Samuel       31          8       JB>W
# 959   160373  NPL[     MT  1_Samuel       31          8      NPLJM
# 960   160431  HLK[     MT  1_Samuel       31         12       JLKW
# 961   160448  BW>[     MT  1_Samuel       31         12       JB>W
#
#                                            gcons_verse  \
# 0    W <LH H >JC H HW> M <JRW M JMJM JMJMH L HCTXWT...
# 1    W KN J<FH CNH B CNH M DJ <LTH B BJT JHWH KN TK...
# 2    W TDR NDR W T>MR JHWH YB>WT >M R>H TR>H B <NJ ...
# 3    JHWH YB>WT >M R>H TR>H B <NJ >MTK W ZKRTNJ W L...
# 4    W J>MR >LJH <LJ <D MTJ TCTKRJN HSJRJ >T JJNK M...
# ..                                                 ...
# 957  W JR>W >NCJ JFR>L >CR B <BR H <MQ W >CR B <BR ...
# 958  W JHJ M MXRT W JB>W PLCTJM L PCV >T H XLLJM W ...
# 959  W JHJ M MXRT W JB>W PLCTJM L PCV >T H XLLJM W ...
# 960  W JQWMW KL >JC XJL W JLKW KL H LJLH W JQXW >T ...
# 961  W JQWMW KL >JC XJL W JLKW KL H LJLH W JQXW >T ...
#
#                                              sign_info stem  ...  \
# 0                                                       qal  ...
# 1                                                       qal  ...
# 2                                                       qal  ...
# 3    1111 11111 11 111 1111 1 111 1110 1 111111 1 1...  qal  ...
# 4                                                       hif  ...
# ..                                                 ...  ...  ...
# 957                                                     qal  ...
# 958                                                     qal  ...
# 959                                                     qal  ...
# 960                                                     qal  ...
# 961                                                     qal  ...
#
#     preposition_1 preposition_2 preposition_3 preposition_4 preposition_5  \
# 0              MN
# 1               B
# 2              <L
# 3
# 4              MN            <L
# ..            ...           ...           ...           ...           ...
# 957
# 958
# 959             B
# 960
# 961
#
#     preposition_6 preposition_7 comments dir_he_dss  \
# 0
# 1
# 2
# 3
# 4
# ..            ...           ...      ...        ...
# 957
# 958
# 959
# 960
# 961
#
#                                    reconstructed_verse
# 0
# 1
# 2
# 3    [JHWH YB>WT >M R>H TR>H B <NJ >MT]K [W ZKRTNJ ...
# 4
# ..                                                 ...
# 957
# 958
# 959
# 960
# 961
#
# [962 rows x 34 columns]

# %%
# Delete the DSS duplicated

verb_ids = df.verb_id.to_list()

duplicates = set([verb_id for verb_id in verb_ids if verb_ids.count(verb_id) > 1])

df = df_1
df_1 = df[~((df.gcons_clause == "None") & (df.subject == "None") & (df.verb_id.isin(duplicates)))] # delete duplicates
df_1.reset_index(drop=True, inplace=True) # reset the index for AnnotEasy
df = df_1

# %%
df
# Out:
#      verb_id   lex scroll      book  chapter  verse_num gcons_verb  \
# 0     141586  <LH[     MT  1_Samuel        1          3        <LH
# 1     141672  <LH[     MT  1_Samuel        1          7       <LTH
# 2     141776  <LH[     MT  1_Samuel        1         11       J<LH
# 3    1996829  <BR[   4Q51  1_Samuel        1         11      J<BWR
# 4     141818  SWR[     MT  1_Samuel        1         14      HSJRJ
# ..       ...   ...    ...       ...      ...        ...        ...
# 957   160348  BW>[     MT  1_Samuel       31          7       JB>W
# 958   160358  BW>[     MT  1_Samuel       31          8       JB>W
# 959   160373  NPL[     MT  1_Samuel       31          8      NPLJM
# 960   160431  HLK[     MT  1_Samuel       31         12       JLKW
# 961   160448  BW>[     MT  1_Samuel       31         12       JB>W
#
#                                            gcons_verse  \
# 0    W <LH H >JC H HW> M <JRW M JMJM JMJMH L HCTXWT...
# 1    W KN J<FH CNH B CNH M DJ <LTH B BJT JHWH KN TK...
# 2    W TDR NDR W T>MR JHWH YB>WT >M R>H TR>H B <NJ ...
# 3    JHWH YB>WT >M R>H TR>H B <NJ >MTK W ZKRTNJ W L...
# 4    W J>MR >LJH <LJ <D MTJ TCTKRJN HSJRJ >T JJNK M...
# ..                                                 ...
# 957  W JR>W >NCJ JFR>L >CR B <BR H <MQ W >CR B <BR ...
# 958  W JHJ M MXRT W JB>W PLCTJM L PCV >T H XLLJM W ...
# 959  W JHJ M MXRT W JB>W PLCTJM L PCV >T H XLLJM W ...
# 960  W JQWMW KL >JC XJL W JLKW KL H LJLH W JQXW >T ...
# 961  W JQWMW KL >JC XJL W JLKW KL H LJLH W JQXW >T ...
#
#                                              sign_info stem  ...  \
# 0                                                       qal  ...
# 1                                                       qal  ...
# 2                                                       qal  ...
# 3    1111 11111 11 111 1111 1 111 1110 1 111111 1 1...  qal  ...
# 4                                                       hif  ...
# ..                                                 ...  ...  ...
# 957                                                     qal  ...
# 958                                                     qal  ...
# 959                                                     qal  ...
# 960                                                     qal  ...
# 961                                                     qal  ...
#
#     preposition_1 preposition_2 preposition_3 preposition_4 preposition_5  \
# 0              MN
# 1               B
# 2              <L
# 3
# 4              MN            <L
# ..            ...           ...           ...           ...           ...
# 957
# 958
# 959             B
# 960
# 961
#
#     preposition_6 preposition_7 comments dir_he_dss  \
# 0
# 1
# 2
# 3
# 4
# ..            ...           ...      ...        ...
# 957
# 958
# 959
# 960
# 961
#
#                                    reconstructed_verse
# 0
# 1
# 2
# 3    [JHWH YB>WT >M R>H TR>H B <NJ >MT]K [W ZKRTNJ ...
# 4
# ..                                                 ...
# 957
# 958
# 959
# 960
# 961
#
# [962 rows x 34 columns]

# %%
df.to_csv('data/biblical_datasets/1_samuel/annotation_df_history/1_samuel.csv', index=False)
