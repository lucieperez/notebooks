# %%
import pandas as pd

# %%
df_1 = pd.read_csv('data/biblical_datasets/isaiah_locatives/annotation_df_history/isaiah_with_loca.csv').fillna("")

# %%
df_1
# Out:
#       verb_id   lex  scroll    book  chapter  verse_num gcons_verb  \
# 0      212256  BW>[      MT  Isaiah        1         12       TB>W
# 1     1895059  BW>[  1Qisaa  Isaiah        1         12       TB>W
# 2      212269  BW>[      MT  Isaiah        1         13       HBJ>
# 3     1895075  BW>[  1Qisaa  Isaiah        1         13       HBJ>
# 4      212315  SWR[      MT  Isaiah        1         16      HSJRW
# ...       ...   ...     ...     ...      ...        ...        ...
# 1680  1918901  BW>[  1Qisaa  Isaiah       66         23       JBW>
# 1681  1927678  BW>[     1Q8  Isaiah       66         23       JBW>
# 1682   234980  JY>[      MT  Isaiah       66         24       JY>W
# 1683  1918913  JY>[  1Qisaa  Isaiah       66         24       JY>W
# 1684  1927689  JY>[     1Q8  Isaiah       66         24       JY>W
#
#                                             gcons_verse  \
# 0         KJ TB>W L R>WT PNJ MJ BQC Z>T M JDKM RMS XYRJ
# 1     KJ> TB>W L R>WT PNJ MJ BQC ZW>T M JDKM L RMWS ...
# 2     L> TWSJPW HBJ> MNXT CW> QVRT TW<BH HJ> LJ XDC ...
# 3     LW> TWSJPW L HBJ> MNXT CW> QVRT TW<BH HJ> LJ X...
# 4        RXYW HZKW HSJRW R< M<LLJKM M NGD <JNJ XDLW HR<
# ...                                                 ...
# 1680  W HJH M DJ XWDC B XWDCW W M DJ CBT B CBTH JBW>...
# 1681  W HJH M DJ XDC B XDCW W M DJ CBT B CBTW JBW> K...
# 1682  W JY>W W R>W B PGRJ H >NCJM H PC<JM BJ KJ TWL<...
# 1683  W JY>W W R>W B PGRJ H >NCJM H PWC<JM BJ> KJ> T...
# 1684  W JY>W W R>W B PGRJ H >NCJM H PC<JM BJ KJ TWL<...
#
#                                               sign_info   stem  ...  \
# 0                                                          qal  ...
# 1     000 0000 0 0000 000 00 000 0000 0 0000 0 0000 ...    qal  ...
# 2                                                          hif  ...
# 3     000 000000 0 0000 0000 000 0000 00000 000 00 0...  hifil  ...
# 4                                                          hif  ...
# ...                                                 ...    ...  ...
# 1680  0 000 0 00 0000 0 00000 0 0 00 000 0 0000 0000...    qal  ...
# 1681  1 111 1 00 001 1 1000 0 0 00 110 0 0000 0000 0...    qal  ...
# 1682                                                       qal  ...
# 1683  0 0000 0 000 0 0000 0 00000 0 000000 000 000 0...    qal  ...
# 1684  1 1111 1 111 1 1111 0 00000 0 11111 11 11 1111...    qal  ...
#
#      cmpl_indiv cmpl_complex motion_type preposition_1 preposition_2  \
# 0
# 1
# 2
# 3
# 4          subs      complex     fictive            MN
# ...         ...          ...         ...           ...           ...
# 1680
# 1681
# 1682
# 1683
# 1684
#
#      preposition_3 preposition_4 preposition_5 preposition_6        comments
# 0
# 1
# 2
# 3
# 4
# ...            ...           ...           ...           ...             ...
# 1680
# 1681                                                          reconstructed?
# 1682
# 1683
# 1684                                                           reconstructed
#
# [1685 rows x 31 columns]

# %%
# Add a column with the verse plus brackets indicating reconstructed letters

def reconstruct_verse(sign_info, verse):
    rec_verse = []
    is_reconstructed = False

    for c_verse, c_sign in zip(verse, sign_info):
        if c_sign == "1" and not is_reconstructed:
            is_reconstructed = True
            rec_verse.append("[")
        if c_sign == "0" and is_reconstructed:
            is_reconstructed = False
            if rec_verse[-1] == " ":
                rec_verse.pop()
                rec_verse.extend(["]", " "])
            else:
                rec_verse.append("]")
        rec_verse.append(c_verse)

    if is_reconstructed:
        rec_verse.append("]")
    return "".join(rec_verse)

df = df_1
df["reconstructed_verse"] = ""

df["reconstructed_verse"] = df.apply(lambda row: reconstruct_verse(row.sign_info, row.gcons_verse) if row.book != "MT" else "", axis=1)

df = df_1

# %%
df
# Out:
#       verb_id   lex  scroll    book  chapter  verse_num gcons_verb  \
# 0      212256  BW>[      MT  Isaiah        1         12       TB>W
# 1     1895059  BW>[  1Qisaa  Isaiah        1         12       TB>W
# 2      212269  BW>[      MT  Isaiah        1         13       HBJ>
# 3     1895075  BW>[  1Qisaa  Isaiah        1         13       HBJ>
# 4      212315  SWR[      MT  Isaiah        1         16      HSJRW
# ...       ...   ...     ...     ...      ...        ...        ...
# 1680  1918901  BW>[  1Qisaa  Isaiah       66         23       JBW>
# 1681  1927678  BW>[     1Q8  Isaiah       66         23       JBW>
# 1682   234980  JY>[      MT  Isaiah       66         24       JY>W
# 1683  1918913  JY>[  1Qisaa  Isaiah       66         24       JY>W
# 1684  1927689  JY>[     1Q8  Isaiah       66         24       JY>W
#
#                                             gcons_verse  \
# 0         KJ TB>W L R>WT PNJ MJ BQC Z>T M JDKM RMS XYRJ
# 1     KJ> TB>W L R>WT PNJ MJ BQC ZW>T M JDKM L RMWS ...
# 2     L> TWSJPW HBJ> MNXT CW> QVRT TW<BH HJ> LJ XDC ...
# 3     LW> TWSJPW L HBJ> MNXT CW> QVRT TW<BH HJ> LJ X...
# 4        RXYW HZKW HSJRW R< M<LLJKM M NGD <JNJ XDLW HR<
# ...                                                 ...
# 1680  W HJH M DJ XWDC B XWDCW W M DJ CBT B CBTH JBW>...
# 1681  W HJH M DJ XDC B XDCW W M DJ CBT B CBTW JBW> K...
# 1682  W JY>W W R>W B PGRJ H >NCJM H PC<JM BJ KJ TWL<...
# 1683  W JY>W W R>W B PGRJ H >NCJM H PWC<JM BJ> KJ> T...
# 1684  W JY>W W R>W B PGRJ H >NCJM H PC<JM BJ KJ TWL<...
#
#                                               sign_info   stem  ...  \
# 0                                                          qal  ...
# 1     000 0000 0 0000 000 00 000 0000 0 0000 0 0000 ...    qal  ...
# 2                                                          hif  ...
# 3     000 000000 0 0000 0000 000 0000 00000 000 00 0...  hifil  ...
# 4                                                          hif  ...
# ...                                                 ...    ...  ...
# 1680  0 000 0 00 0000 0 00000 0 0 00 000 0 0000 0000...    qal  ...
# 1681  1 111 1 00 001 1 1000 0 0 00 110 0 0000 0000 0...    qal  ...
# 1682                                                       qal  ...
# 1683  0 0000 0 000 0 0000 0 00000 0 000000 000 000 0...    qal  ...
# 1684  1 1111 1 111 1 1111 0 00000 0 11111 11 11 1111...    qal  ...
#
#      cmpl_complex motion_type preposition_1 preposition_2 preposition_3  \
# 0
# 1
# 2
# 3
# 4         complex     fictive            MN
# ...           ...         ...           ...           ...           ...
# 1680
# 1681
# 1682
# 1683
# 1684
#
#      preposition_4 preposition_5 preposition_6        comments  \
# 0
# 1
# 2
# 3
# 4
# ...            ...           ...           ...             ...
# 1680
# 1681                                            reconstructed?
# 1682
# 1683
# 1684                                             reconstructed
#
#                                     reconstructed_verse
# 0
# 1     KJ> TB>W L R>WT PNJ MJ BQC ZW>T M JDKM L RMWS ...
# 2
# 3     LW> TWSJPW L HBJ> MNXT CW> QVRT TW<BH HJ> LJ X...
# 4
# ...                                                 ...
# 1680  W HJH M DJ XWDC B XWDCW W M DJ CBT B CBTH JBW>...
# 1681  [W HJH M] DJ XD[C B X]DCW W M DJ [CB]T B CBTW ...
# 1682
# 1683  W JY>W W R>W B PGRJ H >NCJM H PWC<JM BJ> KJ> T...
# 1684  [W JY>W W R>W B PGRJ] H >NCJM H [PC<JM BJ KJ T...
#
# [1685 rows x 32 columns]

# %%
# Delete the DSS duplicated

verb_ids = df.verb_id.to_list()

duplicates = set([verb_id for verb_id in verb_ids if verb_ids.count(verb_id) > 1])

df = df_1
df_1 = df[~((df.gcons_clause == "None") & (df.subject == "None") & (df.verb_id.isin(duplicates)))] # delete duplicates
df_1.reset_index(drop=True, inplace=True) # reset the index for AnnotEasy
df = df_1

# %%
df
# Out:
#       verb_id   lex  scroll    book  chapter  verse_num gcons_verb  \
# 0      212256  BW>[      MT  Isaiah        1         12       TB>W
# 1     1895059  BW>[  1Qisaa  Isaiah        1         12       TB>W
# 2      212269  BW>[      MT  Isaiah        1         13       HBJ>
# 3     1895075  BW>[  1Qisaa  Isaiah        1         13       HBJ>
# 4      212315  SWR[      MT  Isaiah        1         16      HSJRW
# ...       ...   ...     ...     ...      ...        ...        ...
# 1678  1918901  BW>[  1Qisaa  Isaiah       66         23       JBW>
# 1679  1927678  BW>[     1Q8  Isaiah       66         23       JBW>
# 1680   234980  JY>[      MT  Isaiah       66         24       JY>W
# 1681  1918913  JY>[  1Qisaa  Isaiah       66         24       JY>W
# 1682  1927689  JY>[     1Q8  Isaiah       66         24       JY>W
#
#                                             gcons_verse  \
# 0         KJ TB>W L R>WT PNJ MJ BQC Z>T M JDKM RMS XYRJ
# 1     KJ> TB>W L R>WT PNJ MJ BQC ZW>T M JDKM L RMWS ...
# 2     L> TWSJPW HBJ> MNXT CW> QVRT TW<BH HJ> LJ XDC ...
# 3     LW> TWSJPW L HBJ> MNXT CW> QVRT TW<BH HJ> LJ X...
# 4        RXYW HZKW HSJRW R< M<LLJKM M NGD <JNJ XDLW HR<
# ...                                                 ...
# 1678  W HJH M DJ XWDC B XWDCW W M DJ CBT B CBTH JBW>...
# 1679  W HJH M DJ XDC B XDCW W M DJ CBT B CBTW JBW> K...
# 1680  W JY>W W R>W B PGRJ H >NCJM H PC<JM BJ KJ TWL<...
# 1681  W JY>W W R>W B PGRJ H >NCJM H PWC<JM BJ> KJ> T...
# 1682  W JY>W W R>W B PGRJ H >NCJM H PC<JM BJ KJ TWL<...
#
#                                               sign_info   stem  ...  \
# 0                                                          qal  ...
# 1     000 0000 0 0000 000 00 000 0000 0 0000 0 0000 ...    qal  ...
# 2                                                          hif  ...
# 3     000 000000 0 0000 0000 000 0000 00000 000 00 0...  hifil  ...
# 4                                                          hif  ...
# ...                                                 ...    ...  ...
# 1678  0 000 0 00 0000 0 00000 0 0 00 000 0 0000 0000...    qal  ...
# 1679  1 111 1 00 001 1 1000 0 0 00 110 0 0000 0000 0...    qal  ...
# 1680                                                       qal  ...
# 1681  0 0000 0 000 0 0000 0 00000 0 000000 000 000 0...    qal  ...
# 1682  1 1111 1 111 1 1111 0 00000 0 11111 11 11 1111...    qal  ...
#
#      cmpl_complex motion_type preposition_1 preposition_2 preposition_3  \
# 0
# 1
# 2
# 3
# 4         complex     fictive            MN
# ...           ...         ...           ...           ...           ...
# 1678
# 1679
# 1680
# 1681
# 1682
#
#      preposition_4 preposition_5 preposition_6        comments  \
# 0
# 1
# 2
# 3
# 4
# ...            ...           ...           ...             ...
# 1678
# 1679                                            reconstructed?
# 1680
# 1681
# 1682                                             reconstructed
#
#                                     reconstructed_verse
# 0
# 1     KJ> TB>W L R>WT PNJ MJ BQC ZW>T M JDKM L RMWS ...
# 2
# 3     LW> TWSJPW L HBJ> MNXT CW> QVRT TW<BH HJ> LJ X...
# 4
# ...                                                 ...
# 1678  W HJH M DJ XWDC B XWDCW W M DJ CBT B CBTH JBW>...
# 1679  [W HJH M] DJ XD[C B X]DCW W M DJ [CB]T B CBTW ...
# 1680
# 1681  W JY>W W R>W B PGRJ H >NCJM H PWC<JM BJ> KJ> T...
# 1682  [W JY>W W R>W B PGRJ] H >NCJM H [PC<JM BJ KJ T...
#
# [1683 rows x 32 columns]

# %%
df.to_csv('data/biblical_datasets/isaiah_locatives/annotation_df_history/isaiah_with_loca.csv', index=False)
