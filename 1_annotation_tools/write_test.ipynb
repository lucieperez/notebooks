# %%
import pandas as pd

# %%
df = pd.read_csv("data/annotation_df_history/isaiah_dataset.csv")

# %%
df
# Out:
#       verb_id   lex  scroll    book  chapter  verse_num gcons_verb  \
# 0      212256  BW>[      MT  Isaiah        1         12       TB>W
# 1     1895059  BW>[  1Qisaa  Isaiah        1         12       TB>W
# 2      212269  BW>[      MT  Isaiah        1         13       HBJ>
# 3     1895075  BW>[  1Qisaa  Isaiah        1         13       HBJ>
# 4      212315  SWR[      MT  Isaiah        1         16      HSJRW
# ...       ...   ...     ...     ...      ...        ...        ...
# 1399  1918901  BW>[  1Qisaa  Isaiah       66         23       JBW>
# 1400  1927678  BW>[     1Q8  Isaiah       66         23       JBW>
# 1401   234980  JY>[      MT  Isaiah       66         24       JY>W
# 1402  1918913  JY>[  1Qisaa  Isaiah       66         24       JY>W
# 1403  1927689  JY>[     1Q8  Isaiah       66         24       JY>W
#
#                                             gcons_verse  \
# 0         KJ TB>W L R>WT PNJ MJ BQC Z>T M JDKM RMS XYRJ
# ...

# %%
allowed_values = {"factive", "fictive", "factive fictive", "other", "", "unknown"}

# %%
assert all([value in allowed_values for value in set(df.motion_type) if isinstance(value, str)])

# %%
set(df.motion_type)
# Out:
# {'factive', 'factive fictive', 'fictive', nan, 'other', 'unknown'}

# %%
len_gcons_verse = len(str(df.gcons_verse))
len_gcons_verse
# Out:
# 684

# %%
assert all([len(text_str) == len(sign_str) for text_str, sign_str in zip(df.gcons_verse, df.sign_info) if isinstance(sign_str, str)])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 assert all([len(text_str) == len(sign_str) for text_str, sign_str in zip(df.gcons_verse, df.sign_info) if isinstance(sign_str, str)])
#
# AssertionError:
