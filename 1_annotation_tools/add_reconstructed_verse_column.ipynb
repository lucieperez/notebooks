# %%
import pandas as pd

# %%
df_1 = pd.read_csv('../2_datasets/generate_datasets/data/biblical_datasets/Jeremiah_dataset.csv').fillna("")

# %%
pd.set_option("display.max_columns", None)

# %%
df_1
# Out:
#      verb_id   lex scroll      book  chapter  verse_num gcons_verb  \
# 0     235056  GLH[     MT  Jeremiah        1          3       GLWT
# 1     235080  JY>[     MT  Jeremiah        1          5        TY>
# 2     235114  HLK[     MT  Jeremiah        1          7        TLK
# 3     235257  BW>[     MT  Jeremiah        1         15        B>W
# 4     239980  Y<D[     MT  Jeremiah       10          5      JY<DW
# ..       ...   ...    ...       ...      ...        ...        ...
# 941   239727  JRD[     MT  Jeremiah        9         17      TRDNH
# 942   239769  <LH[     MT  Jeremiah        9         20        <LH
# 943   239773  BW>[     MT  Jeremiah        9         20         B>
# 944   239789  NPL[     MT  Jeremiah        9         21       NPLH
# 945   239859  BW>[     MT  Jeremiah        9         24       B>JM
#
#                                            gcons_verse  \
# 0    W JHJ B JMJ JHWJQJM BN J>CJHW MLK JHWDH <D TM ...
# 1    B VRM >YWRK B BVN JD<TJK W B VRM TY> M RXM HQD...
# 2    W J>MR JHWH >LJ >L T>MR N<R >NKJ KJ <L KL >CR ...
# 3    KJ HNNJ QR> L KL MCPXWT MMLKWT YPWNH N>M JHWH ...
# 4    K TMR MQCH HMH W L> JDBRW NFW> JNFW> KJ L> JY<...
# ..                                                 ...
# 941  W TMHRNH W TFNH <LJNW NHJ W TRDNH <JNJNW DM<H ...
# 942  KJ <LH MWT B XLWNJNW B> B >RMNWTJNW L HKRJT <W...
# 943  KJ <LH MWT B XLWNJNW B> B >RMNWTJNW L HKRJT <W...
# 944  DBR KH N>M JHWH W NPLH NBLT H >DM K DMN <L PNJ...
# 945    HNH JMJM B>JM N>M JHWH W PQDTJ <L KL MWL B <RLH
#
#                              gcons_clause     subject     complement  \
# 0            <D GLWT JRWCLM B XDC H XMJCJ      JRWCLM  no complement
# 1                       W B VRM TY> M RXM                      M RXM
# 2                            KJ <L KL TLK                      <L KL
# 3                                   W B>W              no complement
# 4                             KJ L> JY<DW              no complement
# ..                                    ...         ...            ...
# 941                   W TRDNH <JNJNW DM<H      <JNJNW  no complement
# 942                  KJ <LH MWT B XLWNJNW         MWT      B XLWNJNW
# 943                        B> B >RMNWTJNW                B >RMNWTJNW
# 944  W NPLH NBLT H >DM K DMN <L PNJ H FDH  NBLT H >DM  no complement
# 945                         HNH JMJM B>JM        JMJM  no complement
#
#           cmpl_lex dir_he cmpl_constr cmpl_nt cmpl_anim cmpl_det cmpl_indiv  \
# 0    no complement
# 1          MN RXM/    0.0        prep                        det       subs
# 2           <L KL/    0.0        prep                        det       subs
# 3    no complement
# 4    no complement
# ..             ...    ...         ...     ...       ...      ...        ...
# 941  no complement
# 942        B XLWN/    0.0        prep                        det       subs
# 943       B >RMWN/    0.0        prep                        det       subs
# 944  no complement
# 945  no complement
#
#     cmpl_complex dir_he_dss sign_info stem tense preposition_1 preposition_2  \
# 0                                      qal  infc
# 1         simple                       qal  impf            MN
# 2         simple                       qal  impf            <L
# 3                                      qal  perf
# 4                                      qal  impf
# ..           ...        ...       ...  ...   ...           ...           ...
# 941                                    qal  impf
# 942       simple                       qal  perf             B
# 943       simple                       qal  perf             B
# 944                                    qal  perf
# 945                                    qal  ptca
#
#     preposition_3 preposition_4 preposition_5 preposition_6 preposition_7  \
# 0
# 1
# 2
# 3
# 4
# ..            ...           ...           ...           ...           ...
# 941
# 942
# 943
# 944
# 945
#
#     cmpl_translation motion_type comments
# 0
# 1
# 2
# 3
# 4
# ..               ...         ...      ...
# 941
# 942
# 943
# 944
# 945
#
# [946 rows x 33 columns]

# %%
# Add a column with the verse plus brackets indicating reconstructed letters

def reconstruct_verse(sign_info, verse):
    rec_verse = []
    is_reconstructed = False

    for c_verse, c_sign in zip(verse, sign_info):
        if c_sign == "1" and not is_reconstructed:
            is_reconstructed = True
            rec_verse.append("[")
        if c_sign == "0" and is_reconstructed:
            is_reconstructed = False
            if rec_verse[-1] == " ":
                rec_verse.pop()
                rec_verse.extend(["]", " "])
            else:
                rec_verse.append("]")
        rec_verse.append(c_verse)

    if is_reconstructed:
        rec_verse.append("]")
    return "".join(rec_verse)

df = df_1
df["reconstructed_verse"] = ""

df["reconstructed_verse"] = df.apply(lambda row: reconstruct_verse(row.sign_info, row.gcons_verse) if row.book != "MT" else "", axis=1)

df = df_1

# %%
df[df.scroll != "MT"]
# Out:
#      verb_id   lex scroll      book  chapter  verse_num gcons_verb  \
# 5    2032619  Y<D[   4Q71  Jeremiah       10          5      JY<DW
# 7    2032599  BW>[   4Q71  Jeremiah       10          9       JWB>
# 10   2033134  <LH[   4Q72  Jeremiah       10         13       J<LH
# 11   2032679  <LH[   4Q71  Jeremiah       10         13       J<LH
# 12   2032689  JY>[   4Q71  Jeremiah       10         13       JWY>
# ..       ...   ...    ...       ...      ...        ...        ...
# 930  2030437  <BR[   4Q70  Jeremiah        9          9        <BR
# 931  2030451  HLK[   4Q70  Jeremiah        9          9       HLKW
# 933  2030498  <BR[   4Q70  Jeremiah        9         11        <BR
# 935  2030518  HLK[   4Q70  Jeremiah        9         12       HLKW
# 937  2030522  HLK[   4Q70  Jeremiah        9         13       JLKW
#
#                                            gcons_verse  \
# 5    K TMR MQCH HMH W L> JDBRW NFW> JNFW> KJ L> JY<...
# 7    KSP MRQ< M TRCJC JWB> W ZHB M >WPZ W JDJ YWRP ...
# 10   HMWN MJM B CMJM W J<LH NF>JM M QYH >RY BRQJM L...
# 11   L QWL TTW HMWN MJM B CMJM W J<LH NF>JM M QYH >...
# 12   L QWL TTW HMWN MJM B CMJM W J<LH NF>JM M QYH >...
# ..                                                 ...
# 930  <L HRJM >F> BKJ W NHJ W <L N>WT MDBR QJNH KJ N...
# 931  <L HRJM >F> BKJ W NHJ W <L N>WT MDBR QJNH KJ N...
# 933  MJ H >JC H XKM W JBJN >T Z>T W >CR DBR PJ JHWH...
# 935  W J>MR JHWH <L <ZBM >T TWRTJ >CR NTTJ L PNJHM ...
# 937  W JLKW >XRJ CRRWT LBM W >XRJ H B<LJM >CR LMDWM...
#
#                              gcons_clause subject  \
# 5                                    None    None
# 7                                    None    None
# 10                                   None    None
# 11                                   None    None
# 12                                   None    None
# ..                                    ...     ...
# 930                                  None    None
# 931                                  None    None
# 933                                  None    None
# 935                         W LW> HLKW BH
# 937  W JLKW >XRJ CRRWT LBM W >XRJ H B<LJM
#
#                         complement cmpl_lex dir_he cmpl_constr cmpl_nt  \
# 5
# 7
# 10
# 11
# 12
# ..                             ...      ...    ...         ...     ...
# 930
# 931
# 933
# 935                             BH             0.0
# 937  >XRJ CRRWT LBM W >XRJ H B<LJM             0.0
#
#     cmpl_anim cmpl_det cmpl_indiv cmpl_complex dir_he_dss  \
# 5                                                     0.0
# 7                                                     0.0
# 10                                                    0.0
# 11                                                    0.0
# 12                                                    0.0
# ..        ...      ...        ...          ...        ...
# 930                                                   0.0
# 931                                                   0.0
# 933                                                   0.0
# 935                                                   0.0
# 937                                                   0.0
#
#                                              sign_info stem tense  \
# 5    0 000 0000 000 0 00 00000  0000 00000 00 00 00...  qal  impf
# 7    000 0000 0 00000 0000 0 000 0 0000 0 000 0000 ...  hof  impf
# 10   0000 000 0 0000 0 0000 00000 1 0 000 000 00000...  hif  wayq
# 11   0 000 000 0000 000 0 0000 0 0000 00000 0 000 0...  hif  wayq
# 12   0 000 000 0000 000 0 0000 0 0000 00000 0 000 0...  hif  wayq
# ..                                                 ...  ...   ...
# 930  00 0000 000 000 0 000 0 00 0000 0000 0000 00 0...  qal  ptca
# 931  00 0000 000 000 0 000 0 00 0000 0000 0000 00 0...  qal  perf
# 933  00 0 000 0 000 0 0000 00 000 0 000 000 00 0000...  qal  ptca
# 935  0 0000 0000 00 0000 00 00000 000 0000 0 00000 ...  qal  perf
# 937  0 0000 0000 00000 000 0 0000 0 00000 000 00000...  qal  wayq
#
#     preposition_1 preposition_2 preposition_3 preposition_4 preposition_5  \
# 5
# 7
# 10
# 11
# 12
# ..            ...           ...           ...           ...           ...
# 930
# 931
# 933
# 935            BH
# 937
#
#     preposition_6 preposition_7 cmpl_translation motion_type comments  \
# 5
# 7
# 10
# 11
# 12
# ..            ...           ...              ...         ...      ...
# 930
# 931
# 933
# 935
# 937
#
#                                    reconstructed_verse
# 5    K TMR MQCH HMH W L> JDBRW NFW> JNFW> KJ L> JY<...
# 7    KSP MRQ< M TRCJC JWB> W ZHB M >WPZ W JDJ YWRP ...
# 10   HMWN MJM B CMJM W J<LH NF>JM [M] QYH >RY BRQJM...
# 11   L QWL TTW HMWN MJM B CMJM W J<LH NF>JM M QYH >...
# 12   L QWL TTW HMWN MJM B CMJM W J<LH NF>JM M QYH >...
# ..                                                 ...
# 930  <L HRJM >F> BKJ W NHJ W <L N>WT MDBR QJNH KJ N...
# 931  <L HRJM >F> BKJ W NHJ W <L N>WT MDBR QJNH KJ N...
# 933  MJ H >JC H XKM W JBJN >T Z>T W >CR DBR PJ JHWH...
# 935  W J>MR JHWH <L <ZBM >T TWRTJ >CR NTTJ L PNJHM ...
# 937  W JLKW >XRJ CRRWT LBM W >XRJ H B<LJM >CR LMDWM...
#
# [150 rows x 34 columns]

# %%
# Delete the DSS duplicated

verb_ids = df.verb_id.to_list()

duplicates = set([verb_id for verb_id in verb_ids if verb_ids.count(verb_id) > 1])

df = df_1
df_1 = df[~((df.gcons_clause == "None") & (df.subject == "None") & (df.verb_id.isin(duplicates)))] # delete duplicates
df_1.reset_index(drop=True, inplace=True) # reset the index for AnnotEasy
df = df_1

# %%
df
# Out:
#       verb_id   lex scroll    book  chapter  verse_num gcons_verb  \
# 0       28771  BW>[     MT  Exodus        1          1       B>JM
# 1       28778  BW>[     MT  Exodus        1          1        B>W
# 2     1945779  BW>[   4Q13  Exodus        1          1       B>JM
# 3     1945787  BW>[   4Q13  Exodus        1          1        B>W
# 4     1941985  BW>[   4Q11  Exodus        1          1       B>JM
# ...       ...   ...    ...     ...      ...        ...        ...
# 1049    33743  NTK[     MT  Exodus        9         33        NTK
# 1050  1948348  JY>[   4Q14  Exodus        9         33        JY>
# 1051  1948371  NTK[   4Q14  Exodus        9         33        NTK
# 1052  1942562  JY>[   4Q11  Exodus        9         33        JY>
# 1053  1942585  NTK[   4Q11  Exodus        9         33        NTK
#
#                                             gcons_verse  \
# 0     W >LH CMWT BNJ JFR>L H B>JM MYRJMH >T J<QB >JC...
# 1     W >LH CMWT BNJ JFR>L H B>JM MYRJMH >T J<QB >JC...
# 2     >LH CMWT BNJ JFR>L H B>JM MYRJMH >T J<QWB >BJH...
# 3     >LH CMWT BNJ JFR>L H B>JM MYRJMH >T J<QWB >BJH...
# 4     >LH CMWT BNJ JFR>L H B>JM MYRJMH >T J<QB >JC W...
# ...                                                 ...
# 1049  W JY> MCH M <M PR<H >T H <JR W JPRF KPJW >L JH...
# 1050  W JY> MCH M <M PR<H >T H <JR W JPRF KPJW >L JH...
# 1051  W JY> MCH M <M PR<H >T H <JR W JPRF KPJW >L JH...
# 1052  W JY> MCH M <M PR<H >T H <JR W JPRF KPJW >L JH...
# 1053  W JY> MCH M <M PR<H >T H <JR W JPRF KPJW >L JH...
#
#                                               sign_info stem tense  \
# 0                                                        qal  ptca
# 1                                                        qal  perf
# 2     1 1 1 1 1 000 0000 000 00000 0 0000 000000 00 ...  qal  ptca
# 3     1 1 1 1 1 000 0000 000 00000 0 0000 000000 00 ...  qal  perf
# 4     000 0000 000 00000 0 0000 000000 00 0000 000 0...  qal  ptca
# ...                                                 ...  ...   ...
# 1049                                                     nif  perf
# 1050  0 000 000 0 00 0000 00 0 000 0 0000 0000 00 00...  qal  wayq
# 1051  0 000 000 0 00 0000 00 0 000 0 0000 0000 00 00...  nif  perf
# 1052  1 0 000 000 0 00 0000 00 0 000 0 0000 0000 00 ...  qal  wayq
# 1053  1 0 000 000 0 00 0000 00 0 000 0 0000 0000 00 ...  nif  perf
#
#                       gcons_clause     subject     complement       cmpl_lex  \
# 0            H B>JM MYRJMH >T J<QB                     MYRJMH         MYRJM/
# 1                   >JC W BJTW B>W  >JC W BJTW  no complement  no complement
# 2           H B>JM MYRJMH >T J<QWB                     MYRJMH         MYRJM/
# 3                   >JC W BJTW B>W  >JC W BJTW  no complement  no complement
# 4            H B>JM MYRJMH >T J<QB                     MYRJMH         MYRJM/
# ...                            ...         ...            ...            ...
# 1049             W MVR L> NTK >RYH         MVR           >RYH           >RY/
# 1050  W JY> MCH M <M PR<H >T H <JR         MCH      M <M PR<H    MN <M PR<H/
# 1051             W MVR L> NTK >RYH         MVR           >RYH           >RY/
# 1052  W JY> MCH M <M PR<H >T H <JR         MCH      M <M PR<H    MN <M PR<H/
# 1053             W MVR L> NTK >RYH         MVR           >RYH           >RY/
#
#                cmpl_translation dir_he  cmpl_constr cmpl_nt cmpl_anim  \
# 0                      to Egypt    1.0       dir_he    topo    inanim
# 1
# 2                      to Egypt    1.0       dir_he    topo    inanim
# 3
# 4                      to Egypt    1.0       dir_he    topo    inanim
# ...                         ...    ...          ...     ...       ...
# 1049        toward/on the earth    1.0       dir-he    topo    inanim
# 1050  from (being) with Pharaoh    0.0  prep + prep    pers      anim
# 1051        toward/on the earth    1.0       dir-he    topo    inanim
# 1052  from (being) with Pharaoh    0.0  prep + prep    pers      anim
# 1053        toward/on the earth    1.0       dir-he    topo    inanim
#
#      cmpl_det cmpl_indiv cmpl_complex      motion_type preposition_1  \
# 0         det       nmpr       simple          factive
# 1
# 2         det       nmpr       simple          factive
# 3
# 4         det       nmpr       simple          factive
# ...       ...        ...          ...              ...           ...
# 1049      det       subs       simple  factive fictive
# 1050      det       subs       simple          factive            MN
# 1051      det       subs       simple  factive fictive
# 1052      det       subs       simple          factive            MN
# 1053      det       subs       simple  factive fictive
#
#      preposition_2 preposition_3 preposition_4 preposition_5 preposition_6  \
# 0
# 1
# 2
# 3
# 4
# ...            ...           ...           ...           ...           ...
# 1049
# 1050            <M
# 1051
# 1052            <M
# 1053
#
#      preposition_7                                           comments  \
# 0
# 1
# 2
# 3
# 4
# ...            ...                                                ...
# 1049                poured on/toward the earth, not horizontal motion
# 1050
# 1051                poured on/toward the earth, not horizontal motion
# 1052
# 1053                poured on/toward the earth, not horizontal motion
#
#                                     reconstructed_verse
# 0
# 1
# 2     [>LH CMWT B]NJ JFR>L H B>JM MYRJMH >T J<QWB >B...
# 3     [>LH CMWT B]NJ JFR>L H B>JM MYRJMH >T J<QWB >B...
# 4     >LH CMWT BNJ JFR>L H B>JM MYRJMH >T J<QB >JC W...
# ...                                                 ...
# 1049
# 1050  W JY> MCH M <M PR<H >T H <JR W JPRF KPJW >L JH...
# 1051  W JY> MCH M <M PR<H >T H <JR W JPRF KPJW >L JH...
# 1052  [W] JY> MCH M <M PR<H >T H <JR W JPRF KPJW >L ...
# 1053  [W] JY> MCH M <M PR<H >T H <JR W JPRF KPJW >L ...
#
# [1054 rows x 33 columns]

# %%
df.to_csv('data/biblical_datasets/exodus/annotation_df_history/Exodus_dataset.csv', index=False)
