# %%
# This code has been generated using ChatGPT (GPT 5) - September 2025

# %%
import pandas as pd

# %%
df = pd.read_csv("data/datasets_to_check/combined_datasets/combined_datasets.csv").fillna("")

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
def classify_complement(row):
    """Check whether the complement in a verse is present, fully reconstructed, or partially reconstructed."""
    gv  = row.get('gcons_verse')
    si  = row.get('sign_info')
    comp = row.get('complement')

    # Coerce NaNs to empty strings
    gv  = "" if pd.isna(gv)  else str(gv)
    si  = "" if pd.isna(si)  else str(si)
    comp = "" if pd.isna(comp) else str(comp)

    gv_ns   = ''.join(gv.split())
    si_ns   = ''.join(si.split())
    comp_ns = ''.join(comp.split()).lower()

    # Skip if sign_info is empty
    if not si_ns:
        return pd.Series([pd.NA, pd.NA, pd.NA, 'skipped_empty_sign_info'],
                         index=['comp_start','comp_end','comp_sign_info','comp_status'])

    # Skip if complement is empty or "no complement"
    if not comp_ns or comp_ns == 'nocomplement':
        return pd.Series([pd.NA, pd.NA, pd.NA, 'skipped_no_complement'],
                         index=['comp_start','comp_end','comp_sign_info','comp_status'])

    # Length mismatch safeguard
    if len(gv_ns) != len(si_ns):
        return pd.Series([pd.NA, pd.NA, pd.NA, 'length_mismatch'],
                         index=['comp_start','comp_end','comp_sign_info','comp_status'])

    # Find complement in the verse (first occurrence)
    start = gv_ns.find(comp_ns)
    if start == -1:
        return pd.Series([pd.NA, pd.NA, pd.NA, 'not_found'],
                         index=['comp_start','comp_end','comp_sign_info','comp_status'])

    end = start + len(comp_ns)
    comp_si = si_ns[start:end]

    # Classify
    if set(comp_si) == {'0'}:
        status = 'present'
    elif set(comp_si) == {'1'}:
        status = 'fully_reconstructed'
    else:
        status = 'partially_reconstructed'

    return pd.Series([start, end - 1, comp_si, status],
                     index=['comp_start','comp_end','comp_sign_info','comp_status'])

# %%
def check_comment_agreement(row):
    """Verify whether the manual comment about reconstruction agrees with the automatic classification."""
    status = row.get('comp_status')
    comment = row.get('comments')
    comment = "" if pd.isna(comment) else str(comment).lower()

    if status in ['skipped_empty_sign_info', 'skipped_no_complement']:
        return 'not_applicable'

    if status in ['fully_reconstructed', 'partially_reconstructed']:
        return 'agree' if 'reconstructed' in comment else 'disagree'
    elif status == 'present':
        return 'agree' if 'reconstructed' not in comment else 'disagree'
    else:
        return 'not_applicable'

# %%
df[['comp_start','comp_end','comp_sign_info','comp_status']] = df.apply(classify_complement, axis=1)
df['comment_agreement'] = df.apply(check_comment_agreement, axis=1)

# Optional: disagreements
disagreements = df[df['comment_agreement'] == 'disagree']
disagreements[['book','chapter','verse_num','complement','comp_status','comments']]
# Out:
# Empty DataFrame
# Columns: [book, chapter, verse_num, complement, comp_status, comments]
# Index: []

# %%
set(df.comp_status)
# Out:
# {'not_found', 'skipped_empty_sign_info', 'skipped_no_complement'}

# %%
import pandas as pd

def classify_complement_row(gcons_verse, sign_info, complement):
    gv_ns = ''.join((gcons_verse or '').split())  # keep < and >
    si_ns = ''.join((sign_info   or '').split())
    comp_ns = ''.join((complement or '').split())

    # basic guards
    if not si_ns or not comp_ns:
        return {'comp_start': pd.NA, 'comp_end': pd.NA, 'comp_sign_info': pd.NA, 'comp_status': 'skipped'}
    if len(gv_ns) != len(si_ns):
        return {'comp_start': pd.NA, 'comp_end': pd.NA, 'comp_sign_info': pd.NA, 'comp_status': 'length_mismatch'}

    # find first occurrence
    start = gv_ns.find(comp_ns)
    if start == -1:
        return {'comp_start': pd.NA, 'comp_end': pd.NA, 'comp_sign_info': pd.NA, 'comp_status': 'not_found'}

    end = start + len(comp_ns)
    comp_si = si_ns[start:end]

    if set(comp_si) == {'0'}:
        status = 'present'
    elif set(comp_si) == {'1'}:
        status = 'fully_reconstructed'
    else:
        status = 'partially_reconstructed'

    return {'comp_start': start, 'comp_end': end-1, 'comp_sign_info': comp_si, 'comp_status': status}

# %%
gcons_verse = "B <T H HJ> >BJ> >TKM W B <T QBYJ >TKM KJ >TN >TKM"
sign_info   = "1 11 1 111 1111 1110 0 0 00 0000 0000 00 000 0111"

# %%
# Build a small dataframe with the three complements
df_test = pd.DataFrame({
    "gcons_verse": [gcons_verse]*3,
    "sign_info": [sign_info]*3,
    "complement": ["H HJ>", "QBYJ", ">TKM"]
})

# %%
# Apply the function row by row
df_results = df_test.apply(lambda r: pd.Series(classify_complement_row(r['gcons_verse'], r['sign_info'], r['complement'])), axis=1)

# %%
# Combine back into one dataframe
df_out = pd.concat([df_test, df_results], axis=1)

# %%
df_out
# Out:
#                                          gcons_verse  \
# 0  B <T H HJ> >BJ> >TKM W B <T QBYJ >TKM KJ >TN >TKM
# 1  B <T H HJ> >BJ> >TKM W B <T QBYJ >TKM KJ >TN >TKM
# 2  B <T H HJ> >BJ> >TKM W B <T QBYJ >TKM KJ >TN >TKM
#
#                                            sign_info complement  comp_start  \
# 0  1 11 1 111 1111 1110 0 0 00 0000 0000 00 000 0111      H HJ>           3
# 1  1 11 1 111 1111 1110 0 0 00 0000 0000 00 000 0111       QBYJ          19
# 2  1 11 1 111 1111 1110 0 0 00 0000 0000 00 000 0111       >TKM          11
#
#    comp_end comp_sign_info              comp_status
# 0         6           1111      fully_reconstructed
# 1        22           0000                  present
# 2        14           1110  partially_reconstructed

# %%
# Apply the function row by row
df_results = df.apply(lambda r: pd.Series(classify_complement_row(r['gcons_verse'], r['sign_info'], r['complement'])), axis=1)

# %%
df_out = pd.concat([df, df_results], axis=1)

# %%
df_out[(df_out.scroll != "MT") & (df_out.book == "Deuteronomy")]
# Out:
#       verb_id   lex scroll         book  chapter  verse_num gcons_verb  \
# 4005  1985801  PNH[   4Q35  Deuteronomy        1          7        PNW
# 4006  1985803  NS<[   4Q35  Deuteronomy        1          7        S<W
# 4007  1985806  BW>[   4Q35  Deuteronomy        1          7        B>W
# 4009  1992973  BW>[   4Q45  Deuteronomy        1          8        B>W
# 4010  1985849  BW>[   4Q35  Deuteronomy        1          8        B>W
# ...       ...   ...    ...          ...      ...        ...        ...
# 4873  1893598  BW>[    1Q5  Deuteronomy       33         16     TBW>TH
# 4875  1893629  JY>[    1Q5  Deuteronomy       33         18       Y>TK
# 4878  1994539  <LH[   4Q45  Deuteronomy       34          1        J<L
# 4879  2105208  <BR[  Mas1c  Deuteronomy       34          4       T<BR
# 4881  1990710  <BR[   4Q39  Deuteronomy       34          4       T<BR
#
#                                             gcons_verse  \
# 4005  PNW W S<W LKM W B>W HR H >MRJ W >L KL CKNJW B ...
# 4006  PNW W S<W LKM W B>W HR H >MRJ W >L KL CKNJW B ...
# 4007  PNW W S<W LKM W B>W HR H >MRJ W >L KL CKNJW B ...
# 4009  R>H NTTJ L PNJKM >T H >RY B>W W RCW >T H >RY >...
# 4010  R>H NTTJ L PNJKM >T H >RY B>W W RCW >T H >RY >...
# ...                                                 ...
# 4873  W M MGD >RY W ML>H W RYWN CKNJ SNH TBW>TH L R>...
# 4875     W L ZBLWN >MR FMX ZBWLN B Y>TK W JFFKR B >HLJK
# 4878  W J<L MCH M <RBT MW>B >L HR NBW R>C H PSGH >CR...
# 4879  W J>MR JHWH >LJW Z>T H >RY >CR NCB<TJ L >BRHM ...
# 4881  L JYXQ W L J<QB L >MR L ZR<K >TNNH HR>JTJK B <...
#
#                                               sign_info stem tense  \
# 4005  000 0 000 000 0 000 00 1 1111 1 11 11 11111 1 ...  qal  impv
# 4006  000 0 000 000 0 000 00 1 1111 1 11 11 11111 1 ...  qal  impv
# 4007  000 0 000 000 0 000 00 1 1111 1 11 11 11111 1 ...  qal  impv
# 4009  111 1111 1 11111 00 1 111 111 1 111 11 1 111 1...  qal  impv
# 4010  111 1111 1 11111 11 1 111 111 1 111 10 0 000 0...  qal  impv
# ...                                                 ...  ...   ...
# 4873  0 0 000 000 0 0111 1 1111 1111 111 111111 1 11...  qal  impf
# 4875     1 0 00000 001 111 11111 1 1111 1 11111 1 11111  qal  infc
# 4878  1 111 111 1 1111 1111 11 11 111 111 1 1111 111...  qal  wayq
# 4879  1 1111 1110 0000 000 1 111 111 111111 1 11111 ...  qal  impf
# 4881  1 1111 1 1 1111 1 111 1 1111 11111 0001100 1 1...  qal  impf
#
#                                     gcons_clause subject  \
# 4005                                         PNW
# 4006                                   W S<W LKM
# 4007                           W B>W HR [H >MRJ]
# 4009                                         B>W
# 4010                                         B>W
# ...                                          ...     ...
# 4873        TBW>TH L R>C JWSP W L QDQD NZJR >XJW
# 4875                                      B Y>TK
# 4878  W J<L MCH M <RBT MW>B >L HR NBW R>C H PSGH     MCH
# 4879                               W CMH L> T<BR
# 4881                               W CMH L> T<BR
#
#                          complement                          cmpl_lex  \
# 4005                  no complement                     no complement
# 4006                            LKM                                 L
# 4007                    HR [H >MRJ]                       HR/ H >MRJ/
# 4009                  no complement                     no complement
# 4010                  no complement                     no complement
# ...                             ...                               ...
# 4873  L R>C JWSP W L QDQD NZJR >XJW  L R>C/ JWSP/ W L QDQD/ NZJR/ >X/
# 4875                  no complement                     no complement
# 4878           >L HR NBW R>C H PSGH         >L HR/ NBW=/ R>C/ H PSGH/
# 4879                            CMH                                CM
# 4881                            CMH                                CM
#
#                                        cmpl_translation dir_he  cmpl_constr  \
# 4005
# 4006                                   for you / to you    0.0         prep
# 4007  to the mountain / the hill country of the Amor...    0.0           vc
# 4009
# 4010
# ...                                                 ...    ...          ...
# 4873  to the head of Joseph and on the crown of the ...    0.0  prep + prep
# 4875
# 4878                 to mount Nebo to the top of Pisgah    0.0         prep
# 4879                                              there    1.0       dir-he
# 4881                                              there    1.0       dir-he
#
#         cmpl_nt cmpl_anim cmpl_det cmpl_indiv cmpl_complex motion_type  \
# 4005
# 4006     person      anim      det       prsf       simple     factive
# 4007      place    inanim      det       subs      complex     factive
# 4009
# 4010
# ...         ...       ...      ...        ...          ...         ...
# 4873  body part    inanim      det       subs      complex     fictive
# 4875
# 4878      place    inanim      det       subs      complex     factive
# 4879      place    inanim      det        adv       simple     factive
# 4881      place    inanim      det        adv       simple     factive
#
#      spatial_arg_type preposition_1 preposition_2 preposition_3 preposition_4  \
# 4005
# 4006            other             L
# 4007             goal
# 4009
# 4010
# ...               ...           ...           ...           ...           ...
# 4873             goal             L             L
# 4875
# 4878             goal            >L
# 4879             goal
# 4881             goal
#
#      preposition_5 preposition_6       comments  \
# 4005
# 4006
# 4007                              reconstructed
# 4009                              reconstructed
# 4010                              reconstructed
# ...            ...           ...            ...
# 4873                              reconstructed
# 4875                              reconstructed
# 4878                              reconstructed
# 4879                              reconstructed
# 4881                              reconstructed
#
#                                     reconstructed_verse Study_Edition  \
# 4005  PNW W S<W LKM W B>W HR [H >MRJ W >L KL CKNJW B...
# 4006  PNW W S<W LKM W B>W HR [H >MRJ W >L KL CKNJW B...
# 4007  PNW W S<W LKM W B>W HR [H >MRJ W >L KL CKNJW B...
# 4009  [R>H NTTJ L PNJKM] >T [H >RY B>W W RCW >T H >R...
# 4010  [R>H NTTJ L PNJKM >T H >RY B>W W RCW >]T H >RY...
# ...                                                 ...           ...
# 4873  W M MGD >RY W M[L>H W RYWN CKNJ SNH TBW>TH L R...
# 4875  [W] L ZBLWN >M[R FMX ZBWLN B Y>TK W JFFKR B >H...
# 4878  [W J<L MCH M <RBT MW>B >L HR NBW R>C H PSGH >C...
# 4879  [W J>MR JHW]H >LJW Z>T [H >RY >CR NCB<TJ L >BR...
# 4881  [L JYXQ W L J<QB L >MR L ZR<K >TNNH] HR>[JT]JK...
#
#      comp_start comp_end          comp_sign_info              comp_status
# 4005       <NA>     <NA>                    <NA>                not_found
# 4006          7        9                     000                  present
# 4007       <NA>     <NA>                    <NA>                not_found
# 4009       <NA>     <NA>                    <NA>                not_found
# 4010       <NA>     <NA>                    <NA>                not_found
# ...         ...      ...                     ...                      ...
# 4873         31       52  1111111111111111111111      fully_reconstructed
# 4875       <NA>     <NA>                    <NA>                not_found
# 4878         16       30         111111111111111      fully_reconstructed
# 4879         74       76                     001  partially_reconstructed
# 4881         39       41                     111      fully_reconstructed
#
# [469 rows x 38 columns]

# %%
def check_comment_agreement_row(status, comments):
    c = "" if pd.isna(comments) else str(comments).lower()
    if status in ('fully_reconstructed', 'partially_reconstructed'):
        return 'agree' if 'reconstructed' in c else 'disagree'
    elif status == 'present':
        return 'agree' if 'reconstructed' not in c else 'disagree'
    else:
        return 'not_applicable'  # for any other status, if it ever appears

# Add agreement column
df_out['comment_agreement'] = df_out.apply(
    lambda r: check_comment_agreement_row(r['comp_status'], r['comments']),
    axis=1
)

# Show only disagreements
disagreements = df_out[df_out['comment_agreement'] == 'disagree']
disagreements[['complement', 'comp_status', 'comments', 'comp_sign_info', 'comp_start', 'comp_end']]
# Out:
#                              complement              comp_status  \
# 1057                               >RYH                  present
# 1109                                 LW                  present
# 1286                            L MQWMW  partially_reconstructed
# 1538                          B<D H XLN                  present
# 3015                                HNH                  present
# 3894                    <L XD MN Q>MJ >                  present
# 4063                              H HRH                  present
# 4082                      DRK MDBR MW>B  partially_reconstructed
# 4107                                 BW      fully_reconstructed
# 4174            M >RY MYRJM M BJT <BDJM  partially_reconstructed
# 4176            M >RY MYRJM M BJT <BDJM  partially_reconstructed
# 4179            M >RY MYRJM M BJT <BDJM  partially_reconstructed
# 4305            M >RY MYRJM M BJT <BDJM  partially_reconstructed
# 4362                         B KL DRKJW  partially_reconstructed
# 4366                         B KWL DRKW      fully_reconstructed
# 4373                              MYRJM  partially_reconstructed
# 4812                                CMH      fully_reconstructed
# 5185                         L PNJ PR<H                  present
# 5186                         L PNJ PR<H                  present
# 5263                              B MYR                  present
# 5294                              M <LJ      fully_reconstructed
# 5307                              M <LJ  partially_reconstructed
# 5318                                >LJ  partially_reconstructed
# 5345                M MYRJM M BJT <BDJM  partially_reconstructed
# 5351                M MYRJM M BJT <BDJM  partially_reconstructed
# 5390                             L JHWH  partially_reconstructed
# 5392                             L JHWH      fully_reconstructed
# 5397                M MYRJM M BJT <BDJM  partially_reconstructed
# 5423                         B TWK H JM                  present
# 5430                   L PNJ MXNH JFR>L  partially_reconstructed
# 5475                               B JM      fully_reconstructed
# 5521                    >L QYH >RY KN<N  partially_reconstructed
# 5524                           L MS<JHM                  present
# 5533                               MMNW      fully_reconstructed
# 5545                   >L MCH >L H MDBR  partially_reconstructed
# 5546                   >L MCH >L H MDBR  partially_reconstructed
# 5563                                 BH                  present
# 5568                           >L MQWMW  partially_reconstructed
# 5585                         <L HR SJNJ  partially_reconstructed
# 5610                            >L JHWH      fully_reconstructed
# 5671                                 LW                  present
# 5748                                >LJ                  present
# 6027                             M TWKH                  present
# 6335                          <L >DMTKM                  present
# 6594                           >L H >DM                  present
# 6737                                >LJ                  present
# 6805                            L >BRHM                  present
# 7207                              >LJNW  partially_reconstructed
# 7510                       <L VWB YW>RH  partially_reconstructed
# 7584   B NQRWT H YWRJM W B S<PJ H SL<JM  partially_reconstructed
# 7672                      <L KWL >PJQJW      fully_reconstructed
# 7673                     <L KWL GDWWTJW  partially_reconstructed
# 7789                        >L >BNJ BWR  partially_reconstructed
# 8434                               <LJK                  present
# 8444                               <LJK                  present
# 8445                               <LJK                  present
# 8446                               <LJK                  present
# 8624                               CLWM                  present
# 8775                                 LH                  present
# 8935                             >L R<H      fully_reconstructed
# 8945                                 BH                  present
# 9091                                BBL      fully_reconstructed
# 9100                        <L H KFDJJM                  present
# 9126                              B CBJ                  present
# 9978                             TRCJCH  partially_reconstructed
# 9983                              TRCJC      fully_reconstructed
# 10038                            M <LJW                  present
# 11093                               LNW                  present
# 11577                            B JWBL                  present
# 11611                              <MKM  partially_reconstructed
# 12894                               LHM                  present
# 13183                           <L G>JM  partially_reconstructed
# 13242                             MYRJM                  present
#
#              comments            comp_sign_info comp_start comp_end
# 1057    reconstructed                      0000         38       41
# 1109    reconstructed                        00         32       33
# 1286     diff from MT                    000001         72       77
# 1538    reconstructed                   0000000         14       20
# 3015   reconstructed?                       000         59       61
# 3894   reconstructed?               00000000000          4       14
# 4063    reconstructed                      0000         41       44
# 4082                                00000001111         10       20
# 4107                                         11         15       16
# 4174     min excluded        000011110000000000         23       40
# 4176     min excluded        111110000000000011         25       42
# 4179     min excluded        011100000000000000         27       44
# 4305     min excluded        000011111000000000         30       47
# 4362                                   00000011         52       59
# 4366                                   11111111         55       62
# 4373                                      11110         16       20
# 4812         verb rec                       111          4        6
# 5185    reconstructed                  00000000         14       21
# 5186    reconstructed                  00000000         12       19
# 5263    reconstructed                      0000         12       15
# 5294     min excluded                      1111         42       45
# 5307                                       0001         13       16
# 5318         verb rec                       001         15       17
# 5345         verb rec           000000000000011         34       48
# 5351     min excluded           000000000011111         34       48
# 5390                                      00001         14       18
# 5392                                      11111         16       20
# 5397     min excluded           000001110000000         52       66
# 5423    reconstructed                   0000000         46       52
# 5430                              0000100000111         18       30
# 5475                                        111         23       25
# 5521                               000000000110         56       67
# 5524    reconstructed                   0000000         18       24
# 5533     min excluded                      1111         39       42
# 5545         verb rec              000001000011         24       35
# 5546         verb rec              000110000000         24       35
# 5563    reconstructed                        00         42       43
# 5568         verb rec                   0000011         43       49
# 5585         verb rec                  00000111         44       51
# 5610                                     111111         56       61
# 5671    reconstructed                        00         31       32
# 5748    reconstructed                       000          6        8
# 6027    reconstructed                     00000         11       15
# 6335   reconstructed?                  00000000         28       35
# 6594    reconstructed                    000000         46       51
# 6737    reconstructed                       000         22       24
# 6805    reconstructed                    000000          0        5
# 7207                                      10011         57       61
# 7510                                 0000011111         33       42
# 7584                   000000111111110000000000          4       27
# 7672                                11111111111         71       81
# 7673                               111110000000         86       97
# 7789                                  010000000         47       55
# 8434    reconstructed                      0000         40       43
# 8444   reconstructed?                      0000          4        7
# 8445    reconstructed                      0000          4        7
# 8446    reconstructed                      0000          4        7
# 8624    reconstructed                      0000          5        8
# 8775    reconstructed                        00         23       24
# 8935                                      11111         43       47
# 8945    reconstructed                        00         55       56
# 9091                                        111         80       82
# 9100   reconstructed?                 000000000         40       48
# 9126    reconstructed                      0000         20       23
# 9978                                     000001         12       17
# 9983         verb rec                     11111         12       16
# 10038   reconstructed                     00000         37       41
# 11093   reconstructed                       000         26       28
# 11577   reconstructed                     00000         51       55
# 11611        verb rec                      1000          6        9
# 12894   reconstructed                       000          2        4
# 13183        verb rec                    100000         18       23
# 13242   reconstructed                     00000         10       14

# %%
df_out['comment_agreement'].value_counts(dropna=False)
# Out:
# not_applicable    12261
# agree              1303
# disagree             73
# Name: comment_agreement, dtype: int64

# %%
len(df) == (df_out['comment_agreement'] == 'agree').sum() \
          + (df_out['comment_agreement'] == 'disagree').sum() \
          + (df_out['comment_agreement'] == 'not_applicable').sum()
# Out:
# True

# %%
# Get the list of indices
disagreement_indices = disagreements.index.tolist()

str(disagreement_indices)
# Out:
# '[1057, 1109, 1286, 1538, 3015, 3894, 4063, 4082, 4107, 4174, 4176, 4179, 4305, 4362, 4366, 4373, 4812, 5185, 5186, 5263, 5294, 5307, 5318, 5345, 5351, 5390, 5392, 5397, 5423, 5430, 5475, 5521, 5524, 5533, 5545, 5546, 5563, 5568, 5585, 5610, 5671, 5748, 6027, 6335, 6594, 6737, 6805, 7207, 7510, 7584, 7672, 7673, 7789, 8434, 8444, 8445, 8446, 8624, 8775, 8935, 8945, 9091, 9100, 9126, 9978, 9983, 10038, 11093, 11577, 11611, 12894, 13183, 13242]'
