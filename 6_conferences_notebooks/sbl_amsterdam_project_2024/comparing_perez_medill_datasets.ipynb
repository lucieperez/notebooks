# %%
import pandas as pd
import re

# %%
pd.set_option("display.max_columns", None)

# %%
# Import Medill dataset
df_1 = pd.read_excel("data/Medill 2020 Hebrew Goal Data.xls").fillna("")

# %%
# Select only books present in Perez
df_m = df_1[df_1.book.isin(['exodus', 'deuteronomy', 'isaiah'])].copy()

# %%
# Import Perez dataset
df_2 = pd.read_csv("data/sbl_grouped_cmpls_for_annot.csv").fillna("")

# %%
# Select only goals
df_p = df_2[df_2.spatial_arg_type == "goal"].copy()

# %%
df_1.columns
# Out:
# Index(['id', 'book', 'info_refer', 'info_reads', 'info_means', 'texttype',
#        'syn_vbinit', 'syn_gcb4vb', 'syn_realis', 'syn_affneg', 'sub_explicit',
#        'sub_anim', 'sub_def', 'sub_num', 'obj_reflexive', 'obj_anim',
#        'obj_def', 'obj_num', 'info_verbroot', 'verbid', 'construction',
#        'sub_affected', 'sub_affect2', 'vb_binyan', 'vb_passive', 'vb_particip',
#        'vb_parse', 'gc_sgpl', 'gc_sameclseq', 'gc_samesame', 'gc_parclseq',
#        'gc_parsame', 'info_gcorder', 'gc', 'gc_end', 'gc_def', 'gc_add',
#        'gc_proper', 'gc_anim', 'gc_complex', 'gc_prep', 'source', 'era',
#        'soc_oral', 'soc_north', 'gc2', 'book2', 'vb_aspect', 'obj_def2',
#        'gc_samesame2', 'gc_parsame2', 'verse', 'gc3binary', 'unique'],
#       dtype='object')

# %%
set(df_1.gc_proper)
# Out:
# {'common noun', 'pronoun', 'proper noun'}

# %%
set(df_1[df_1.info_means == "thither"].info_gcorder)
# Out:
# {'', 'a', 'b', 'c', 'd'}

# %%
df_m.head(2)
# Out:
#         id    book info_refer  info_reads info_means   texttype  \
# 316  315.0  exodus   Ex 01:01  mişrayma:h   to Egypt  narrative
# 317  316.0  exodus   Ex 01:19     ?alehen    to them   dialogue
#
#          syn_vbinit        syn_gcb4vb syn_realis syn_affneg sub_explicit  \
# 316  verb not first  GC not before vb     realis     affirm     explicit
# 317      verb first  GC not before vb   irrealis     affirm     explicit
#
#                      sub_anim      sub_def          sub_num   obj_reflexive  \
# 316  animate/extended animate  definite NP       plural/all  not applicable
# 317  animate/extended animate  definite NP  sg/distributive  not applicable
#
#     obj_anim obj_def obj_num info_verbroot  verbid construction  \
# 316                           b.w.? "come"     0.0   Intrans MC
# 317                           b.w.? "come"     0.0   Intrans MC
#
#                   sub_affected                sub_affect2 vb_binyan  \
# 316                   affected                   affected         G
# 317  incompletely aff (irreal)  incompletely aff (irreal)         G
#
#       vb_passive      vb_particip    vb_parse gc_sgpl gc_sameclseq  \
# 316  not passive  one participant  participle      sg           no
# 317  not passive  one participant   imperfect      pl           no
#
#     gc_samesame gc_parclseq gc_parsame info_gcorder    gc  \
# 316                      no                           hey
# 317                      no                          prep
#
#                         gc_end    gc_def       gc_add    gc_proper    gc_anim  \
# 316                  consonant  definite  no adjuncts  proper noun  inanimate
# 317  blocked - poss pro suffix  definite  no adjuncts      pronoun    animate
#
#     gc_complex  gc_prep       source           era        soc_oral soc_north  \
# 316     simple  no prep     Priestly  transitional  more oral like   not yet
# 317     simple      ?el  other non-P           CBH  more oral like   not yet
#
#                         gc2   book2     vb_aspect obj_def2 gc_samesame2  \
# 316                     hey  exodus  imperfective
# 317  prep or prep plus prep  exodus  imperfective
#
#     gc_parsame2  verse  gc3binary                    unique
# 316              prose          0  unique or representative
# 317              prose          1  unique or representative

# %%
df_p.head(2)
# Out:
#    verb_id   lex scroll    book  chapter  verse_num gcons_verb  \
# 0   212418  BW>[     MT  Isaiah        1         23       JBW>
# 2   212564  NHR[     MT  Isaiah        2          2       NHRW
#
#                                          gcons_verse sign_info stem tense  \
# 0  FRJK SWRRJM W XBRJ GNBJM KLW >HB CXD W RDP CLM...            qal  impf
# 2  W HJH B >XRJT H JMJM NKWN JHJH HR BJT JHWH B R...            qal  perf
#
#                 gcons_clause    subject complement cmpl_lex  \
# 0  W RJB >LMNH L> JBW> >LJHM  RJB >LMNH      >LJHM       >L
# 2      W NHRW >LJW KL H GWJM  KL H GWJM       >LJW       >L
#
#        cmpl_translation dir_he cmpl_constr cmpl_nt cmpl_anim cmpl_det  \
# 0               to them    0.0        prep    prps      anim      det
# 2  to it (the mountain)    0.0        prep    prps    inanim      det
#
#   cmpl_indiv cmpl_complex motion_type spatial_arg_type preposition_1  \
# 0       prsf       simple     fictive             goal            >L
# 2       prsf       simple     factive             goal            >L
#
#   preposition_2 preposition_3 preposition_4  \
# 0
# 2
#
#                                             comments reconstructed_verse
# 0  the cause of the widow does not come to them, ...
# 2

# %%
print("Dataset Medill (Exodus, Deuteronomy, Isaiah) length: ", len(df_m))
print("Dataset Perez (Exodus, Deuteronomy, Isaiah) length:", len(df_p))
# Out:
# Dataset Medill (Exodus, Deuteronomy, Isaiah) length:  364
# Dataset Perez (Exodus, Deuteronomy, Isaiah) length: 412

# %%
# Add comparing columns to df_m: gc_def2
set(df_m.gc_def)
# Out:
# {'definite', 'not definite'}

# %%
# Create a mapping dictionary

mapping = {
    'definite': 'det',
    'not definite': 'und',
}

# Create the new column 'construction' using the map function
df_m['gc_def2'] = df_m['gc_def'].map(mapping)

# check the column gc_def2 and gc_def

print(df_m.gc_def.value_counts())
print(df_m.gc_def2.value_counts())
# Out:
# definite        296
# not definite     68
# Name: gc_def, dtype: int64
# det    296
# und     68
# Name: gc_def2, dtype: int64

# %%
print(df_p.cmpl_det.value_counts())
# Out:
# det    391
# und     21
# Name: cmpl_det, dtype: int64

# %%
# Create necessary columns to compare line by line

# %%
set(df_m.book)
# Out:
# {'deuteronomy', 'exodus', 'isaiah'}

# %%
# Dictionary for mapping

mapping_book = {
    'deuteronomy': 'Deuteronomy',
    'exodus': 'Exodus',
    'isaiah': 'Isaiah',
}

# Create the new column 'construction' using the map function
df_m['book'] = df_m['book'].map(mapping_book)

# %%
# Create the columns chapter and verse from info_refer

def extract_chapter_verse(info_refer):
    match = re.match(r'\w+\s(\d+):(\d+)', info_refer)
    if match:
        return int(match.group(1)), int(match.group(2))
    return None, None

# Apply the function to create new columns
df_m['chapter'], df_m['verse_num'] = zip(*df_m['info_refer'].apply(extract_chapter_verse))

# Create a list of columns in the desired order
desired_columns = ['id', 'book', 'chapter', 'verse_num'] + [col for col in df_m.columns if col not in ['id','book', 'chapter', 'verse_num']]

# Reorder the dataframe columns
df_m = df_m[desired_columns]

# Display the reordered dataframe
df_m.head(5)
# Out:
#         id    book  chapter  verse_num info_refer    info_reads  \
# 316  315.0  Exodus        1          1   Ex 01:01    mişrayma:h
# 317  316.0  Exodus        1         19   Ex 01:19       ?alehen
# 318  317.0  Exodus        1         22   Ex 01:22     hay?ora:h
# 319  318.0  Exodus        2         10   Ex 02:10  le-bat par'o
# 320  319.0  Exodus        2         11   Ex 02:11    ?el ?ehayv
#
#           info_means   texttype      syn_vbinit        syn_gcb4vb syn_realis  \
# 316         to Egypt  narrative  verb not first  GC not before vb     realis
# 317          to them   dialogue      verb first  GC not before vb   irrealis
# 318      to the Nile   dialogue  verb not first      GC before vb   irrealis
# 319  to P's daughter  narrative      verb first  GC not before vb     realis
# 320  to his brothers  narrative      verb first  GC not before vb     realis
#
#     syn_affneg  sub_explicit                  sub_anim       sub_def  \
# 316     affirm      explicit  animate/extended animate   definite NP
# 317     affirm      explicit  animate/extended animate   definite NP
# 318     affirm  not explicit  animate/extended animate  not explicit
# 319     affirm  not explicit  animate/extended animate  not explicit
# 320     affirm  not explicit  animate/extended animate  not explicit
#
#              sub_num   obj_reflexive                  obj_anim      obj_def  \
# 316       plural/all  not applicable
# 317  sg/distributive  not applicable
# 318       plural/all   not reflexive  animate/extended animate  definite NP
# 319  sg/distributive   not reflexive  animate/extended animate      pronoun
# 320  sg/distributive  not applicable
#
#              obj_num        info_verbroot  verbid            construction  \
# 316                          b.w.? "come"     0.0              Intrans MC
# 317                          b.w.? "come"     0.0              Intrans MC
# 318  sg/distributive       sh.l.k "throw"    67.0           Caused Motion
# 319  sg/distributive         b.w.? "come"     0.0  Leading (non-coercive)
# 320                   y.ts.? "went forth"    77.0              Intrans MC
#
#                   sub_affected                sub_affect2 vb_binyan  \
# 316                   affected                   affected         G
# 317  incompletely aff (irreal)  incompletely aff (irreal)         G
# 318  incompletely aff (irreal)  incompletely aff (irreal)         C
# 319                   affected                   affected         C
# 320                   affected                   affected         G
#
#       vb_passive      vb_particip        vb_parse gc_sgpl gc_sameclseq  \
# 316  not passive  one participant      participle      sg           no
# 317  not passive  one participant       imperfect      pl           no
# 318  not passive    more than one       imperfect      sg           no
# 319  not passive    more than one  pret wayyiqtol      sg           no
# 320  not passive  one participant  pret wayyiqtol      pl           no
#
#     gc_samesame gc_parclseq gc_parsame info_gcorder    gc  \
# 316                      no                           hey
# 317                      no                          prep
# 318                      no                           hey
# 319                      no                          prep
# 320                      no                          prep
#
#                         gc_end    gc_def       gc_add    gc_proper    gc_anim  \
# 316                  consonant  definite  no adjuncts  proper noun  inanimate
# 317  blocked - poss pro suffix  definite  no adjuncts      pronoun    animate
# 318                  consonant  definite  no adjuncts  common noun  inanimate
# 319                  consonant  definite  no adjuncts  common noun    animate
# 320  blocked - poss pro suffix  definite  no adjuncts  common noun    animate
#
#     gc_complex  gc_prep       source           era        soc_oral soc_north  \
# 316     simple  no prep     Priestly  transitional  more oral like   not yet
# 317     simple      ?el  other non-P           CBH  more oral like   not yet
# 318     simple  no prep  other non-P           CBH  more oral like   not yet
# 319    complex        l  other non-P           CBH  more oral like   not yet
# 320    complex      ?el  other non-P           CBH  more oral like   not yet
#
#                         gc2   book2     vb_aspect obj_def2 gc_samesame2  \
# 316                     hey  exodus  imperfective
# 317  prep or prep plus prep  exodus  imperfective
# 318                     hey  exodus  imperfective   def NP
# 319  prep or prep plus prep  exodus    perfective  pronoun
# 320  prep or prep plus prep  exodus    perfective
#
#     gc_parsame2  verse  gc3binary                    unique gc_def2
# 316              prose          0  unique or representative     det
# 317              prose          1  unique or representative     det
# 318              prose          0  unique or representative     det
# 319              prose          1  unique or representative     det
# 320              prose          1  unique or representative     det

# %%
# Comparing definiteness annotations

# Merge the DataFrames on 'book', 'chapter', and 'verse'
merged_df = pd.merge(df_m, df_p, on=['book', 'chapter', 'verse_num'], suffixes=('_m', '_p'))

# Compare the values in 'gc_det2' and 'cmpl_det'
merged_df['det_match'] = merged_df['gc_def2'] == merged_df['cmpl_det']

# Display the rows where the values differ
differences = merged_df[merged_df['det_match'] == False].reset_index()

# Adjust display options
# Display all rows
pd.set_option('display.max_rows', None)

# Display the full content of each cell
pd.set_option('display.max_colwidth', None)

# Print the differences
differences[['book', 'chapter', 'verse_num', 'gc_def2', 'cmpl_det', "info_reads", "info_means", "cmpl_translation", "cmpl_lex"]]
# Out:
#            book  chapter  verse_num gc_def2 cmpl_det  \
# 0        Exodus        3          8     und      det
# 1        Exodus        3          8     und      det
# 2        Exodus        3         17     und      det
# 3        Exodus        9         23     und      det
# 4        Exodus        9         33     und      det
# 5        Exodus       10         26     und      det
# 6        Exodus       14         20     und      det
# 7        Exodus       16         35     und      det
# 8        Exodus       16         35     det      und
# 9        Exodus       21         13     und      det
# 10       Exodus       21         33     und      det
# 11       Exodus       26         33     und      det
# 12       Exodus       28         43     und      det
# 13       Exodus       28         43     und      det
# 14       Exodus       29         30     und      det
# 15       Exodus       30         20     und      det
# 16       Exodus       30         20     und      det
# 17       Exodus       33          7     und      det
# 18       Exodus       40         32     und      det
# 19       Exodus       40         32     und      det
# 20       Exodus       40         35     und      det
# 21  Deuteronomy        1         37     und      det
# 22  Deuteronomy        1         38     und      det
# 23  Deuteronomy        1         39     und      det
# 24  Deuteronomy        2         27     und      det
# 25  Deuteronomy        2         27     und      det
# 26  Deuteronomy        3         21     und      det
# 27  Deuteronomy        4          5     und      det
# 28  Deuteronomy        4         14     und      det
# 29  Deuteronomy        4         26     und      det
# 30  Deuteronomy        4         42     und      det
# 31  Deuteronomy        4         42     und      det
# 32  Deuteronomy        6          1     und      det
# 33  Deuteronomy        7          1     und      det
# 34  Deuteronomy        7          1     und      det
# 35  Deuteronomy       11          8     und      det
# 36  Deuteronomy       11         10     und      det
# 37  Deuteronomy       11         11     und      det
# 38  Deuteronomy       11         29     und      det
# 39  Deuteronomy       11         29     und      det
# 40  Deuteronomy       12          5     und      det
# 41  Deuteronomy       12          6     und      det
# 42  Deuteronomy       12         11     und      det
# 43  Deuteronomy       12         29     und      det
# 44  Deuteronomy       19          3     und      det
# 45  Deuteronomy       19          4     und      det
# 46  Deuteronomy       21          4     det      und
# 47  Deuteronomy       23         13     und      det
# 48  Deuteronomy       23         13     und      det
# 49  Deuteronomy       23         21     und      det
# 50  Deuteronomy       28         21     und      det
# 51  Deuteronomy       28         36     det      und
# 52  Deuteronomy       28         63     und      det
# 53  Deuteronomy       30          1     und      det
# 54  Deuteronomy       30         16     und      det
# 55  Deuteronomy       30         18     und      det
# 56  Deuteronomy       31         13     und      det
# 57  Deuteronomy       31         16     und      det
# 58  Deuteronomy       32         47     und      det
# 59  Deuteronomy       32         50     und      det
# 60  Deuteronomy       32         52     und      det
# 61  Deuteronomy       32         52     und      det
# 62  Deuteronomy       34          4     und      det
# 63       Isaiah        7         24     und      det
# 64       Isaiah        7         25     und      det
# 65       Isaiah       20          6     und      det
#
#                       info_reads                             info_means  \
# 0     ?el ?erets tobah varaxabah               to a good and broad land
# 1   ?el ?erets zbat xalab devash  to a land flowing with milk and honey
# 2   ?el ?erets zbat xalab devash  to a land flowing with milk and honey
# 3                        ?arşa:h                              to ground
# 4                        ?arşa:h                              to ground
# 5                       ša:mma:h                                thither
# 6                        ?el zeh                                to that
# 7            ?el ?erets noshabet                     to a liveable land
# 8      ?el qetsey ?erets kenaaan    to the border of the land of Canaan
# 9                       ša:mma:h                                thither
# 10                      ša:mma:h                                thither
# 11                      ša:mma:h                                thither
# 12               ?el ?ohel mo'ed                 to the tent of meeting
# 13               ?el ?ohel mo'ed                 to the tent of meeting
# 14               ?el ?ohel mo'ed                 to the tent of meeting
# 15               ?el ?ohel mo'ed                 to the tent of meeting
# 16               ?el ?ohel mo'ed                 to the tent of meeting
# 17               ?el ?ohel mo'ed                 to the tent of meeting
# 18               ?el ?ohel mo'ed                 to the tent of meeting
# 19               ?el ?ohel mo'ed                 to the tent of meeting
# 20               ?el ?ohel mo'ed                 to the tent of meeting
# 21                          sham                                thither
# 22                      ša:mma:h                                thither
# 23                      ša:mma:h                                thither
# 24                         yamin                           to the right
# 25                        sem?ol                            to the left
# 26                      ša:mma:h                                thither
# 27                      ša:mma:h                                thither
# 28                      ša:mma:h                                thither
# 29                      ša:mma:h                                thither
# 30                      ša:mma:h                                thither
# 31                      ša:mma:h                                thither
# 32                      ša:mma:h                                thither
# 33                      ša:mma:h                                thither
# 34                      ša:mma:h                                thither
# 35                      ša:mma:h                                thither
# 36                      ša:mma:h                                thither
# 37                      ša:mma:h                                thither
# 38                      ša:mma:h                                thither
# 39                      ša:mma:h                                thither
# 40                      ša:mma:h                                thither
# 41                      ša:mma:h                                thither
# 42                      ša:mma:h                                thither
# 43                      ša:mma:h                                thither
# 44                      ša:mma:h                                thither
# 45                      ša:mma:h                                thither
# 46              ?el naxal ?eitan                       to a strong wadi
# 47                      ša:mma:h                                thither
# 48                          xuts                                outside
# 49                      ša:mma:h                                thither
# 50                      ša:mma:h                                thither
# 51                       ?el goy                            to a nation
# 52                      ša:mma:h                                thither
# 53                      ša:mma:h                                thither
# 54                      ša:mma:h                                thither
# 55                      ša:mma:h                                thither
# 56                      ša:mma:h                                thither
# 57                      ša:mma:h                                thither
# 58                      ša:mma:h                                thither
# 59                      ša:mma:h                                thither
# 60                      ša:mma:h                                thither
# 61                      ša:mma:h                                thither
# 62                      ša:mma:h                                thither
# 63                      ša:mma:h                                thither
# 64                      ša:mma:h                                thither
# 65                          sham                                thither
#
#                                                                                                                                                                               cmpl_translation  \
# 0   to the good and broad land, to the land flowing with milk and honey, to the place of the Canaanites and the Hittites and the Amorites and the Perizzites and the Hivites and the Jebusites
# 1   to the good and broad land, to the land flowing with milk and honey, to the place of the Canaanites and the Hittites and the Amorites and the Perizzites and the Hivites and the Jebusites
# 2                                                     to the land of the Canaanites and the Hittites and the Amorites and the Perizzites and the Jebusites, a land flowing with milk and honey
# 3                                                                                                                                                                             toward the earth
# 4                                                                                                                                                                          toward/on the earth
# 5                                                                                                                                                                                        there
# 6                                                                                                                                                                              to this (place)
# 7                                                                                                                                                          to the border of the land of Canaan
# 8                                                                                                                                                                         to an inhabited land
# 9                                                                                                                                                                                        there
# 10                                                                                                                                                                                       there
# 11                                                                                                                                                                                       there
# 12                                                                                                                                                               into the tent of the assembly
# 13                                                                                                                                                                                to the altar
# 14                                                                                                                                                                 to the tent of the assembly
# 15                                                                                                                                                               into the tent of the assembly
# 16                                                                                                                                                                                to the altar
# 17                                                                                                                                                                 to the tent of the assembly
# 18                                                                                                                                                               into the tent of the assembly
# 19                                                                                                                                                                                to the altar
# 20                                                                                                                                                               into the tent of the assembly
# 21                                                                                                                                                                                       there
# 22                                                                                                                                                                                       there
# 23                                                                                                                                                                                       there
# 24                                                                                                                                                               to the right hand or the left
# 25                                                                                                                                                               to the right hand or the left
# 26                                                                                                                                                                                       there
# 27                                                                                                                                                                                       there
# 28                                                                                                                                                                                       there
# 29                                                                                                                                                                                       there
# 30                                                                                                                                                                                       there
# 31                                                                                                                                                                   to one among these cities
# 32                                                                                                                                                                                       there
# 33                                                                                                                                                                               into the land
# 34                                                                                                                                                                                       there
# 35                                                                                                                                                                                       there
# 36                                                                                                                                                                                       there
# 37                                                                                                                                                                                       there
# 38                                                                                                                                                                               into the land
# 39                                                                                                                                                                                       there
# 40                                                                                                                                                                                       there
# 41                                                                                                                                                                                      there
# 42                                                                                                                                                                                       there
# 43                                                                                                                                                                                       there
# 44                                                                                                                                                                                       there
# 45                                                                                                                                                                                       there
# 46                                                                                                                                                              to a valley with running water
# 47                                                                                                                                                                                       there
# 48                                                                                                                                                                                       there
# 49                                                                                                                                                                                       there
# 50                                                                                                                                                                                       there
# 51                                                                                                                                                                                 to a nation
# 52                                                                                                                                                                                       there
# 53                                                                                                                                                                                to your mind
# 54                                                                                                                                                                                       there
# 55                                                                                                                                                                                       there
# 56                                                                                                                                                                                       there
# 57                                                                                                                                                                                       there
# 58                                                                                                                                                                                       there
# 59                                                                                                                                                                                       there
# 60                                                                                                                                                                                       there
# 61                                                                                                                                                                               into the land
# 62                                                                                                                                                                                       there
# 63                                                                                                                                                                                       there
# 64                                                                                                                                                                                       there
# 65                                                                                                                                                                                       there
#
#                                                                                                            cmpl_lex
# 0   >L >RY/ VWB/ W RXB/ >L >RY/ ZWB[ XLB/ W DBC/ >L MQWM/ H KN<NJ/ W H XTJ/ W H >MRJ/ W H PRZJ/ W H XWJ/ W H JBWSJ/
# 1   >L >RY/ VWB/ W RXB/ >L >RY/ ZWB[ XLB/ W DBC/ >L MQWM/ H KN<NJ/ W H XTJ/ W H >MRJ/ W H PRZJ/ W H XWJ/ W H JBWSJ/
# 2                        >L >RY/ H KN<NJ/ W H XTJ/ W H >MRJ/ W H PRZJ/ W H XWJ/ W H JBWSJ/ >L >RY/ ZWB[ XLB/ W DBC/
# 3                                                                                                              >RY/
# 4                                                                                                              >RY/
# 5                                                                                                                CM
# 6                                                                                                             >L ZH
# 7                                                                                               >L QYH=/ >RY/ KN<N/
# 8                                                                                                      >L >RY/ JCB[
# 9                                                                                                                CM
# 10                                                                                                               CM
# 11                                                                                                               CM
# 12                                                                                                    >L >HL/ MW<D/
# 13                                                                                                       >L H MZBX/
# 14                                                                                                    >L >HL/ MW<D/
# 15                                                                                                    >L >HL/ MW<D/
# 16                                                                                                       >L H MZBX/
# 17                                                                                                    >L >HL/ MW<D/
# 18                                                                                                    >L >HL/ MW<D/
# 19                                                                                                       >L H MZBX/
# 20                                                                                                    >L >HL/ MW<D/
# 21                                                                                                               CM
# 22                                                                                                               CM
# 23                                                                                                               CM
# 24                                                                                                    JMJN/ W FM>L/
# 25                                                                                                    JMJN/ W FM>L/
# 26                                                                                                               CM
# 27                                                                                                               CM
# 28                                                                                                               CM
# 29                                                                                                               CM
# 30                                                                                                               CM
# 31                                                                                        >L >XD/ MN H <JR/ H >L===
# 32                                                                                                               CM
# 33                                                                                                        >L H >RY/
# 34                                                                                                               CM
# 35                                                                                                               CM
# 36                                                                                                               CM
# 37                                                                                                               CM
# 38                                                                                                        >L H >RY/
# 39                                                                                                               CM
# 40                                                                                                               CM
# 41                                                                                                               CM
# 42                                                                                                               CM
# 43                                                                                                               CM
# 44                                                                                                               CM
# 45                                                                                                               CM
# 46                                                                                                    >L NXL/ >JTN/
# 47                                                                                                               CM
# 48                                                                                                               CM
# 49                                                                                                               CM
# 50                                                                                                               CM
# 51                                                                                                          >L GWJ/
# 52                                                                                                               CM
# 53                                                                                                          >L LBB/
# 54                                                                                                               CM
# 55                                                                                                               CM
# 56                                                                                                               CM
# 57                                                                                                               CM
# 58                                                                                                               CM
# 59                                                                                                               CM
# 60                                                                                                               CM
# 61                                                                                                        >L H >RY/
# 62                                                                                                               CM
# 63                                                                                                               CM
# 64                                                                                                               CM
# 65                                                                                                               CM
