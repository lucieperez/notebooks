# %%
import pandas as pd

# %%
df = pd.read_excel("data/Medill 2020 Hebrew Goal Data.xls")

# %%
df[df.info_means == "thither"]
# Out:
#           id      book info_refer info_reads info_means   texttype  \
# 40      41.0   genesis  Gen 14:10   ša:mma:h    thither  narrative
# 72      72.0   genesis  Gen 19:20   ša:mma:h    thither   dialogue
# 73      73.0   genesis  Gen 19:20   ša:mma:h    thither   dialogue
# 74      74.0   genesis  Gen 19:22   ša:mma:h    thither   dialogue
# 75      75.0   genesis  Gen 19:22   ša:mma:h    thither   dialogue
# ...      ...       ...        ...        ...        ...        ...
# 2704  2636.0   qohelet  Qoh 09:10   ša:mma:h    thither       n/sp
# 2758  2690.0    daniel  Dan 09:07       sham    thither       n/sp
# 2821  2748.0  nehemiah  Neh 04:14   ša:mma:h    thither   dialogue
# 2855  2781.0  nehemiah  Neh 13:09       sham    thither  narrative
# 2931  2853.0     2 chr  2Ch 01:06       sham    thither  narrative
#
#           syn_vbinit        syn_gcb4vb syn_realis syn_affneg  ... soc_north  \
# 40        verb first  GC not before vb     realis     affirm  ...   not yet
# 72    verb not first  GC not before vb   irrealis     affirm  ...   not yet
# 73        verb first  GC not before vb   irrealis     affirm  ...   not yet
# 74    verb not first  GC not before vb   irrealis     affirm  ...   not yet
# 75        verb first  GC not before vb   irrealis     affirm  ...   not yet
# ...              ...               ...        ...        ...  ...       ...
# 2704  verb not first  GC not before vb   irrealis     affirm  ...       NaN
# 2758      verb first  GC not before vb     realis     affirm  ...       NaN
# 2821      verb first  GC not before vb   irrealis     affirm  ...       NaN
# 2855      verb first  GC not before vb     realis     affirm  ...       NaN
# 2931      verb first  GC not before vb     realis     affirm  ...       NaN
#
#                    gc2             book2     vb_aspect obj_def2 gc_samesame2  \
# 40                 hey           genesis    perfective      NaN          NaN
# 72                 hey           genesis  imperfective      NaN          NaN
# 73                 hey           genesis  imperfective      NaN          NaN
# 74                 hey           genesis  imperfective      NaN          NaN
# 75                 hey           genesis  imperfective      NaN          NaN
# ...                ...               ...           ...      ...          ...
# 2704               hey     miscellaneous  imperfective      NaN          NaN
# 2758  acc of direction            daniel    perfective  pronoun          NaN
# 2821               hey          nehemiah  imperfective      NaN          NaN
# 2855  acc of direction          nehemiah    perfective   def NP          NaN
# 2931  acc of direction  1 chr or all chr    perfective      NaN          NaN
#
#      gc_parsame2  verse gc3binary                    unique
# 40           NaN  prose         0  unique or representative
# 72           NaN  prose         0  unique or representative
# 73          same  prose         0  unique or representative
# 74           NaN  prose         0  unique or representative
# 75          same  prose         0  unique or representative
# ...          ...    ...       ...                       ...
# 2704         NaN  prose         0  unique or representative
# 2758         NaN  prose         0  unique or representative
# 2821         NaN  prose         0  unique or representative
# 2855         NaN  prose         0  unique or representative
# 2931         NaN  prose         0  unique or representative
#
# [133 rows x 54 columns]

# %%
df.columns
# Out:
# Index(['id', 'book', 'info_refer', 'info_reads', 'info_means', 'texttype',
#        'syn_vbinit', 'syn_gcb4vb', 'syn_realis', 'syn_affneg', 'sub_explicit',
#        'sub_anim', 'sub_def', 'sub_num', 'obj_reflexive', 'obj_anim',
#        'obj_def', 'obj_num', 'info_verbroot', 'verbid', 'construction',
#        'sub_affected', 'sub_affect2', 'vb_binyan', 'vb_passive', 'vb_particip',
#        'vb_parse', 'gc_sgpl', 'gc_sameclseq', 'gc_samesame', 'gc_parclseq',
#        'gc_parsame', 'info_gcorder', 'gc', 'gc_end', 'gc_def', 'gc_add',
#        'gc_proper', 'gc_anim', 'gc_complex', 'gc_prep', 'source', 'era',
#        'soc_oral', 'soc_north', 'gc2', 'book2', 'vb_aspect', 'obj_def2',
#        'gc_samesame2', 'gc_parsame2', 'verse', 'gc3binary', 'unique'],
#       dtype='object')

# %%
set(df.info_verbroot)
# Out:
# {'.b.r "cross over"',
#  '.l.h "go up"',
#  '.r.h "empty"',
#  '.t.q "move"',
#  '.w.p "fly"',
#  '?.s.p "gather"',
#  'b.d.l "separate"',
#  'b.q.\' "break thru"',
#  'b.r.x "flee"',
#  'b.w.? "come"',
#  'd.b.q "cling"',
#  'd.r.k "tread"',
#  'd.x.p "hurry"',
#  'g.h.r "stretch out"',
#  'g.l.h "carry to exile"',
#  'g.l.l "roll"',
#  'h.l.k "go"',
#  'h.p.k "turn"',
#  'k.n.s "gather"',
#  'l.q.t "gather"',
#  'l.q.x "take"',
#  'l.x.ts "press"',
#  'm.h.r "hurry"',
#  'm.l.t "escape"',
#  'm.s.k "pull"',
#  'm.ts.h "drain"',
#  'm.w.sh "depart"',
#  'm.x.h "wipe off"',
#  'n.d.x "banish"',
#  'n.g.\' "touch"',
#  'n.g.r "pour"',
#  'n.g.sh "approach"',
#  'n.g.x "push"',
#  'n.h.g "drive"',
#  'n.k.h "strike"',
#  'n.p.l "fall"',
#  'n.s.\' "set out"',
#  'n.s.? "carry"',
#  'n.s.g "reach"',
#  'n.t.h "stretch out"',
#  'n.t.k "pour out"',
#  'n.t.q "tear away"',
#  'n.w.s "flee"',
#  'n.x.h "lead"',
#  'n.z.h "sprinkle"',
#  'p.n.h "turn"',
#  'p.r.sh "scatter"',
#  'p.r.ts "spread"',
#  'p.sh.t "raid"',
#  'p.w.ts "scatter"',
#  'q.b.ts "gather"',
#  'q.h.l "assemble"',
#  'q.l.\' "sling"',
#  'q.r.b "approach"',
#  'q.w.h "gather"',
#  'q.y.? "vomit"',
#  'r.d.h "scrape"',
#  'r.d.p "pursue"',
#  'r.k.b "drive"',
#  'r.w.m "be high"',
#  'r.w.ts "run"',
#  's.b.b "go around"',
#  's.w.r "turn"',
#  's.x.b "drag"',
#  'sh.b.h "take captive"',
#  'sh.l.k "throw"',
#  'sh.l.x "send"',
#  'sh.p.k "pour"',
#  'sh.w.b "return"',
#  'sh.x.t "press"',
#  't.q.\' "thrust"',
#  't.w.l "hurl"',
#  'ts.n.x "go down"',
#  'y.\'.d "meet"',
#  'y.r.d "go down"',
#  'y.r.h "shoot"',
#  'y.ts.? "went forth"',
#  'y.ts.q "pour out"',
#  'z.r.h "scatter"',
#  'z.r.q "toss"'}

# %%
columns_to_drop = ['id', 'texttype',
       'syn_vbinit', 'syn_gcb4vb', 'syn_realis', 'syn_affneg', 'sub_explicit',
       'sub_anim', 'sub_def', 'sub_num', 'obj_reflexive', 'obj_anim',
       'obj_def', 'obj_num', 'verbid', 'construction',
       'sub_affected', 'sub_affect2', 'vb_binyan', 'vb_passive', 'vb_particip',
       'vb_parse', 'gc_sgpl', 'gc_sameclseq', 'gc_samesame', 'gc_parclseq',
       'gc_parsame', 'info_gcorder','gc_end', 'gc_add',
       'gc_proper', 'gc_complex', 'gc_prep', 'source', 'era',
       'soc_oral', 'soc_north', 'gc2', 'book2', 'vb_aspect', 'obj_def2',
       'gc_samesame2', 'gc_parsame2', 'verse', 'gc3binary', 'unique']

# %%
new_df = df.drop(columns=columns_to_drop)

new_df
# Out:
#          book info_refer       info_reads    info_means  \
# 0     genesis  Gen 01:09  ?el ma:qom exad  to one place
# 1     genesis  Gen 02:19      ?el ha?adam    to the man
# 2     genesis  Gen 02:22      ?el ha?adam    to the man
# 3     genesis  Gen 04:03          le-YHWH       to YHWH
# 4     genesis  Gen 06:18     ?el hate:bah    to the ark
# ...       ...        ...              ...           ...
# 3120    2 chr  2Ch 36:07         le-babel    to Babylon
# 3121    2 chr  2Ch 36:10         babela:h    to Babylon
# 3122    2 chr  2Ch 36:17           alehem       to them
# 3123    2 chr  2Ch 36:18            babel    to Babylon
# 3124    2 chr  2Ch 36:20        ?el babel    to Babylon
#
#                info_verbroot                gc        gc_def    gc_anim
# 0             q.w.h "gather"              prep  not definite  inanimate
# 1               b.w.? "come"              prep      definite    animate
# 2               b.w.? "come"              prep      definite    animate
# 3               b.w.? "come"              prep      definite    animate
# 4               b.w.? "come"              prep      definite  inanimate
# ...                      ...               ...           ...        ...
# 3120            b.w.? "come"              prep      definite  inanimate
# 3121            b.w.? "come"               hey      definite  inanimate
# 3122            .l.h "go up"              prep      definite    animate
# 3123            b.w.? "come"  acc of direction      definite  inanimate
# 3124  g.l.h "carry to exile"              prep      definite  inanimate
#
# [3125 rows x 8 columns]

# %%
set(new_df[new_df.info_reads == "ša:mma:h"].gc_def)
# Out:
# {'not definite'}

# %%
set(new_df[new_df.info_means == "thither"].gc_def)
# Out:
# {'not definite'}

# %%
set(new_df.gc_def)
# Out:
# {'definite', 'not definite'}

# %%
new_df[new_df.book == "isaiah"]
# Out:
#         book info_refer                             info_reads  \
# 2185  isaiah  Isa 06:06                                  ?elai
# 2186  isaiah  Isa 07:01                            yerushalaim
# 2187  isaiah  Isa 07:03  ?el qatse ta'alat habrekah ha'elyonah
# 2188  isaiah  Isa 07:03                ?el mesilat sadeh kobes
# 2189  isaiah  Isa 07:06                              bi-yhudah
# 2190  isaiah  Isa 07:24                               ša:mma:h
# 2191  isaiah  Isa 07:25                               ša:mma:h
# 2192  isaiah  Isa 08:07                                 alehem
# 2193  isaiah  Isa 14:02                            ?el meqomam
# 2194  isaiah  Isa 16:12                           ?el miqdasho
# 2195  isaiah  Isa 19:23                           bi-mitsrayim
# 2196  isaiah  Isa 20:01                             ?ašdo:da:h
# 2197  isaiah  Isa 20:06                                   sham
# 2198  isaiah  Isa 22:15                      ?el hasoken hazeh
# 2199  isaiah  Isa 22:15                             al shebna?
# 2200  isaiah  Isa 27:13                    be-?erets mitsrayim
# 2201  isaiah  Isa 30:29                            be-har YHWH
# 2202  isaiah  Isa 30:29                       ?el tsur yisrael
# 2203  isaiah  Isa 36:01                     al kol are yehudah
# 2204  isaiah  Isa 36:02                  ?el hamelek hezqiyahu
# 2205  isaiah  Isa 36:02                        yeru:ša:lamma:h
# 2206  isaiah  Isa 36:03                                 ?elayv
# 2207  isaiah  Isa 36:10                     al ha?arets hazo?t
# 2208  isaiah  Isa 36:10                    ?el ha?arets hazo?t
# 2209  isaiah  Isa 36:16                                  ?elai
# 2210  isaiah  Isa 36:17                             ?el ?erets
# 2211  isaiah  Isa 36:22                          ?el hezqiyahu
# 2212  isaiah  Isa 37:01                              beyt YHWH
# 2213  isaiah  Isa 37:02                          ?el yisa'yahu
# 2214  isaiah  Isa 37:05                          ?el yisa'yahu
# 2215  isaiah  Isa 37:07                             ?el ?artso
# 2216  isaiah  Isa 37:09                          ?el hezqiyahu
# 2217  isaiah  Isa 37:14                              beyt YHWH
# 2218  isaiah  Isa 37:33                       ?el ha'ir hazo?t
# 2219  isaiah  Isa 37:34                       ?el ha'ir hazo?t
# 2220  isaiah  Isa 37:38                         ?erets ?ararat
# 2221  isaiah  Isa 38:01                                 ?elayv
# 2222  isaiah  Isa 38:22                              beyt YHWH
# 2223  isaiah  Isa 39:01                          ?el hezqiyahu
# 2224  isaiah  Isa 39:03                                 ?eleka
# 2225  isaiah  Isa 39:03                                  ?elai
# 2226  isaiah  Isa 39:03                  ?el hamelek hezqiyahu
# 2227  isaiah  Isa 39:06                                  babel
# 2228  isaiah  Isa 52:04                              mitsrayim
# 2229  isaiah  Isa 66:19                            ?el hagoyim
# 2230  isaiah  Isa 66:20                          al har qodshi
# 2231  isaiah  Isa 66:20                              beyt YHWH
#
#                                     info_means        info_verbroot  \
# 2185                                     to me           .w.p "fly"
# 2186                      to/against Jerusalem         .l.h "go up"
# 2187  to the end of the path of the upper pool  y.ts.? "went forth"
# 2188         to the road to the fuller's field  y.ts.? "went forth"
# 2189                          to/against Judah         .l.h "go up"
# 2190                                   thither         b.w.? "come"
# 2191                                   thither         b.w.? "come"
# 2192                           to/against them         .l.h "go up"
# 2193                            to their place         b.w.? "come"
# 2194                          to his sanctuary         b.w.? "come"
# 2195                                into Egypt         b.w.? "come"
# 2196                                 to ashdod         b.w.? "come"
# 2197                                   thither         n.w.s "flee"
# 2198                           to this steward         b.w.? "come"
# 2199                                 to Shebna         b.w.? "come"
# 2200                    into the land of Egypt       n.d.x "banish"
# 2201                         to the mt of YHWH         b.w.? "come"
# 2202                     to the rock of Israel         b.w.? "come"
# 2203        to/against all the cities of Judah         .l.h "go up"
# 2204                          to king Hezekiah        sh.l.x "send"
# 2205                              to Jerusalem        sh.l.x "send"
# 2206                                    to him  y.ts.? "went forth"
# 2207                      to/against this land         .l.h "go up"
# 2208                              to this land         .l.h "go up"
# 2209                                     to me  y.ts.? "went forth"
# 2210                                 to a land         l.q.x "take"
# 2211                               to Hezekiah         b.w.? "come"
# 2212                      to the house of YHWH         b.w.? "come"
# 2213                                 to Isaiah        sh.l.x "send"
# 2214                                 to Isaiah         b.w.? "come"
# 2215                               to his land      sh.w.b "return"
# 2216                               to Hezekiah        sh.l.x "send"
# 2217                      to the house of YHWH         .l.h "go up"
# 2218                              to this city         b.w.? "come"
# 2219                              to this city         b.w.? "come"
# 2220                     to the land of Urartu       m.l.t "escape"
# 2221                                    to him         b.w.? "come"
# 2222                      to the house of YHWH         .l.h "go up"
# 2223                               to Hezekiah        sh.l.x "send"
# 2224                                    to you         b.w.? "come"
# 2225                                     to me         b.w.? "come"
# 2226                          to king Hezekiah         b.w.? "come"
# 2227                                to babylon        n.s.? "carry"
# 2228                                  to Egypt      y.r.d "go down"
# 2229                            to the nations        sh.l.x "send"
# 2230                             to my holy mt         b.w.? "come"
# 2231                      to the house of YHWH         b.w.? "come"
#
#                     gc        gc_def    gc_anim
# 2185              prep      definite    animate
# 2186  acc of direction      definite  inanimate
# 2187              prep      definite  inanimate
# 2188              prep  not definite  inanimate
# 2189              prep      definite  inanimate
# 2190               hey  not definite  inanimate
# 2191               hey  not definite  inanimate
# 2192              prep      definite    animate
# 2193              prep      definite  inanimate
# 2194              prep      definite  inanimate
# 2195              prep      definite  inanimate
# 2196               hey      definite  inanimate
# 2197  acc of direction  not definite  inanimate
# 2198              prep      definite    animate
# 2199              prep      definite    animate
# 2200              prep      definite  inanimate
# 2201              prep      definite  inanimate
# 2202              prep      definite  inanimate
# 2203              prep      definite  inanimate
# 2204              prep      definite    animate
# 2205               hey      definite  inanimate
# 2206              prep      definite    animate
# 2207              prep      definite  inanimate
# 2208              prep      definite  inanimate
# 2209              prep      definite    animate
# 2210              prep  not definite  inanimate
# 2211              prep      definite    animate
# 2212  acc of direction      definite  inanimate
# 2213              prep      definite    animate
# 2214              prep      definite    animate
# 2215              prep      definite  inanimate
# 2216              prep      definite    animate
# 2217  acc of direction      definite  inanimate
# 2218              prep      definite  inanimate
# 2219              prep      definite  inanimate
# 2220  acc of direction      definite  inanimate
# 2221              prep      definite    animate
# 2222  acc of direction      definite  inanimate
# 2223              prep      definite    animate
# 2224              prep      definite    animate
# 2225              prep      definite    animate
# 2226              prep      definite    animate
# 2227  acc of direction      definite  inanimate
# 2228  acc of direction      definite  inanimate
# 2229              prep      definite  inanimate
# 2230              prep      definite  inanimate
# 2231  acc of direction      definite  inanimate
