# %%
import pandas as pd

# %%
df = pd.read_excel("data/Medill 2020 Hebrew Goal Data.xls")

# %%
pd.set_option("display.max_rows", None)

# %%
df[df.info_means == "thither"]
# Out:
#           id      book info_refer info_reads info_means   texttype  \
# 40      41.0   genesis  Gen 14:10   ša:mma:h    thither  narrative
# 72      72.0   genesis  Gen 19:20   ša:mma:h    thither   dialogue
# 73      73.0   genesis  Gen 19:20   ša:mma:h    thither   dialogue
# 74      74.0   genesis  Gen 19:22   ša:mma:h    thither   dialogue
# 75      75.0   genesis  Gen 19:22   ša:mma:h    thither   dialogue
# ...      ...       ...        ...        ...        ...        ...
# 2704  2636.0   qohelet  Qoh 09:10   ša:mma:h    thither       n/sp
# 2758  2690.0    daniel  Dan 09:07       sham    thither       n/sp
# 2821  2748.0  nehemiah  Neh 04:14   ša:mma:h    thither   dialogue
# 2855  2781.0  nehemiah  Neh 13:09       sham    thither  narrative
# 2931  2853.0     2 chr  2Ch 01:06       sham    thither  narrative
#
#           syn_vbinit        syn_gcb4vb syn_realis syn_affneg  ... soc_north  \
# 40        verb first  GC not before vb     realis     affirm  ...   not yet
# 72    verb not first  GC not before vb   irrealis     affirm  ...   not yet
# 73        verb first  GC not before vb   irrealis     affirm  ...   not yet
# 74    verb not first  GC not before vb   irrealis     affirm  ...   not yet
# 75        verb first  GC not before vb   irrealis     affirm  ...   not yet
# ...              ...               ...        ...        ...  ...       ...
# 2704  verb not first  GC not before vb   irrealis     affirm  ...       NaN
# 2758      verb first  GC not before vb     realis     affirm  ...       NaN
# 2821      verb first  GC not before vb   irrealis     affirm  ...       NaN
# 2855      verb first  GC not before vb     realis     affirm  ...       NaN
# 2931      verb first  GC not before vb     realis     affirm  ...       NaN
#
#                    gc2             book2     vb_aspect obj_def2 gc_samesame2  \
# 40                 hey           genesis    perfective      NaN          NaN
# 72                 hey           genesis  imperfective      NaN          NaN
# 73                 hey           genesis  imperfective      NaN          NaN
# 74                 hey           genesis  imperfective      NaN          NaN
# 75                 hey           genesis  imperfective      NaN          NaN
# ...                ...               ...           ...      ...          ...
# 2704               hey     miscellaneous  imperfective      NaN          NaN
# 2758  acc of direction            daniel    perfective  pronoun          NaN
# 2821               hey          nehemiah  imperfective      NaN          NaN
# 2855  acc of direction          nehemiah    perfective   def NP          NaN
# 2931  acc of direction  1 chr or all chr    perfective      NaN          NaN
#
#      gc_parsame2  verse gc3binary                    unique
# 40           NaN  prose         0  unique or representative
# 72           NaN  prose         0  unique or representative
# 73          same  prose         0  unique or representative
# 74           NaN  prose         0  unique or representative
# 75          same  prose         0  unique or representative
# ...          ...    ...       ...                       ...
# 2704         NaN  prose         0  unique or representative
# 2758         NaN  prose         0  unique or representative
# 2821         NaN  prose         0  unique or representative
# 2855         NaN  prose         0  unique or representative
# 2931         NaN  prose         0  unique or representative
#
# [133 rows x 54 columns]

# %%
df.columns
# Out:
# Index(['id', 'book', 'info_refer', 'info_reads', 'info_means', 'texttype',
#        'syn_vbinit', 'syn_gcb4vb', 'syn_realis', 'syn_affneg', 'sub_explicit',
#        'sub_anim', 'sub_def', 'sub_num', 'obj_reflexive', 'obj_anim',
#        'obj_def', 'obj_num', 'info_verbroot', 'verbid', 'construction',
#        'sub_affected', 'sub_affect2', 'vb_binyan', 'vb_passive', 'vb_particip',
#        'vb_parse', 'gc_sgpl', 'gc_sameclseq', 'gc_samesame', 'gc_parclseq',
#        'gc_parsame', 'info_gcorder', 'gc', 'gc_end', 'gc_def', 'gc_add',
#        'gc_proper', 'gc_anim', 'gc_complex', 'gc_prep', 'source', 'era',
#        'soc_oral', 'soc_north', 'gc2', 'book2', 'vb_aspect', 'obj_def2',
#        'gc_samesame2', 'gc_parsame2', 'verse', 'gc3binary', 'unique'],
#       dtype='object')

# %%
set(df.info_verbroot)
# Out:
# {'.b.r "cross over"',
#  '.l.h "go up"',
#  '.r.h "empty"',
#  '.t.q "move"',
#  '.w.p "fly"',
#  '?.s.p "gather"',
#  'b.d.l "separate"',
#  'b.q.\' "break thru"',
#  'b.r.x "flee"',
#  'b.w.? "come"',
#  'd.b.q "cling"',
#  'd.r.k "tread"',
#  'd.x.p "hurry"',
#  'g.h.r "stretch out"',
#  'g.l.h "carry to exile"',
#  'g.l.l "roll"',
#  'h.l.k "go"',
#  'h.p.k "turn"',
#  'k.n.s "gather"',
#  'l.q.t "gather"',
#  'l.q.x "take"',
#  'l.x.ts "press"',
#  'm.h.r "hurry"',
#  'm.l.t "escape"',
#  'm.s.k "pull"',
#  'm.ts.h "drain"',
#  'm.w.sh "depart"',
#  'm.x.h "wipe off"',
#  'n.d.x "banish"',
#  'n.g.\' "touch"',
#  'n.g.r "pour"',
#  'n.g.sh "approach"',
#  'n.g.x "push"',
#  'n.h.g "drive"',
#  'n.k.h "strike"',
#  'n.p.l "fall"',
#  'n.s.\' "set out"',
#  'n.s.? "carry"',
#  'n.s.g "reach"',
#  'n.t.h "stretch out"',
#  'n.t.k "pour out"',
#  'n.t.q "tear away"',
#  'n.w.s "flee"',
#  'n.x.h "lead"',
#  'n.z.h "sprinkle"',
#  'p.n.h "turn"',
#  'p.r.sh "scatter"',
#  'p.r.ts "spread"',
#  'p.sh.t "raid"',
#  'p.w.ts "scatter"',
#  'q.b.ts "gather"',
#  'q.h.l "assemble"',
#  'q.l.\' "sling"',
#  'q.r.b "approach"',
#  'q.w.h "gather"',
#  'q.y.? "vomit"',
#  'r.d.h "scrape"',
#  'r.d.p "pursue"',
#  'r.k.b "drive"',
#  'r.w.m "be high"',
#  'r.w.ts "run"',
#  's.b.b "go around"',
#  's.w.r "turn"',
#  's.x.b "drag"',
#  'sh.b.h "take captive"',
#  'sh.l.k "throw"',
#  'sh.l.x "send"',
#  'sh.p.k "pour"',
#  'sh.w.b "return"',
#  'sh.x.t "press"',
#  't.q.\' "thrust"',
#  't.w.l "hurl"',
#  'ts.n.x "go down"',
#  'y.\'.d "meet"',
#  'y.r.d "go down"',
#  'y.r.h "shoot"',
#  'y.ts.? "went forth"',
#  'y.ts.q "pour out"',
#  'z.r.h "scatter"',
#  'z.r.q "toss"'}

# %%
columns_to_drop = ['id', 'texttype',
       'syn_vbinit', 'syn_gcb4vb', 'syn_realis', 'syn_affneg', 'sub_explicit',
       'sub_anim', 'sub_def', 'sub_num', 'obj_reflexive', 'obj_anim',
       'obj_def', 'obj_num', 'verbid', 'construction',
       'sub_affected', 'sub_affect2', 'vb_binyan', 'vb_passive', 'vb_particip',
       'vb_parse', 'gc_sgpl', 'gc_sameclseq', 'gc_samesame', 'gc_parclseq',
       'gc_parsame', 'info_gcorder','gc_end', 'gc_add',
       'gc_proper', 'gc_complex', 'gc_prep', 'source', 'era',
       'soc_oral', 'soc_north', 'gc2', 'book2', 'vb_aspect', 'obj_def2',
       'gc_samesame2', 'gc_parsame2', 'verse', 'gc3binary', 'unique']

# %%
new_df = df.drop(columns=columns_to_drop)

new_df
# Out:
#          book info_refer       info_reads    info_means  \
# 0     genesis  Gen 01:09  ?el ma:qom exad  to one place
# 1     genesis  Gen 02:19      ?el ha?adam    to the man
# 2     genesis  Gen 02:22      ?el ha?adam    to the man
# 3     genesis  Gen 04:03          le-YHWH       to YHWH
# 4     genesis  Gen 06:18     ?el hate:bah    to the ark
# ...       ...        ...              ...           ...
# 3120    2 chr  2Ch 36:07         le-babel    to Babylon
# 3121    2 chr  2Ch 36:10         babela:h    to Babylon
# 3122    2 chr  2Ch 36:17           alehem       to them
# 3123    2 chr  2Ch 36:18            babel    to Babylon
# 3124    2 chr  2Ch 36:20        ?el babel    to Babylon
#
#                info_verbroot                gc        gc_def    gc_anim
# 0             q.w.h "gather"              prep  not definite  inanimate
# 1               b.w.? "come"              prep      definite    animate
# 2               b.w.? "come"              prep      definite    animate
# 3               b.w.? "come"              prep      definite    animate
# 4               b.w.? "come"              prep      definite  inanimate
# ...                      ...               ...           ...        ...
# 3120            b.w.? "come"              prep      definite  inanimate
# 3121            b.w.? "come"               hey      definite  inanimate
# 3122            .l.h "go up"              prep      definite    animate
# 3123            b.w.? "come"  acc of direction      definite  inanimate
# 3124  g.l.h "carry to exile"              prep      definite  inanimate
#
# [3125 rows x 8 columns]

# %%
set(new_df[new_df.info_reads == "ša:mma:h"].gc_def)
# Out:
# {'not definite'}

# %%
set(new_df[new_df.info_means == "thither"].gc_def)
# Out:
# {'not definite'}

# %%
set(new_df.gc_def)
# Out:
# {'definite', 'not definite'}

# %%
new_df[new_df.book == "deuteronomy"]
# Out:
#             book  info_refer                info_reads  \
# 758  deuteronomy  Deut 01:07              har ha?amori
# 759  deuteronomy  Deut 01:07         ?el kol shekanayv
# 760  deuteronomy  Deut 01:19          ad qadesh barnea
# 761  deuteronomy  Deut 01:20           ad har ha?amori
# 762  deuteronomy  Deut 01:22                   ?alehen
# 763  deuteronomy  Deut 01:22                     ?elai
# 764  deuteronomy  Deut 01:24                ha:ha:ra:h
# 765  deuteronomy  Deut 01:24           ad naxal eshkol
# 766  deuteronomy  Deut 01:31            ad maqom hazeh
# 767  deuteronomy  Deut 01:37                      sham
# 768  deuteronomy  Deut 01:38                  ša:mma:h
# 769  deuteronomy  Deut 01:39                  ša:mma:h
# 770  deuteronomy  Deut 01:40             hammidba:ra:h
# 771  deuteronomy  Deut 01:41                ha:ha:ra:h
# 772  deuteronomy  Deut 01:43                ha:ha:ra:h
# 773  deuteronomy  Deut 02:01             hammidba:ra:h
# 774  deuteronomy  Deut 02:26                 ?el sixon
# 775  deuteronomy  Deut 02:27                     yamin
# 889  deuteronomy  Deut 28:68                 mitsrayim
# 890  deuteronomy  Deut 29:06         ?el hamaqom hazeh
# 891  deuteronomy  Deut 29:27        ?el ?arets ?axeret
# 892  deuteronomy  Deut 30:01                  ša:mma:h
# 893  deuteronomy  Deut 30:03                  ša:mma:h
# 894  deuteronomy  Deut 30:05              ?el ha?arets
# 895  deuteronomy  Deut 30:12             hašša:mayma:h
# 896  deuteronomy  Deut 30:12                     la-nu
# 897  deuteronomy  Deut 30:13           ?el 'eber hayam
# 898  deuteronomy  Deut 30:13                     la-nu
# 899  deuteronomy  Deut 30:16                  ša:mma:h
# 900  deuteronomy  Deut 30:18                  ša:mma:h
# 901  deuteronomy  Deut 31:07              ?el ha?arets
# 902  deuteronomy  Deut 31:13                  ša:mma:h
# 903  deuteronomy  Deut 31:16                  ša:mma:h
# 904  deuteronomy  Deut 31:20             ?el ha?adamah
# 905  deuteronomy  Deut 31:21              ?el ha?arets
# 906  deuteronomy  Deut 31:23              ?el ha?arets
# 907  deuteronomy  Deut 31:28                     ?elai
# 908  deuteronomy  Deut 32:47                  ša:mma:h
# 909  deuteronomy  Deut 32:49   ?el har ha'arabim hazeh
# 910  deuteronomy  Deut 32:50                  ša:mma:h
# 911  deuteronomy  Deut 32:52                  ša:mma:h
# 912  deuteronomy  Deut 32:52              ?el ha?arets
# 913  deuteronomy  Deut 34:01              ?el har nebo
# 914  deuteronomy  Deut 34:01            ro?sh hapisgah
# 915  deuteronomy  Deut 34:04                  ša:mma:h
#
#                                 info_means        info_verbroot  \
# 758    to the hill country of the Amorites         b.w.? "come"
# 759                 to all their neighbors         b.w.? "come"
# 760                       to Qadesh Barnea         b.w.? "come"
# 761    to the hill country of the Amorites         b.w.? "come"
# 762                                to them         b.w.? "come"
# 763                                  to me     q.r.b "approach"
# 764                    to the hill country         .l.h "go up"
# 765                     to the wadi Eshkol         b.w.? "come"
# 766                          to this place         b.w.? "come"
# 767                                thither         b.w.? "come"
# 768                                thither         b.w.? "come"
# 769                                thither         b.w.? "come"
# 770                      to the wilderness      n.s.' "set out"
# 771                    to the hill country         .l.h "go up"
# 772                    to the hill country         .l.h "go up"
# 773                      to the wilderness      n.s.' "set out"
# 774                              to Sihon         sh.l.x "send"
# 775                           to the right         s.w.r "turn"
# 776                            to the left         s.w.r "turn"
# 777                            to the land    .b.r "cross over"
# 778                              to Yahats  y.ts.? "went forth"
# 779       to the land of the sons of Ammon     q.r.b "approach"
# 780    to all the banks of the wadi yabbok     q.r.b "approach"
# 781                               to Edrei  y.ts.? "went forth"
# 782                                thither    .b.r "cross over"
# 783                   to the top of Pisgah         .l.h "go up"
# 784                                thither         b.w.? "come"
# 785                                  to me     q.h.l "assemble"
# 786                                thither    .b.r "cross over"
# 787                       to the good land         b.w.? "come"
# 788                                thither    .b.r "cross over"
# 789                                thither        n.h.g "drive"
# 790                                 to one         n.w.s "flee"
# 791                                thither         n.w.s "flee"
# 792                      onto the mountain         .l.h "go up"
# 793                                  to me     q.r.b "approach"
# 794                         to yalls tents      sh.w.b "return"
# 795                                thither    .b.r "cross over"
# 796                            to the land         b.w.? "come"
# 797                            to the land         b.w.? "come"
# 798                                thither         b.w.? "come"
# 799                          to your house         b.w.? "come"
# 800                         to a good land         b.w.? "come"
# 801                          to this place         b.w.? "come"
# 802                    to the hill country         .l.h "go up"
# 803                            to the wadi       sh.l.k "throw"
# 804                            to the land         b.w.? "come"
# 805                                  to me         .l.h "go up"
# 806                    to the hill country         .l.h "go up"
# 807                    to the hill country         .l.h "go up"
# 808                             to Moserah      n.s.' "set out"
# 809                              to Gudgod      n.s.' "set out"
# 810                            to Yatbatah      n.s.' "set out"
# 811                               to Egypt      y.r.d "go down"
# 812                          to this place         b.w.? "come"
# 813                                thither    .b.r "cross over"
# 814                                thither         b.w.? "come"
# 815                                thither    .b.r "cross over"
# 816                            to the land         b.w.? "come"
# 817                                thither         b.w.? "come"
# 818                                thither         b.w.? "come"
# 819                                thither         b.w.? "come"
# 820                            to the rest         b.w.? "come"
# 821                     to the inheritance         b.w.? "come"
# 822                                thither         b.w.? "come"
# 823                           to the place         b.w.? "come"
# 824                                thither         b.w.? "come"
# 825             to the midst of its square      q.b.ts "gather"
# 826                           to the place           h.l.k "go"
# 827                          to your tents           h.l.k "go"
# 828                          to your gates  y.ts.? "went forth"
# 829                           to the place         .l.h "go up"
# 830               to the Levitical priests         b.w.? "come"
# 831                           to the Judge         b.w.? "come"
# 832                            to the land         b.w.? "come"
# 833                               to Egypt      sh.w.b "return"
# 834                           to the place         b.w.? "come"
# 835                            to the land         b.w.? "come"
# 836                                thither         n.w.s "flee"
# 837                                thither         n.w.s "flee"
# 838                        into the forest         b.w.? "come"
# 839                 to one of these cities         n.w.s "flee"
# 840                 to one of these cities         n.w.s "flee"
# 841                     to the battlefield     q.r.b "approach"
# 842                           to his house      sh.w.b "return"
# 843                           to his house      sh.w.b "return"
# 844                           to his house      sh.w.b "return"
# 845                           to his house      sh.w.b "return"
# 846                              to a city     q.r.b "approach"
# 847                       to a strong wadi      y.r.d "go down"
# 848             to the midst of your house         b.w.? "come"
# 849              to the elders of his city  y.ts.? "went forth"
# 850               to the gate of his place  y.ts.? "went forth"
# 851                         to his brother      sh.w.b "return"
# 852             to the midst of your house       ?.s.p "gather"
# 853              to the elders of the city  y.ts.? "went forth"
# 854                            to the gate  y.ts.? "went forth"
# 855  to the entrance of her father's house  y.ts.? "went forth"
# 856               to the gate of that city  y.ts.? "went forth"
# 857                       outside the camp  y.ts.? "went forth"
# 858               to the midst of the camp         b.w.? "come"
# 859               to the midst of the camp         b.w.? "come"
# 860                                thither  y.ts.? "went forth"
# 861                                outside  y.ts.? "went forth"
# 862          to the house of YHWH your God         b.w.? "come"
# 863                                thither         b.w.? "come"
# 864       into the vineyard of your friend         b.w.? "come"
# 865          into the grain of your friend         b.w.? "come"
# 866                           to his house         b.w.? "come"
# 867                                 to you  y.ts.? "went forth"
# 868                                outside  y.ts.? "went forth"
# 869                           to the court    n.g.sh "approach"
# 870                            to the gate         .l.h "go up"
# 871                          to the elders         .l.h "go up"
# 872                                 to him    n.g.sh "approach"
# 873                            to the land         b.w.? "come"
# 874                           to the place           h.l.k "go"
# 875                            to the land         b.w.? "come"
# 876                          to the priest         b.w.? "come"
# 877                               to Egypt      y.r.d "go down"
# 878                          to this place         b.w.? "come"
# 879                            to the land    .b.r "cross over"
# 880                            to the land    .b.r "cross over"
# 881                         to/against you  y.ts.? "went forth"
# 882                                thither         b.w.? "come"
# 883                         to/against him  y.ts.? "went forth"
# 884                            to a nation           h.l.k "go"
# 885                                thither        n.h.g "drive"
# 886                           to the field  y.ts.? "went forth"
# 887                                thither         b.w.? "come"
# 888               to the ends of the earth     p.w.ts "scatter"
# 889                               to egypt      sh.w.b "return"
# 890                          to this place         b.w.? "come"
# 891                        to another land       sh.l.k "throw"
# 892                                thither       n.d.x "banish"
# 893                                thither     p.w.ts "scatter"
# 894                            to the land         b.w.? "come"
# 895                           to the skies         .l.h "go up"
# 896                                  to us         l.q.x "take"
# 897           to the other side of the sea    .b.r "cross over"
# 898                                  to us         l.q.x "take"
# 899                                thither         b.w.? "come"
# 900                                thither         b.w.? "come"
# 901                            to the land         b.w.? "come"
# 902                                thither    .b.r "cross over"
# 903                                thither         b.w.? "come"
# 904                            to the land         b.w.? "come"
# 905                            to the land         b.w.? "come"
# 906                            to the land         b.w.? "come"
# 907                                  to me     q.h.l "assemble"
# 908                                thither    .b.r "cross over"
# 909                      to this mt Abarim         .l.h "go up"
# 910                                thither         .l.h "go up"
# 911                                thither         b.w.? "come"
# 912                            to the land         b.w.? "come"
# 913                             to mt nebo         .l.h "go up"
# 914                   to the top of Pisgah         .l.h "go up"
# 915                                thither    .b.r "cross over"
#
#                    gc        gc_def    gc_anim
# 758  acc of direction      definite  inanimate
# 759              prep      definite    animate
# 760              prep      definite  inanimate
# 761              prep      definite  inanimate
# 762              prep      definite  inanimate
# 763              prep      definite    animate
# 764               hey      definite  inanimate
# 765              prep      definite  inanimate
# 766              prep      definite  inanimate
# 767  acc of direction  not definite  inanimate
# 768               hey  not definite  inanimate
# 769               hey  not definite  inanimate
# 770               hey      definite  inanimate
# 771               hey      definite  inanimate
# 772               hey      definite  inanimate
# 773               hey      definite  inanimate
# 774              prep      definite    animate
# 775  acc of direction  not definite  inanimate
# 776  acc of direction  not definite  inanimate
# 777              prep      definite  inanimate
# 778               hey      definite  inanimate
# 779              prep      definite  inanimate
# 780  acc of direction      definite  inanimate
# 781  acc of direction      definite  inanimate
# 782               hey  not definite  inanimate
# 783  acc of direction      definite  inanimate
# 784               hey  not definite  inanimate
# 785              prep      definite    animate
# 786               hey  not definite  inanimate
# 787              prep      definite  inanimate
# 788               hey  not definite  inanimate
# 789               hey  not definite  inanimate
# 790              prep      definite  inanimate
# 791               hey  not definite  inanimate
# 792              prep      definite  inanimate
# 793              prep      definite    animate
# 794              prep      definite  inanimate
# 795               hey  not definite  inanimate
# 796              prep      definite  inanimate
# 797              prep      definite  inanimate
# 798               hey  not definite  inanimate
# 799              prep      definite  inanimate
# 800              prep  not definite  inanimate
# 801              prep      definite  inanimate
# 802               hey      definite  inanimate
# 803              prep      definite  inanimate
# 804              prep      definite  inanimate
# 805              prep      definite    animate
# 806               hey      definite  inanimate
# 807               hey      definite  inanimate
# 808  acc of direction      definite  inanimate
# 809               hey      definite  inanimate
# 810  acc of direction      definite  inanimate
# 811               hey      definite  inanimate
# 812              prep      definite  inanimate
# 813               hey  not definite  inanimate
# 814               hey  not definite  inanimate
# 815               hey  not definite  inanimate
# 816              prep      definite  inanimate
# 817               hey  not definite  inanimate
# 818               hey  not definite  inanimate
# 819               hey  not definite  inanimate
# 820              prep      definite  inanimate
# 821              prep      definite  inanimate
# 822               hey  not definite  inanimate
# 823              prep      definite  inanimate
# 824               hey  not definite  inanimate
# 825              prep      definite  inanimate
# 826              prep      definite  inanimate
# 827              prep      definite  inanimate
# 828              prep      definite  inanimate
# 829              prep      definite  inanimate
# 830              prep      definite    animate
# 831              prep      definite    animate
# 832              prep      definite  inanimate
# 833               hey      definite  inanimate
# 834              prep      definite  inanimate
# 835              prep      definite  inanimate
# 836               hey  not definite  inanimate
# 837               hey  not definite  inanimate
# 838              prep      definite  inanimate
# 839              prep      definite  inanimate
# 840              prep      definite  inanimate
# 841              prep      definite  inanimate
# 842              prep      definite  inanimate
# 843              prep      definite  inanimate
# 844              prep      definite  inanimate
# 845              prep      definite  inanimate
# 846              prep  not definite  inanimate
# 847              prep      definite  inanimate
# 848              prep      definite  inanimate
# 849              prep      definite    animate
# 850              prep      definite  inanimate
# 851              prep      definite    animate
# 852              prep      definite  inanimate
# 853              prep      definite    animate
# 854               hey      definite  inanimate
# 855              prep      definite  inanimate
# 856              prep      definite  inanimate
# 857     prep and prep      definite  inanimate
# 858              prep      definite  inanimate
# 859              prep      definite  inanimate
# 860               hey  not definite  inanimate
# 861  acc of direction  not definite  inanimate
# 862  acc of direction      definite  inanimate
# 863               hey  not definite  inanimate
# 864              prep      definite  inanimate
# 865              prep      definite  inanimate
# 866              prep      definite  inanimate
# 867              prep      definite    animate
# 868               hey      definite  inanimate
# 869              prep      definite  inanimate
# 870               hey      definite  inanimate
# 871              prep      definite    animate
# 872              prep      definite    animate
# 873              prep      definite  inanimate
# 874              prep      definite  inanimate
# 875              prep      definite  inanimate
# 876              prep      definite    animate
# 877               hey      definite  inanimate
# 878              prep      definite  inanimate
# 879              prep      definite  inanimate
# 880              prep      definite  inanimate
# 881              prep      definite    animate
# 882               hey  not definite  inanimate
# 883              prep      definite    animate
# 884              prep      definite    animate
# 885               hey  not definite  inanimate
# 886  acc of direction      definite  inanimate
# 887               hey  not definite  inanimate
# 888              prep      definite  inanimate
# 889  acc of direction      definite  inanimate
# 890              prep      definite  inanimate
# 891              prep  not definite  inanimate
# 892               hey  not definite  inanimate
# 893               hey  not definite  inanimate
# 894              prep      definite  inanimate
# 895               hey      definite  inanimate
# 896              prep      definite    animate
# 897              prep      definite  inanimate
# 898              prep      definite    animate
# 899               hey  not definite  inanimate
# 900               hey  not definite  inanimate
# 901              prep      definite  inanimate
# 902               hey  not definite  inanimate
# 903               hey  not definite  inanimate
# 904              prep      definite  inanimate
# 905              prep      definite  inanimate
# 906              prep      definite  inanimate
# 907              prep      definite    animate
# 908               hey  not definite  inanimate
# 909              prep      definite  inanimate
# 910               hey  not definite  inanimate
# 911               hey  not definite  inanimate
# 912              prep      definite  inanimate
# 913              prep      definite  inanimate
# 914  acc of direction      definite  inanimate
# 915               hey  not definite  inanimate

# %%
df2 = pd.read_csv("data/sbl_grouped_cmpls_for_annot.csv")
