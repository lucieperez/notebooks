# %%
import pandas as pd

# %%
df = pd.read_csv("data/Exodus_dataset.csv").fillna("")

# %%
df = df[df.lex == "BW>["]

# %%
set(df.comments)
# Out:
# {'',
#  'B GBLK locative in database',
#  'B with the sense against, ',
#  'God says to Moses "I will come to you", factive or fictive?',
#  'REC',
#  'all the people will go to their place / place as actual place or describing a status?',
#  'bring the matters to God, actual motion?',
#  'bring the matters to you fictive motion',
#  'come for its wages, curious as a complement',
#  'come to God?',
#  'have brought sin upon them fictive but not horizontal?',
#  'he made the poles go through the rings, factive motion?',
#  'locative in the database',
#  'no a destination, motion?',
#  'not destination/origin',
#  'put something / make something go into something, motion?',
#  'put something into something',
#  'put the poles into the rings etc, not horizontal motion?',
#  'put the poles into the rings, not horizontal motion?',
#  'the cry of the people has come to me',
#  'the people bring more than enough, not destination/origin ',
# ...

# %%
len(df[df.scroll == "MT"])
# Out:
# 126

# %%
df
# Out:
#       verb_id   lex scroll    book  chapter  verse_num gcons_verb  \
# 0       28771  BW>[     MT  Exodus        1          1       B>JM
# 1       28778  BW>[     MT  Exodus        1          1        B>W
# 2     1945779  BW>[   4Q13  Exodus        1          1       B>JM
# 3     1945787  BW>[   4Q13  Exodus        1          1        B>W
# 4     1941985  BW>[   4Q11  Exodus        1          1       B>JM
# ...       ...   ...    ...     ...      ...        ...        ...
# 1020  1953191  BW>[   4Q22  Exodus        8         19        JB>
# 1021    32836  BW>[     MT  Exodus        8         20        JB>
# 1022  1953291  BW>[   4Q22  Exodus        8         20        JB>
# 1023  1942415  BW>[   4Q11  Exodus        8         20        JB>
# 1033    33027  BW>[     MT  Exodus        9          1         B>
#
#                                             gcons_verse  \
# 0     W >LH CMWT BNJ JFR>L H B>JM MYRJMH >T J<QB >JC...
# 1     W >LH CMWT BNJ JFR>L H B>JM MYRJMH >T J<QB >JC...
# ...
