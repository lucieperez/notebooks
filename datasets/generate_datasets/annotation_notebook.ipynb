# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
import pandas as pd

# %%
### This notebook has been created with the help of ChatGPT. ###

# %%
pd.set_option('display.max_colwidth', None)  # For older versions of pandas, use -1 instead of None
pd.set_option('display.max_columns', None)   # Ensure all columns are shown

# %%
df = pd.read_csv('data/bib_dss_all_verbs.csv')  # Replace with your DataFrame
df.fillna("")

# converting 'dir_he' and 'dir_he_dss' from float to int 

df["dir_he"] = df["dir_he"].astype(str)
df["dir_he"] = df["dir_he"].replace("1.0", "1").replace("0.0", "0")

df
# Out:
#       verb_id   lex   scroll     book chapter  verse_num gcons_verb  \
# 0     1889904  <WP[      1Q1  Genesis       1         20      J<WPP
# 1     1890016  HLK[      1Q1  Genesis       3         14        TLK
# 2     1890027  HLK[      1Q1  Genesis      22         13        JLK
# 3     1890035  <LH[      1Q1  Genesis      22         13      J<LHW
# 4     1890114  BW>[      1Q1  Genesis      23         18        B>J
# ...       ...   ...      ...      ...     ...        ...        ...
# 4360  2107831  HLK[  Xjudges   Judges       4          9        >LK
# 4361  2107847  HLK[       X4       X4      f1          1  no_g_cons
# 4362  2107848  HLK[       X4       X4      f1          1  no_g_cons
# 4363  2107849  HLK[       X4       X4      f1          1  no_g_cons
# 4364  2107850  HLK[       X4       X4      f1          2  no_g_cons
#
#                                                                                                              gcons_verse  \
# 0                                          W J>MR >LHJM JCRWYW H MJM CRY NPC XJH W <WP J<WPP <L H >RY <L PNJ RQJ< H CMJM
# 1     W J>MR JHWH >LHJM >L H NXC KJ <FJT Z>T >RWR >TH M KWL H BHMH W M KWL XJT H FDH <L GXNK TLK W <PR T>KL KWL JMJ XJJK
# 2                                                               B QRNJW W JLK >BRHM W JQX >T H >JL W J<LHW L <LH TXT BNW
# 3                                                               B QRNJW W JLK >BRHM W JQX >T H >JL W J<LHW L <LH TXT BNW
# 4                                                                        L >BRHM L MQNH L <JNJ BNJ XT B KWL B>J C<R <JRW
# ...                                                                                                                  ...
# 4360                                                                   W T>MR HLK >LK <MK >PS KJ L> THJH TP>RTK <L H DRK
# 4361                                                                                                                 NaN
# 4362                                                                                                                 NaN
# 4363                                                                                                                 NaN
# 4364                                                                                                                 NaN
#
#                                  gcons_clause  \
# 0     W <WP J<WPP <L H >RY <L PNJ RQJ< H CMJM
# 1                                 <L GXNK TLK
# 2                                        None
# 3                                        None
# 4                                         NaN
# ...                                       ...
# 4360                                     None
# 4361                                     None
# 4362                                     None
# 4363                                     None
# 4364                                     None
#
#                                       subject                   complement  \
# 0                                         <WP  <L H >RY <L PNJ RQJ< H CMJM
# 1                                         NaN                      <L GXNK
# 2                                        None                          NaN
# 3                                        None                          NaN
# 4     L MQNH L <JNJ BNJ XT B KWL B>J C<R <JRW                      L >BRHM
# ...                                       ...                          ...
# 4360                                     None                          NaN
# 4361                                     None                          NaN
# 4362                                     None                          NaN
# 4363                                     None                          NaN
# 4364                                     None                          NaN
#
#      dir_he  dir_he_dss  \
# 0         0           0
# 1         0           0
# 2       nan           0
# 3       nan           0
# 4         0           0
# ...     ...         ...
# 4360    nan           0
# 4361    nan           0
# 4362    nan           0
# 4363    nan           0
# 4364    nan           0
#
#                                                                                                                     sign_info  \
# 0                                            0 0000 00000 000000 0 000 000 000 000 0 000 00000 00 0 000 00 000 0000 0 0000 00
# 1     0 0000 0000 00000 00 0 000 00 0000 000 0000 000 0 000 0 0000 0 0 000 000 0 000 00 00000 000 0 000 0000 000 000 00000 00
# 2                                                              0 000000 0 000 00000 0 000 00 0 000 0 000000 0 000 000 0000 00
# 3                                                              0 000000 0 000 00000 0 000 00 0 000 0 000000 0 000 000 0000 00
# 4                                                                         0 00000 0 0000 0 0000 000 00 0 000 000 000 00000 00
# ...                                                                                                                       ...
# 4360                                                                   0 0000 000 000 0000 000 00 00 0000 0000000 00 0 000 00
# 4361                                                                                                    01 00 000 01111111 01
# 4362                                                                                                    01 00 000 01111111 01
# 4363                                                                                                    01 00 000 01111111 01
# 4364                                                                                                               01 0 01 00
#
#        stem tense preposition_1 preposition_2 preposition_3 preposition_4  \
# 0     polel  impf            <L            <L           NaN           NaN
# 1       qal  impf            <L           NaN           NaN           NaN
# 2       qal  wayy           NaN           NaN           NaN           NaN
# 3     hifil  wayy           NaN           NaN           NaN           NaN
# 4       qal  ptca             L           NaN           NaN           NaN
# ...     ...   ...           ...           ...           ...           ...
# 4360    qal  impf           NaN           NaN           NaN           NaN
# 4361    qal  impf           NaN           NaN           NaN           NaN
# 4362    NaN   NaN           NaN           NaN           NaN           NaN
# 4363    NaN   NaN           NaN           NaN           NaN           NaN
# 4364    NaN   NaN           NaN           NaN           NaN           NaN
#
#      preposition_5 preposition_6 preposition_7
# 0              NaN           NaN           NaN
# 1              NaN           NaN           NaN
# 2              NaN           NaN           NaN
# 3              NaN           NaN           NaN
# 4              NaN           NaN           NaN
# ...            ...           ...           ...
# 4360           NaN           NaN           NaN
# 4361           NaN           NaN           NaN
# 4362           NaN           NaN           NaN
# 4363           NaN           NaN           NaN
# 4364           NaN           NaN           NaN
#
# [4365 rows x 23 columns]

# %% [markdown]
# ### Step 3: Define Columns to Annotate and Create Widgets

# %%
# List of columns of interest
columns = df.columns.to_list()
columns_for_info = [
    'verb_id',
    'lex',
    'scroll',
    'book',
    'chapter',
    'verse_num',
    'gcons_verb',
    'gcons_verse',
    'sign_info',
    'stem',
    'tense',
]
columns_to_annotate = [
    'gcons_clause',
    'subject',
    'complement',
    'dir_he',
    'preposition_1',
    'preposition_2',
    'preposition_3',
    'preposition_4',
    'preposition_5',
    'preposition_6',
    'preposition_7',
]

# %%
annotation_input = widgets.Textarea(
    value='',
    placeholder='Type your annotation here',
    description='',
    disabled=False,
    layout=widgets.Layout(width='100%', height='100px')  # Adjust width and height as needed
)

submit_button = widgets.Button(
    description='Submit',
    disabled=False,
    button_style='',
    tooltip='Click to submit annotation',
    icon='check'
)

prev_row_button = widgets.Button(
    description='Previous Row',
    disabled=False,
    button_style='',
    tooltip='Go to the previous row',
    icon='arrow-left'
)

next_row_button = widgets.Button(
    description='Next Row',
    disabled=False,
    button_style='',
    tooltip='Go to the next row',
    icon='arrow-right'
)

# %% [markdown]
# ### Step 4: Display Data and Widgets with Navigation and Iteration Logic

# %%
current_index = 0  # Start with the first row
current_column_index = 0  # Start with the first column to annotate

def display_row(row_index, col_index):
    global current_index, current_column_index
    current_index, current_column_index = row_index, col_index
    
    # Get the value from the DataFrame, convert NaN or non-string values to string
    cell_value = df.at[row_index, columns_to_annotate[col_index]]
    if pd.isna(cell_value):
        cell_value = ''  # Convert NaN to an empty string
    else:
        cell_value = str(cell_value)  # Convert non-string values to string

    clear_output(wait=True)

    # Set the value of the annotation input and display it along with other elements
    annotation_input.value = cell_value
    display(df.iloc[row_index][columns_for_info])
    display(df.iloc[row_index][columns_to_annotate])
    display(widgets.HTML(value=f"<b>Annotate '{columns_to_annotate[col_index]}':</b>"))
    display(annotation_input, submit_button)
    display(widgets.HBox([prev_row_button, next_row_button]))

def navigate_row(offset):
    new_index = current_index + offset
    if 0 <= new_index < len(df):
        display_row(new_index, 0)

display_row(current_index, current_column_index)
# Out:
# verb_id                                                                                 1889904
# lex                                                                                        <WP[
# scroll                                                                                      1Q1
# book                                                                                    Genesis
# chapter                                                                                       1
# verse_num                                                                                    20
# gcons_verb                                                                                J<WPP
# gcons_verse       W J>MR >LHJM JCRWYW H MJM CRY NPC XJH W <WP J<WPP <L H >RY <L PNJ RQJ< H CMJM
# sign_info      0 0000 00000 000000 0 000 000 000 000 0 000 00000 00 0 000 00 000 0000 0 0000 00
# stem                                                                                      polel
# tense                                                                                      impf
# Name: 0, dtype: object
# gcons_clause     W <WP J<WPP <L H >RY <L PNJ RQJ< H CMJM
# subject                                              <WP
# complement                   <L H >RY <L PNJ RQJ< H CMJM
# dir_he                                                 0
# preposition_1                                         <L
# preposition_2                                         <L
# preposition_3
# preposition_4
# preposition_5
# preposition_6
# preposition_7
# Name: 0, dtype: object
# HTML(value="<b>Annotate 'gcons_clause':</b>")
# Textarea(value='W <WP J<WPP <L H >RY <L PNJ RQJ< H CMJM', layout=Layout(height='100px', width='100%'), placeho…
# Button(description='Submit', icon='check', style=ButtonStyle(), tooltip='Click to submit annotation')
# HBox(children=(Button(description='Previous Row', icon='arrow-left', style=ButtonStyle(), tooltip='Go to the p…

# %% [markdown]
# ### Step 5: Handle Annotation Submission and Row Navigation

# %%
def on_submit_clicked(b):
    df.at[current_index, columns_to_annotate[current_column_index]] = annotation_input.value
    if current_column_index + 1 < len(columns_to_annotate):
        display_row(current_index, current_column_index + 1)
    else:
        print("All annotations for this row are complete.")

def on_prev_row_clicked(b):
    navigate_row(-1)

def on_next_row_clicked(b):
    navigate_row(1)

submit_button.on_click(on_submit_clicked)
prev_row_button.on_click(on_prev_row_clicked)
next_row_button.on_click(on_next_row_clicked)
