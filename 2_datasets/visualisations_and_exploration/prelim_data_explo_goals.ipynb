# %%
import pandas as pd
from collections import Counter

# %%
pd.set_option("display.max_columns", None) # show all columns
pd.set_option("display.max_rows", None) # show all columns

# %%
df1 = pd.read_csv("../../1_annotation_tools/data/biblical_datasets/deuteronomy_locatives/annotation_df_history/deuteronomy_with_loca.csv").fillna("")
df2 = pd.read_csv("../../1_annotation_tools/data/biblical_datasets/exodus_locatives/annotation_df_history/exodus_with_loca.csv").fillna("")
df3 = pd.read_csv("../../1_annotation_tools/data/biblical_datasets/isaiah_locatives/annotation_df_history/isaiah_with_loca.csv").fillna("")

# %%
df3.columns
# Out:
# Index(['verb_id', 'lex', 'scroll', 'book', 'chapter', 'verse_num',
#        'gcons_verb', 'gcons_verse', 'sign_info', 'stem', 'tense',
#        'gcons_clause', 'subject', 'complement', 'cmpl_lex', 'cmpl_translation',
#        'dir_he', 'cmpl_constr', 'cmpl_nt', 'cmpl_anim', 'cmpl_det',
#        'cmpl_indiv', 'cmpl_complex', 'motion_type', 'preposition_1',
#        'preposition_2', 'preposition_3', 'preposition_4', 'preposition_5',
#        'preposition_6', 'comments', 'reconstructed_verse'],
#       dtype='object')

# %%
# Use groupby and value_counts to get the counts of each cmpl_constr per cmpl_anim
result = df3.groupby('cmpl_anim')['cmpl_constr'].value_counts().unstack(fill_value=0)

# Display the result
print(result)
# Out:
# cmpl_constr       dir-he  prep  prep + dir-he  prep + prep  vc
# cmpl_anim
#              979       0     0              0            0   0
# anim           0       0   195              0            0   2
# anim inanim    0       0    10              0            0   0
# inanim         0      22   388              4            4  79

# %%
result
# Out:
# cmpl_constr       dir-he  prep  prep + dir-he  prep + prep  vc
# cmpl_anim
#              979       0     0              0            0   0
# anim           0       0   195              0            0   2
# anim inanim    0       0    10              0            0   0
# inanim         0      22   388              4            4  79

# %%
df3[(df3.cmpl_anim == "anim") & (df3.cmpl_constr == "vc")]
# Out:
#      verb_id   lex  scroll    book  chapter  verse_num gcons_verb  \
# 286   216346  <WP[      MT  Isaiah       11         14        <PW
# 290  1899300  <WP[  1Qisaa  Isaiah       11         14        <PW
#
#                                            gcons_verse  \
# 286  W <PW B KTP PLCTJM JMH JXDW JBZW >T BNJ QDM >D...
# 290  W <PW B KTP PLCTJJM JMH JXDW W BZZW >T BNJ QDM...
#
#                                              sign_info stem tense  \
# 286                                                     qal  perf
# 290  0 000 0 000 0000000 000 0000 0 0000 00 000 000...  qal  perf
#
#                 gcons_clause subject complement cmpl_lex  \
# 286   W <PW B KTP PLCTJM JMH             PLCTJM   PLCTJ/
# 290  W <PW B KTP PLCTJJM JMH            PLCTJJM   PLCTJ/
#
#             cmpl_translation dir_he cmpl_constr cmpl_nt cmpl_anim cmpl_det  \
# 286  towards the Philistines    0.0          vc    gens      anim      und
# ...

# %%
frames = [df1, df2, df3]
df = pd.concat(frames)

# %%
# Use groupby and value_counts to get the counts of each cmpl_constr per cmpl_anim
result = df.groupby('cmpl_anim')['cmpl_constr'].value_counts().unstack(fill_value=0)

# Display the result
result
# Out:
# cmpl_constr        dir-he  dir-he + prep  dir_he  prep  prep + dir-he  \
# cmpl_anim
#              1563       0              0       0     3              0
# anim            0       0              0       0   486              0
# anim inanim     0       0              0       0    10              0
# inanim          0     165              1       4  1256              9
#
# cmpl_constr  prep + prep  prep + prep + prep  prep + prep + prep + prep  \
# cmpl_anim
#                        0                   0                          0
# anim                  43                   8                          0
# anim inanim            5                   0                          2
# inanim                75                   6                          0
#
# cmpl_constr  prep + prep + prep + prep + prep + prep + prep   vc
# cmpl_anim
#                                                           0    0
# anim                                                      0    2
# ...

# %%
df[(df.cmpl_anim == "anim") & (df.cmpl_constr == "vc")]
# Out:
#      verb_id   lex  scroll    book  chapter  verse_num gcons_verb  \
# 286   216346  <WP[      MT  Isaiah       11         14        <PW
# 290  1899300  <WP[  1Qisaa  Isaiah       11         14        <PW
#
#                                            gcons_verse  \
# 286  W <PW B KTP PLCTJM JMH JXDW JBZW >T BNJ QDM >D...
# 290  W <PW B KTP PLCTJJM JMH JXDW W BZZW >T BNJ QDM...
#
#                                              sign_info stem tense  \
# 286                                                     qal  perf
# 290  0 000 0 000 0000000 000 0000 0 0000 00 000 000...  qal  perf
#
#                 gcons_clause subject complement cmpl_lex  \
# 286   W <PW B KTP PLCTJM JMH             PLCTJM   PLCTJ/
# 290  W <PW B KTP PLCTJJM JMH            PLCTJJM   PLCTJ/
#
#             cmpl_translation dir_he cmpl_constr cmpl_nt cmpl_anim cmpl_det  \
# 286  towards the Philistines    0.0          vc    gens      anim      und
# ...

# %%
df = df[df.complement != "no complement"]
df = df[df.comments != "reconstructed"]
df = df[df.motion_type != "factive fictive"]

# %%
Counter(df.preposition_1)
# Out:
# Counter({'MN': 321,
#          '>L': 286,
#          '': 186,
#          'B': 152,
#          'L': 80,
#          '<L': 66,
#          '<D': 13,
#          '>XR/': 11,
#          'BMW': 3,
#          '>LJ': 2,
#          'MWL/': 1,
#          '<M': 1,
#          'BJN/': 1,
#          '>LJK': 1,
#          '>L ': 1,
#          ' >L': 1})

# %%
len(df)
# Out:
# 1126

# %%
df_x = df[df.motion_type == "factive fictive"]
df_x
# Out:
#       verb_id   lex  scroll         book  chapter  verse_num gcons_verb  \
# 1       92926  NS<[      MT  Deuteronomy        1          7        S<W
# 4     1985803  NS<[    4Q35  Deuteronomy        1          7        S<W
# 9       93165  QRB[      MT  Deuteronomy        1         17     TQRBWN
# 10    1986046  QRB[    4Q35  Deuteronomy        1         17    TQRJBWN
# 74      93785  PNH[      MT  Deuteronomy        2          3        PNW
# ...       ...   ...     ...          ...      ...        ...        ...
# 1605   233562  JRD[      MT       Isaiah       63          6      >WRJD
# 1606  1917446  JRD[  1Qisaa       Isaiah       63          6     >WRJDH
# 1607  1926569  JRD[     1Q8       Isaiah       63          6      >RJDH
# 1642   234239  NWX[      MT       Isaiah       65         15      HNXTM
# 1643  1918152  NWX[  1Qisaa       Isaiah       65         15     HNXTMH
#
#                                             gcons_verse  \
# ...

# %%
Counter(df_x.preposition_1)
# Out:
# Counter({'L': 71,
#          'B': 66,
#          '<L': 58,
#          'MN': 51,
#          '>L': 31,
#          '': 25,
#          '<M': 7,
#          '<D': 5,
#          '>XR/': 4,
#          'BH': 2,
#          'TXT': 2,
#          '<L ': 2,
#          'LKM': 1,
#          'MMNW': 1,
#          '>T==': 1})

# %%
df_x[df_x.comments != ""]
# Out:
#       verb_id   lex    scroll         book  chapter  verse_num gcons_verb  \
# 1       92926  NS<[        MT  Deuteronomy        1          7        S<W
# 4     1985803  NS<[      4Q35  Deuteronomy        1          7        S<W
# 9       93165  QRB[        MT  Deuteronomy        1         17     TQRBWN
# 10    1986046  QRB[      4Q35  Deuteronomy        1         17    TQRJBWN
# 74      93785  PNH[        MT  Deuteronomy        2          3        PNW
# 75    1986486  PNH[      4Q35  Deuteronomy        2          3        PNW
# 82      93902  <BR[        MT  Deuteronomy        2          8       N<BR
# 85    1991883  <BR[      4Q42  Deuteronomy        2          8       N<BR
# 97      94266  SWR[        MT  Deuteronomy        2         27       >SWR
# 100   1981908  SWR[      4Q31  Deuteronomy        2         27       >SWR
# 120     94494  JY>[        MT  Deuteronomy        3          1        JY>
# 122     94905  <BR[        MT  Deuteronomy        3         18      T<BRW
# ...
