# %%
import pandas as pd

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
df = pd.read_csv("../../1_annotation_tools/data/datasets_to_check/combined_datasets/combined_datasets.csv").fillna("")

# %%
df[df.complement == "CLWM"]
# Out:
#       verb_id   lex  scroll    book  chapter  verse_num gcons_verb  \
# 8619   231580  BW>[      MT  Isaiah       57          2       JBW>
# 8621  1915378  BW>[  1Qisaa  Isaiah       57          2       JBW>
# 8624  1925228  BW>[     1Q8  Isaiah       57          2      JBW>W
#
#                                      gcons_verse  \
# 8619         JBW> CLWM JNWXW <L MCKBWTM HLK NKXW
# 8621  W JBW> CLWM W JNWXW <L MCKBWTJW HLWK NWKXH
# 8624        JBW>W CLWM JNWXW <L MCKBTM HWLK NKXH
#
#                                        sign_info stem tense gcons_clause  \
# 8619                                              qal  impf    JBW> CLWM
# 8621  0 0000 0000 0 00000 00 00000000 0000 00000  qal  impf  W JBW> CLWM
# 8624        11100 0000 11111 11 000000 0000 0000  qal  impf   JBW>W CLWM
#
#      subject complement cmpl_lex cmpl_translation dir_he cmpl_constr  \
# 8619               CLWM    CLWM/       into peace    0.0          vc
# ...

# %%
# Create a boolean column indicating if 'CLWM' is present
df["has_CLWM"] = df["gcons_clause"].astype(str).apply(lambda x: "CLWM" in x)

# Now you can filter or inspect easily
df[df["has_CLWM"]]
# Out:
#        verb_id   lex  scroll          book  chapter  verse_num gcons_verb  \
# 70        6216  HLK[     1QH           1QH       18         12      HTHLK
# 71        6216  HLK[     1QH           1QH       18         12      HTHLK
# 72        6216  HLK[     1QH           1QH       18         12      HTHLK
# 368     397988  BW>[      MT  1_Chronicles       12         18       B>TM
# 893     192342  JY>[      MT       1_Kings       20         18       JY>W
# 947     194032  CWB[      MT       1_Kings       22         17      JCWBW
# 956     194241  BW>[      MT       1_Kings       22         27        B>J
# 957     194248  CWB[      MT       1_Kings       22         28        CWB
# 958     194249  CWB[      MT       1_Kings       22         28       TCWB
# 982     141869  HLK[      MT      1_Samuel        1         17        LKJ
# 1567    153725  HLK[      MT      1_Samuel       20         13       HLKT
# 1600    154333  HLK[      MT      1_Samuel       20         42         LK
# ...
