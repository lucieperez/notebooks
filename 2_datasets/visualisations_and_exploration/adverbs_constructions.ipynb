# %%
import pandas as pd

# %%
df = pd.read_csv("../../1_annotation_tools/data/datasets_to_check/combined_datasets/combined_datasets.csv").fillna("")

# %%
pd.set_option("display.max_columns", False)
pd.set_option("display.max_rows", False)
pd.set_option("display.max_colwidth", False)

# %%
df_adv = df[df.cmpl_indiv == "adv"].copy()

# %%
set(df_adv.cmpl_constr)
# Out:
# {'dir-he', 'prep', 'vc'}

# %%
df_adv[df_adv.cmpl_constr == "prep"]
# Out:
#        verb_id   lex scroll  ...       comments                        reconstructed_verse  Study_Edition
# 427    400570   BW>[  MT     ...
# 2566   199730   BW>[  MT     ...
# 3084   164336   BW>[  MT     ...
# 3594   173504   QRB[  MT     ...
# 6790   10341    HLK[  MT     ...
# 9374   256919   HLK[  MT     ...
# 9848   345536   BW>[  MT     ...
# 13273  330669   SBB[  MT     ...
# 13275  330689   SBB[  MT     ...
# 13276  2051248  SBB[  4Q87   ...  reconstructed  [MH LKH H JM KJ] TNWS [H JRDN TSB L >XWR]
#
# [10 rows x 34 columns]

# %%
df_adv[df_adv.cmpl_constr == "dir-he"]
# Out:
#        verb_id  ... Study_Edition
# 1618   154766   ...
# 2413   196657   ...
# 2416   196698   ...
# 2417   196705   ...
# 2582   200273   ...
# 2748   206191   ...
# 4050   1986288  ...
# 4051   93580    ...
# 4052   1986299  ...
# 4053   93607    ...
# 4124   94997    ...
# 4125   1982294  ...
# ...        ...  ... ..
# 10883  138708   ...
# 11407  63426    ...
# 11457  64835    ...
# 11458  1890730  ...
# 12124  78904    ...
# 12150  79616    ...
# 12555  91344    ...
# 12577  91955    ...
# 12579  92045    ...
# 12580  92129    ...
# 12585  92311    ...
# 12588  92340    ...
#
# [128 rows x 34 columns]
