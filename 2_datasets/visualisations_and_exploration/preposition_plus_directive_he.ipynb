# %%
import pandas as pd

# %%
df = pd.read_csv("data/filtered_dataset.csv").fillna("")

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)

# %%
set(df.cmpl_constr)
# Out:
# {'dir-he', 'prep', 'prep + dir-he', 'vc'}

# %%
df_prep_dirhe = df[df.cmpl_constr == "prep + dir-he"].copy()

# %%
df_prep_dirhe
# Out:
#       verb_id   lex  scroll    book  chapter  verse_num gcons_verb  \
# 1581    32836  BW>[      MT  Exodus        8         20        JB>
# 2348  1898948  BW>[  1Qisaa  Isaiah       10         28         B>
# 3024   118723  CWB[      MT  Joshua       10         15        JCB
# 3039   119419  CWB[      MT  Joshua       10         43        JCB
# 3099   123544  <LH[      MT  Joshua       19         11        <LH
# 3231   136352  BW>[      MT  Judges       14          5       JB>W
# 3811   311731  CWB[      MT  Psalms        9         18      JCWBW
#
#                                                                                     gcons_verse  \
# 1581  W J<F JHWH KN W JB> <RB KBD BJTH PR<H W BJT <BDJW W B KL >RY MYRJM TCXT H >RY M PNJ H <RB
# 2348                                                   B> <L <JTH <BR B MGRWN L MKMC JPQWD KLJW
# 3024                                               W JCB JHWC< W KL JFR>L <MW >L H MXNH H GLGLH
# ...

# %%
df_prep_dirhe.preposition_1
# Out:
# 1581     B
# 2348    <L
# 3024    >L
# 3039    >L
# 3099     L
# 3231    <D
# 3811     L
# Name: preposition_1, dtype: object

# %%
df_sham = df[(df.cmpl_lex == "CM") & (df.scroll == "MT") & (df.lex == "BW>[")]

# %%
len(df_sham)
# Out:
# 41

# %%
df_sham["cmpl_constr"].value_counts()
# Out:
# dir-he    32
# vc         9
# Name: cmpl_constr, dtype: int64

# %%
32 / 41 * 100
# Out:
# 78.04878048780488

# %%
df_sham_vc = df_sham[df_sham.cmpl_constr == "vc"]

# %%
set(df_sham_vc.book)
# Out:
# {'1_Samuel', 'Deuteronomy', 'Ezekiel', 'Jeremiah'}

# %%
df_sham_vc["book"].value_counts()
# Out:
# Ezekiel        4
# 1_Samuel       3
# Deuteronomy    1
# Jeremiah       1
# Name: book, dtype: int64
