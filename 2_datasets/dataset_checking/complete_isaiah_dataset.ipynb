# %%
import pandas as pd

# %%
df1 = pd.read_csv("data/isaiah.csv")
df2 = pd.read_csv("data/1qs.csv")

frames = [df1, df2]

# %%
df = pd.concat(frames)

# %%
# Getting read of NaN and float numbers

df["chapter"] = pd.to_numeric(df["chapter"])
df["verse_num"] = pd.to_numeric(df["verse_num"])
# converting 'dir_he' and 'dir_he_dss' from float to int 

df["dir_he"] = df["dir_he"].astype(str)
df["dir_he"] = df["dir_he"].replace("1.0", "1").replace("0.0", "0")

df["dir_he_dss"] = df["dir_he_dss"].astype(str)
df["dir_he_dss"] = df["dir_he_dss"].replace("1.0", "1").replace("0.0", "0")

df.fillna("")
# Out:
#      verb_id   lex  scroll    book  chapter  verse_num gcons_verb  \
# 0     212315  SWR[      MT  Isaiah        1         16      HSJRW
# 1    1895129  SWR[  1Qisaa  Isaiah        1         16      HSJRW
# 2     212418  BW>[      MT  Isaiah        1         23       JBW>
# 3    1895234  BW>[  1Qisaa  Isaiah        1         23       JBW>
# 4     212437  CWB[      MT  Isaiah        1         25      >CJBH
# ..       ...   ...     ...     ...      ...        ...        ...
# 106    22771  HLK[     1QS     1QS        7         42      HWLKJ
# 107    22944  PNH[     1QS     1QS        7         52        PNJ
# 108    22981  CWB[     1QS     1QS        7         55       HCJB
# 109    23034  CWB[     1QS     1QS        7         58        JCB
# 110    23036  PNH[     1QS     1QS        7         58        PNJ
#
#                                            gcons_verse  \
# 0       RXYW HZKW HSJRW R< M<LLJKM M NGD <JNJ XDLW HR<
# 1    RXYW W HZKW W HSJRW RW< M<LLJKM M NGD <JNJ XDL...
# 2    FRJK SWRRJM W XBRJ GNBJM KLW >HB CXD W RDP CLM...
# 3    FRJKJ SWRRJM W XBRJ GNBJM KWLM >WHBJ CWXD RWDP...
# 4    W >CJBH JDJ <LJK W >YRP K BR SJGJK W >SJRH KL ...
# ..                                                 ...
# 106  <WWNWTJ PC<J XV>T J <M N<WJT LBB J L SWD RMH W...
# 107  HKN B YDQ KWL M<FJ W W HQM L BN >MT KH K >CR R...
# 108  W >JN >XR ZWLT KH L HCJB <L <YT KH W L HFKJL B...
# 109                         W JLWD >CH MH JCB L PNJ KH
# 110                         W JLWD >CH MH JCB L PNJ KH
#
#                        gcons_clause    subject  complement dir_he dir_he_dss  \
# 0       HSJRW R< M<LLJKM M NGD <JNJ             M NGD <JNJ      0        nan
# 1    W HSJRW RW< M<LLJKM M NGD <JNJ             M NGD <JNJ      0          0
# 2         W RJB >LMNH L> JBW> >LJHM  RJB >LMNH       >LJHM      0        nan
# 3        W RJB >LMNH LW> JBW> >LJHM  RJB >LMNH       >LJHM      0          0
# 4                  W >CJBH JDJ <LJK                   <LJK    nan        nan
# ..                              ...        ...         ...    ...        ...
# 106                    W HWLKJ XWCK                   XWCK      0        nan
# 107           L HTJYB L PNJ KH L <D               L PNJ KH      0        nan
# 108                L HCJB <L <YT KH              <L <YT KH      0        nan
# 109                 MH JCB L PNJ KH               L PNJ KH      0        nan
# 110                 MH JCB L PNJ KH               L PNJ KH      0        nan
#
#     sign_info   stem tense preposition_1 preposition_2 preposition_3  \
# 0                hif  impv            MN
# 1              hifil  impv            MN
# 2                qal  impf            >L
# 3                qal  impf            >L
# 4                hif  impf            <L
# ..        ...    ...   ...           ...           ...           ...
# 106              qal  ptca
# 107                                    L
# 108              hif  infc            <L
# 109              hif  impf             L
# 110                                    L
#
#     preposition_4
# 0
# 1
# 2
# 3
# 4
# ..            ...
# 106
# 107
# 108
# 109
# 110
#
# [703 rows x 20 columns]
