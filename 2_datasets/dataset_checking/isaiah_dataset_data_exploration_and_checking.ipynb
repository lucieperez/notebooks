# %%
import pandas as pd

# %%
#df = pd.read_csv("data/isaiah_dataset.csv")
pd.set_option('display.max_columns', None)

# Getting read of NaN and float numbers

#df["chapter"] = pd.to_numeric(df["chapter"])
#df["verse_num"] = pd.to_numeric(df["verse_num"])
# converting 'dir_he' and 'dir_he_dss' from float to int 

#df["dir_he"] = df["dir_he"].astype(str)
#df["dir_he"] = df["dir_he"].replace("1.0", "1").replace("0.0", "0")

#df = df.fillna("")

# Selecting only the occurrences of motion verb + complement in the dataset
#df_cmpl = df[df.complement != "no complement"]
#df_cmpl.head(5)

#df_cmpl.to_csv("data/new_isaiah_dataset.csv", index=False)

# %%
df = pd.read_csv("data/new_isaiah_dataset.csv")

# %%
# Check how many motion_type are no yet fully annotated
len(df[df.motion_type == "factive fictive"])
# Out:
# 111

# %%
# Check how many cmpl_anim are no yet fully annotated
len(df[df.cmpl_anim == "anim inanim"])
# Out:
# 9

# %%
# Check the content of the columns: list and function

columns_to_check = ["stem",
                    "dir_he",
                    "cmpl_constr", 
                    "cmpl_nt", 
                    "cmpl_anim",
                    "cmpl_det",
                    "cmpl_indiv",
                    "cmpl_complex",
                    "motion_type",
                    "preposition_1",
                    "preposition_2",
                    "preposition_3",
                    "preposition_4",
                   ]

def show_set_colum_values(df, column_name):
    print(f"In the column {column_name} you have the following values: {set(df[column_name])}.\n")

# %%
# Check the content of the columns

for column_name in columns_to_check:
    show_set_colum_values(df, column_name)
# Out:
# In the column stem you have the following values: {'polel', 'nif', 'qal', 'piel', 'hit', 'hif', 'hof'}.
#
# In the column dir_he you have the following values: {0, 1}.
#
# In the column cmpl_constr you have the following values: {'prep + dir-he', 'vc', 'prep', 'dir-he'}.
#
# In the column cmpl_nt you have the following values: {'phen', 'other', 'occ', 'obj', 'adv', 'pers,gens,topo', 'topo', 'dir', 'prps', 'gens', 'ppin', 'pers', 'bopa', 'abs'}.
#
# In the column cmpl_anim you have the following values: {'anim inanim', 'inanim', 'anim'}.
#
# In the column cmpl_det you have the following values: {'det', 'und', 'na'}.
#
# In the column cmpl_indiv you have the following values: {'nmpr', 'prsf', 'adv', 'adj', 'subs', 'ppin'}.
#
# In the column cmpl_complex you have the following values: {'complex', 'simple'}.
#
# In the column motion_type you have the following values: {'fictive', 'factive fictive', 'factive'}.
#
# ...

# %%
# Specific checkings

# %%
#df[df.cmpl_det == "na"]

# %%
#df[df.cmpl_nt == "pers,gens,topo"]

# %%
#df[df.cmpl_anim == "anim inanim"]

# %%
df2 = pd.read_excel("../../1_annotation_tools/data/perez_isaiah_dataset_excel.xlsx").fillna("")
df2
# Out:
#      verb_id  in_medill   lex scroll    book  chapter  verse_num gcons_verb  \
# 0     212315          0  SWR[     MT  Isaiah        1         16      HSJRW
# 1     212418          0  BW>[     MT  Isaiah        1         23       JBW>
# 2     212437          0  CWB[     MT  Isaiah        1         25      >CJBH
# 3     212564          0  NHR[     MT  Isaiah        2          2       NHRW
# 4     212577          0  <LH[     MT  Isaiah        2          3       N<LH
# ..       ...        ...   ...    ...     ...      ...        ...        ...
# 238   234301          0  <LH[     MT  Isaiah       65         17     T<LJNH
# 239   234544          0  BW>[     MT  Isaiah       66          4       >BJ>
# 240   234608          0  BW>[     MT  Isaiah       66          7       JBW>
# 241   234871          0  BW>[     MT  Isaiah       66         20      HBJ>W
# 242   234909          0  BW>[     MT  Isaiah       66         20      JBJ>W
#
# ...

# %%
# drop all rows that contain 'MN' in preposition_1
df2 = df2.drop(df2[df2['preposition_1'] == 'MN'].index)

# drop all rows that agree with Medill's dataset
df3 = df2.drop(df2[df2['in_medill'] == 1].index)

# %%
df3
# Out:
#      verb_id  in_medill   lex scroll    book  chapter  verse_num gcons_verb  \
# 1     212418          0  BW>[     MT  Isaiah        1         23       JBW>
# 2     212437          0  CWB[     MT  Isaiah        1         25      >CJBH
# 3     212564          0  NHR[     MT  Isaiah        2          2       NHRW
# 4     212577          0  <LH[     MT  Isaiah        2          3       N<LH
# 5     212590          0  HLK[     MT  Isaiah        2          3       NLKH
# ..       ...        ...   ...    ...     ...      ...        ...        ...
# 238   234301          0  <LH[     MT  Isaiah       65         17     T<LJNH
# 239   234544          0  BW>[     MT  Isaiah       66          4       >BJ>
# 240   234608          0  BW>[     MT  Isaiah       66          7       JBW>
# 241   234871          0  BW>[     MT  Isaiah       66         20      HBJ>W
# 242   234909          0  BW>[     MT  Isaiah       66         20      JBJ>W
#
# ...

# %%
df3["cmpl_type"] = ""
df3
# Out:
#      verb_id  in_medill   lex scroll    book  chapter  verse_num gcons_verb  \
# 1     212418          0  BW>[     MT  Isaiah        1         23       JBW>
# 2     212437          0  CWB[     MT  Isaiah        1         25      >CJBH
# 3     212564          0  NHR[     MT  Isaiah        2          2       NHRW
# 4     212577          0  <LH[     MT  Isaiah        2          3       N<LH
# 5     212590          0  HLK[     MT  Isaiah        2          3       NLKH
# ..       ...        ...   ...    ...     ...      ...        ...        ...
# 238   234301          0  <LH[     MT  Isaiah       65         17     T<LJNH
# 239   234544          0  BW>[     MT  Isaiah       66          4       >BJ>
# 240   234608          0  BW>[     MT  Isaiah       66          7       JBW>
# 241   234871          0  BW>[     MT  Isaiah       66         20      HBJ>W
# 242   234909          0  BW>[     MT  Isaiah       66         20      JBJ>W
#
# ...

# %%
df3.to_csv("data/isaiah_not_in_medill.csv", index=False)
