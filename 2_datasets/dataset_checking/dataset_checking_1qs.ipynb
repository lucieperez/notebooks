# %%
import pandas as pd

# %%
df = pd.read_csv("data/dataset_1qs.csv")

# %%
df.fillna("")
# Out:
#      verb_id  lex scroll book  chapter  verse_num gcons_verb  \
# 0      17125  BW>    1QS  1QS        1         10      JBJ>W
# 1      17194  SWR    1QS  1QS        1         12        SWR
# 2      17200  HLK    1QS  1QS        1         12        LKT
# 3      17080  HLK    1QS  1QS        1          8      HTHLK
# 4      17082  PNH    1QS  1QS        1          8        PNJ
# ..       ...  ...    ...  ...      ...        ...        ...
# 106    22771  HLK    1QS  1QS        7         42      HWLKJ
# 107    22944  PNH    1QS  1QS        7         52        PNJ
# 108    22981  CWB    1QS  1QS        7         55       HCJB
# 109    23034  CWB    1QS  1QS        7         58        JCB
# 110    23036  PNH    1QS  1QS        7         58        PNJ
#
#                                            gcons_verse  \
# 0    W KWL H NDBJM L >MT W JBJ>W KWL D<T M W KWX M ...
# 1          W LW> L SWR M XWQJ >MT W L LKT JMJN W FM>WL
# 2          W LW> L SWR M XWQJ >MT W L LKT JMJN W FM>WL
# 3    L HWXD B <YT >L W L HTHLK L PNJ W TMJM KWL H N...
# 4    L HWXD B <YT >L W L HTHLK L PNJ W TMJM KWL H N...
# ..                                                 ...
# 106  <WWNWTJ PC<J XV>T J <M N<WJT LBB J L SWD RMH W...
# 107  HKN B YDQ KWL M<FJ W W HQM L BN >MT KH K >CR R...
# 108  W >JN >XR ZWLT KH L HCJB <L <YT KH W L HFKJL B...
# 109                         W JLWD >CH MH JCB L PNJ KH
# 110                         W JLWD >CH MH JCB L PNJ KH
#
#                                        gcons_clause subject    complement  \
# 0    W KWL JBJ>W KWL D<T M W KWX M W HWN M B JXD >L     KWL      B JXD >L
# 1                                L SWR M XWQJ >MT W          M XWQJ >MT W
# 2                                L LKT JMJN W FM>WL          JMJN W FM>WL
# 3                        W L HTHLK L PNJ W TMJM KWL               L PNJ W
# 4                        W L HTHLK L PNJ W TMJM KWL               L PNJ W
# ..                                              ...     ...           ...
# 106                                    W HWLKJ XWCK                  XWCK
# 107                           L HTJYB L PNJ KH L <D              L PNJ KH
# 108                                L HCJB <L <YT KH             <L <YT KH
# 109                                 MH JCB L PNJ KH              L PNJ KH
# 110                                 MH JCB L PNJ KH              L PNJ KH
#
#      dir_he dir_he_dss sign_info stem tense preposition_1 preposition_2  \
# 0         0                       hif  impf             B
# 1         0                       qal  infc            MN
# 2         0                       qal  infc
# 3         0                       hit  infc             L
# 4         0                                             L
# ..      ...        ...       ...  ...   ...           ...           ...
# 106       0                       qal  ptca
# 107       0                                             L
# 108       0                       hif  infc            <L
# 109       0                       hif  impf             L
# 110       0                                             L
#
#     preposition_3 preposition_4
# 0
# 1
# 2
# 3
# 4
# ..            ...           ...
# 106
# 107
# 108
# 109
# 110
#
# [111 rows x 20 columns]

# %%
# Dataset tests 

# Find lines without complement and without "no complement"
df[(df.complement == "")]
# Out:
# Empty DataFrame
# Columns: [verb_id, lex, scroll, book, chapter, verse_num, gcons_verb, gcons_verse, gcons_clause, subject, complement, dir_he, dir_he_dss, sign_info, stem, tense, preposition_1, preposition_2, preposition_3, preposition_4]
# Index: []

# %%
df.fillna("")

# Remove the dir_he_dss column

df.drop("dir_he_dss", axis="columns").fillna("")
# Out:
#      verb_id  lex scroll book  chapter  verse_num gcons_verb  \
# 0      17125  BW>    1QS  1QS        1         10      JBJ>W
# 1      17194  SWR    1QS  1QS        1         12        SWR
# 2      17200  HLK    1QS  1QS        1         12        LKT
# 3      17080  HLK    1QS  1QS        1          8      HTHLK
# 4      17082  PNH    1QS  1QS        1          8        PNJ
# ..       ...  ...    ...  ...      ...        ...        ...
# 106    22771  HLK    1QS  1QS        7         42      HWLKJ
# 107    22944  PNH    1QS  1QS        7         52        PNJ
# 108    22981  CWB    1QS  1QS        7         55       HCJB
# 109    23034  CWB    1QS  1QS        7         58        JCB
# 110    23036  PNH    1QS  1QS        7         58        PNJ
#
#                                            gcons_verse  \
# 0    W KWL H NDBJM L >MT W JBJ>W KWL D<T M W KWX M ...
# 1          W LW> L SWR M XWQJ >MT W L LKT JMJN W FM>WL
# 2          W LW> L SWR M XWQJ >MT W L LKT JMJN W FM>WL
# 3    L HWXD B <YT >L W L HTHLK L PNJ W TMJM KWL H N...
# 4    L HWXD B <YT >L W L HTHLK L PNJ W TMJM KWL H N...
# ..                                                 ...
# 106  <WWNWTJ PC<J XV>T J <M N<WJT LBB J L SWD RMH W...
# 107  HKN B YDQ KWL M<FJ W W HQM L BN >MT KH K >CR R...
# 108  W >JN >XR ZWLT KH L HCJB <L <YT KH W L HFKJL B...
# 109                         W JLWD >CH MH JCB L PNJ KH
# 110                         W JLWD >CH MH JCB L PNJ KH
#
#                                        gcons_clause subject    complement  \
# 0    W KWL JBJ>W KWL D<T M W KWX M W HWN M B JXD >L     KWL      B JXD >L
# 1                                L SWR M XWQJ >MT W          M XWQJ >MT W
# 2                                L LKT JMJN W FM>WL          JMJN W FM>WL
# 3                        W L HTHLK L PNJ W TMJM KWL               L PNJ W
# 4                        W L HTHLK L PNJ W TMJM KWL               L PNJ W
# ..                                              ...     ...           ...
# 106                                    W HWLKJ XWCK                  XWCK
# 107                           L HTJYB L PNJ KH L <D              L PNJ KH
# 108                                L HCJB <L <YT KH             <L <YT KH
# 109                                 MH JCB L PNJ KH              L PNJ KH
# 110                                 MH JCB L PNJ KH              L PNJ KH
#
#      dir_he sign_info stem tense preposition_1 preposition_2 preposition_3  \
# 0         0            hif  impf             B
# 1         0            qal  infc            MN
# 2         0            qal  infc
# 3         0            hit  infc             L
# 4         0                                  L
# ..      ...       ...  ...   ...           ...           ...           ...
# 106       0            qal  ptca
# 107       0                                  L
# 108       0            hif  infc            <L
# 109       0            hif  impf             L
# 110       0                                  L
#
#     preposition_4
# 0
# 1
# 2
# 3
# 4
# ..            ...
# 106
# 107
# 108
# 109
# 110
#
# [111 rows x 19 columns]

# %%
# Checking the list of prepositions

prepositions1 = df['preposition_1'].tolist()
prepositions2 = df['preposition_2'].tolist()
prepositions3 = df['preposition_3'].tolist()
prepositions4 = df['preposition_4'].tolist()

prepositions = prepositions1 + prepositions2 + prepositions3 + prepositions4

set(prepositions)
# Out:
# {'<L', '>L', '>T=', 'B', 'L', 'MN', nan}

# %%
# Checking the list of verbs

verbs = set(df["lex"].tolist())
verbs
# Out:
# {'<BR',
#  '<LH',
#  '>TH',
#  'BW>',
#  'CWB',
#  'GLH',
#  'HLK',
#  'JY>',
#  'MWC',
#  'NPL',
#  'PNH',
#  'QRB',
#  'SWR',
#  'T<H',
#  'XWC'}

# %%
# Harmonise the verbs lexemes with BHSA and DSS

def harmonise_vrb_lex(lexeme):
    lexeme += "["
    return lexeme

# %%
lexemes_column = df['lex']
new_lexemes_column = lexemes_column.apply(harmonise_vrb_lex)
df['lex'] = new_lexemes_column

# %%
# Remove the dir_he_dss column

df.drop("dir_he_dss", axis="columns").fillna("")
# Out:
#      verb_id   lex scroll book  chapter  verse_num gcons_verb  \
# 0      17125  BW>[    1QS  1QS        1         10      JBJ>W
# 1      17194  SWR[    1QS  1QS        1         12        SWR
# 2      17200  HLK[    1QS  1QS        1         12        LKT
# 3      17080  HLK[    1QS  1QS        1          8      HTHLK
# 4      17082  PNH[    1QS  1QS        1          8        PNJ
# ..       ...   ...    ...  ...      ...        ...        ...
# 106    22771  HLK[    1QS  1QS        7         42      HWLKJ
# 107    22944  PNH[    1QS  1QS        7         52        PNJ
# 108    22981  CWB[    1QS  1QS        7         55       HCJB
# 109    23034  CWB[    1QS  1QS        7         58        JCB
# 110    23036  PNH[    1QS  1QS        7         58        PNJ
#
#                                            gcons_verse  \
# 0    W KWL H NDBJM L >MT W JBJ>W KWL D<T M W KWX M ...
# 1          W LW> L SWR M XWQJ >MT W L LKT JMJN W FM>WL
# 2          W LW> L SWR M XWQJ >MT W L LKT JMJN W FM>WL
# 3    L HWXD B <YT >L W L HTHLK L PNJ W TMJM KWL H N...
# 4    L HWXD B <YT >L W L HTHLK L PNJ W TMJM KWL H N...
# ..                                                 ...
# 106  <WWNWTJ PC<J XV>T J <M N<WJT LBB J L SWD RMH W...
# 107  HKN B YDQ KWL M<FJ W W HQM L BN >MT KH K >CR R...
# 108  W >JN >XR ZWLT KH L HCJB <L <YT KH W L HFKJL B...
# 109                         W JLWD >CH MH JCB L PNJ KH
# 110                         W JLWD >CH MH JCB L PNJ KH
#
#                                        gcons_clause subject    complement  \
# 0    W KWL JBJ>W KWL D<T M W KWX M W HWN M B JXD >L     KWL      B JXD >L
# 1                                L SWR M XWQJ >MT W          M XWQJ >MT W
# 2                                L LKT JMJN W FM>WL          JMJN W FM>WL
# 3                        W L HTHLK L PNJ W TMJM KWL               L PNJ W
# 4                        W L HTHLK L PNJ W TMJM KWL               L PNJ W
# ..                                              ...     ...           ...
# 106                                    W HWLKJ XWCK                  XWCK
# 107                           L HTJYB L PNJ KH L <D              L PNJ KH
# 108                                L HCJB <L <YT KH             <L <YT KH
# 109                                 MH JCB L PNJ KH              L PNJ KH
# 110                                 MH JCB L PNJ KH              L PNJ KH
#
#      dir_he sign_info stem tense preposition_1 preposition_2 preposition_3  \
# 0         0            hif  impf             B
# 1         0            qal  infc            MN
# 2         0            qal  infc
# 3         0            hit  infc             L
# 4         0                                  L
# ..      ...       ...  ...   ...           ...           ...           ...
# 106       0            qal  ptca
# 107       0                                  L
# 108       0            hif  infc            <L
# 109       0            hif  impf             L
# 110       0                                  L
#
#     preposition_4
# 0
# 1
# 2
# 3
# 4
# ..            ...
# 106
# 107
# 108
# 109
# 110
#
# [111 rows x 19 columns]

# %%
df.to_csv("data/1qs.csv", sep=",", index=False)
