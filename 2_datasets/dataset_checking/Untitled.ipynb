# %%
import pandas as pd
from collections import Counter

# %%
df = pd.read_csv("data/Exodus_dataset.csv").fillna("")

# %%
pd.set_option('display.max_columns', None)

# %%
len(df[(df.complement != "no complement") & (df.scroll == "MT")])
# Out:
# 329

# %%
len(df[(df.scroll == "MT")])
# Out:
# 529

# %%
set(df.lex)
# Out:
# {'<BR[',
#  '<LH[',
#  '<WZ[',
#  'BRX[',
#  'BW>[',
#  'CWB[',
#  'GLH[',
#  'HLK[',
#  'JRD[',
#  'JY>[',
#  'MHR[',
#  'MWC[',
#  'NGC[',
#  'NPL[',
#  'NS<[',
#  'NTK[',
#  'NWS[',
#  'NWX[',
#  'PNH[',
#  'QHL[',
#  'QRB[',
#  'SBB[',
#  'SWR[',
#  'T<H[',
#  'VB<['}

# %%
df.lex.Counter()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14316\4004539042.py in ?()
# ----> 1 df.lex.Counter()
#
# ~\.conda\envs\hebrew\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5898             and name not in self._accessors
#    5899             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'Counter'

# %%
df[(df.lex == "BW>[") & (df.scroll == "MT")]
# Out:
#       verb_id   lex scroll    book  chapter  verse_num gcons_verb  \
# 0       28771  BW>[     MT  Exodus        1          1       B>JM
# 1       28778  BW>[     MT  Exodus        1          1        B>W
# 10      29061  BW>[     MT  Exodus        1         19       TBW>
# 12      33790  BW>[     MT  Exodus       10          1         B>
# 15      33834  BW>[     MT  Exodus       10          3        JB>
# ...       ...   ...    ...     ...      ...        ...        ...
# 989     32274  BW>[     MT  Exodus        7         23        JB>
# 991     32318  BW>[     MT  Exodus        7         26         B>
# 994     32355  BW>[     MT  Exodus        7         28        B>W
# 1021    32836  BW>[     MT  Exodus        8         20        JB>
# 1033    33027  BW>[     MT  Exodus        9          1         B>
#
#                                             gcons_verse sign_info stem tense  \
# 0     W >LH CMWT BNJ JFR>L H B>JM MYRJMH >T J<QB >JC...            qal  ptca
# ...
