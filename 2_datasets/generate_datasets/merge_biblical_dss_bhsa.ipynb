# %%
import pandas as pd

# %%
df1 = pd.read_csv("data/bhsa_all_verbs.csv").fillna("")

# %%
df2 = pd.read_csv("data/bib_dss_all_verbs.csv").fillna("")

# %%
df1.columns
# Out:
# Index(['verb_id', 'lex', 'scroll', 'book', 'chapter', 'verse_num',
#        'gcons_verb', 'gcons_verse', 'gcons_clause', 'subject', 'complement',
#        'dir_he', 'dir_he_dss', 'sign_info', 'stem', 'tense', 'preposition_1',
#        'preposition_2', 'preposition_3', 'preposition_4', 'preposition_5',
#        'preposition_6', 'preposition_7'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['verb_id', 'lex', 'scroll', 'book', 'chapter', 'verse_num',
#        'gcons_verb', 'gcons_verse', 'gcons_clause', 'subject', 'complement',
#        'dir_he', 'dir_he_dss', 'sign_info', 'stem', 'tense'],
#       dtype='object')

# %%
frames = [df1, df2]

# %%
df = pd.concat(frames).fillna("")

# %%
df.sort_values(["book", "chapter", "verse_num"], ascending=[True, True, True], ignore_index=True, inplace=True)
df
# Out:
#        verb_id   lex scroll       book chapter  verse_num gcons_verb  \
# 0      2081244  SWR[   11Q1       11Q1    fa+b          1  no_g_cons
# 1      1890249  BW>[    1Q1        1Q1     f14          1  no_g_cons
# 2      1890250  BW>[    1Q1        1Q1     f14          1  no_g_cons
# 3      1890251  BW>[    1Q1        1Q1     f14          2  no_g_cons
# 4      1929321  HWH[   1Q13       1Q13     f48          1  no_g_cons
# ...        ...   ...    ...        ...     ...        ...        ...
# 15597  2098519  QRB[  Mur88  Zephaniah       3          2       QRBH
# 15598  2098664  SWR[  Mur88  Zephaniah       3         11       >SJR
# 15599  2098688  XSH[  Mur88  Zephaniah       3         12        XSW
# 15600  2037711  BW>[   4Q77  Zephaniah       3         20       >BJ>
# 15601  2098824  BW>[  Mur88  Zephaniah       3         20       >BJ>
#
#                       gcons_verse      gcons_clause subject  ...  \
# 0      LEX: KSP/ SWR[ XLB=/ XLB=/              None    None  ...
# 1               LEX:  W BW>[ BW>[              None    None  ...
# 2               LEX:  W BW>[ BW>[              None    None  ...
# 3               LEX: BW>[ >BN/                 None    None  ...
# 4               LEX: W HWH[ HWH[               None    None  ...
# ...                           ...               ...     ...  ...
# 15597                        QRBH  >L >LHJH L> QRBH          ...
# 15598                        >SJR              None    None  ...
# 15599                         XSW   W XSW B CM JHWH          ...
# 15600                        >BJ>              None    None  ...
# 15601                        >BJ>              None    None  ...
#
#                                                sign_info   stem    tense  \
# 0                                           010000000001  hifil  unknown
# 1                                              010000001    qal     wayy
# 2                                              010000001
# 3                                             0110000100
# 4                                             0100010100
# ...                                                  ...    ...      ...
# 15597    00000000000000000000000000000000000000000000000    qal     perf
# 15598  0000000000000000000000000000000000000000000000...  hifil     impf
# 15599                 0000000000000000000000000000000000    qal     perf
# 15600  0000000000000000000000000000000000000000000000...  hifil     impf
# 15601  0000000000000000000000000000000000000000000000...  hifil     impf
#
#       preposition_1 preposition_2 preposition_3 preposition_4 preposition_5  \
# 0
# 1
# 2
# 3
# 4
# ...             ...           ...           ...           ...           ...
# 15597
# 15598
# 15599
# 15600
# 15601
#
#       preposition_6 preposition_7
# 0
# 1
# 2
# 3
# 4
# ...             ...           ...
# 15597
# 15598
# 15599
# 15600
# 15601
#
# [15602 rows x 23 columns]
