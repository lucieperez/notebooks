# %%
import pandas as pd

# %%
df1 = pd.read_csv("data/bhsa_all_verbs.csv").fillna("")

# %%
df2 = pd.read_csv("data/bib_dss_all_verbs.csv").fillna("")

# %%
pd.set_option("display.max_columns", None)

# %%
df1.columns
# Out:
# Index(['verb_id', 'lex', 'scroll', 'book', 'chapter', 'verse_num',
#        'gcons_verb', 'gcons_verse', 'gcons_clause', 'subject', 'complement',
#        'cmpl_lex', 'dir_he', 'cmpl_constr', 'cmpl_nt', 'cmpl_anim', 'cmpl_det',
#        'cmpl_indiv', 'cmpl_complex', 'dir_he_dss', 'sign_info', 'stem',
#        'tense', 'preposition_1', 'preposition_2', 'preposition_3',
#        'preposition_4', 'preposition_5', 'preposition_6', 'preposition_7'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['verb_id', 'lex', 'scroll', 'book', 'chapter', 'verse_num',
#        'gcons_verb', 'gcons_verse', 'gcons_clause', 'subject', 'complement',
#        'cmpl_lex', 'dir_he', 'dir_he_dss', 'sign_info', 'stem', 'tense',
#        'preposition_1', 'preposition_2', 'preposition_3', 'preposition_4',
#        'preposition_5', 'preposition_6', 'preposition_7'],
#       dtype='object')

# %%
frames = [df1, df2]

# %%
df = pd.concat(frames).fillna("")

# %%
df.sort_values(["book", "chapter", "verse_num"], ascending=[True, True, True], ignore_index=True, inplace=True)
df[df.scroll == "MT"]
# Out:
#        verb_id   lex scroll          book chapter  ...  preposition_3 preposition_4 preposition_5 preposition_6 preposition_7
# 23      391367  JY>[     MT  1_Chronicles       1  ...
# 24      392084  BW>[     MT  1_Chronicles       2  ...
# 25      392509  JY>[     MT  1_Chronicles       2  ...
# 26      392539  BW>[     MT  1_Chronicles       2  ...
# 27      392967  BW>[     MT  1_Chronicles       4  ...
# ...        ...   ...    ...           ...     ...  ...            ...           ...           ...           ...           ...
# 15585   303935  SWR[     MT     Zephaniah       3  ...
# 15586   303958  XSH[     MT     Zephaniah       3  ...
# 15587   303999  SWR[     MT     Zephaniah       3  ...
# 15588   304002  PNH[     MT     Zephaniah       3  ...
# 15589   304089  BW>[     MT     Zephaniah       3  ...
#
# [11237 rows x 30 columns]

# %%
df.to_csv("data/all_verbs_bhsa_bib_dss.csv", index=False)

# %%
df[df.book == "Exodus"].head()
# Out:
#       verb_id   lex scroll    book chapter  verse_num gcons_verb  \
# 5446    28771  BW>[     MT  Exodus       1          1       B>JM
# 5447    28778  BW>[     MT  Exodus       1          1        B>W
# 5448    28798  JY>[     MT  Exodus       1          5       JY>J
# 5449    28881  <LH[     MT  Exodus       1         10        <LH
# 5450    29061  BW>[     MT  Exodus       1         19       TBW>
#
#                                             gcons_verse  \
# 5446  W >LH CMWT BNJ JFR>L H B>JM MYRJMH >T J<QB >JC...
# 5447  W >LH CMWT BNJ JFR>L H B>JM MYRJMH >T J<QB >JC...
# 5448  W JHJ KL NPC JY>J JRK J<QB CB<JM NPC W JWSP HJ...
# 5449  HBH NTXKMH LW PN JRBH W HJH KJ TQR>NH MLXMH W ...
# 5450  W T>MRN H MJLDT >L PR<H KJ L> K NCJM H MYRJT H...
#
#                               gcons_clause               subject  \
# 5446                 H B>JM MYRJMH >T J<QB
# 5447                        >JC W BJTW B>W            >JC W BJTW
# ...
