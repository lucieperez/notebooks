# %%
import pandas as pd

from collections import Counter
import json

from tfob import TFOb,  get_dss, get_bhsa

# %%
BHSA = get_bhsa()
# Out:
# **Locating corpus resources ...**
# <b title="local release">app:</b> <span title="rv1.9=#gd796845ffd026d7896a29d71f730d471cba06631 offline under C:/Users/University/text-fabric-data/github">~/text-fabric-data/github/etcbc/dss/app</span>
# <b title="local release">data:</b> <span title="rv1.9=#gd796845ffd026d7896a29d71f730d471cba06631 offline under C:/Users/University/text-fabric-data/github">~/text-fabric-data/github/etcbc/dss/tf/1.9</span>
# <b title="local release">data:</b> <span title="rv1.9=#gd796845ffd026d7896a29d71f730d471cba06631 offline under C:/Users/University/text-fabric-data/github">~/text-fabric-data/github/etcbc/dss/parallels/tf/1.9</span>
# ...

# %%
# Get all the verses in the BHSA database
verses_bhsa = TFOb.all("verse", BHSA)

# %%
# Find embedded clauses and create a list of simple verse (without embedded clauses)

verses_bhsa_simple = []

for verse in verses_bhsa:
    is_simple = True
    verse_str = str(verse)
    for clause in verse.to_clauses:
        if str(clause) not in verse_str:
            is_simple = False
    if is_simple:
        verses_bhsa_simple.append(verse)

# %%
# Create dictionaries for full syntax (containing all verses) 

full_syntax = {}

for verse in verses_bhsa:
    full_syntax[str(verse)] = []
    for clause in verse.to_clauses:
        full_syntax[str(verse)].append(str(clause))

# %%
# Create dictionaries for simple syntax (exclusing verses containing embedded clauses)

simple_syntax = {}

for verse in verses_bhsa_simple:
    simple_syntax[str(verse)] = []
    for clause in verse.to_clauses:
        simple_syntax[str(verse)].append(str(clause))

# %%
#full_syntax

# %%
#simple_syntax

# %%
# Convert the dictionaries to JSON

full_syntax_json = json.dumps(full_syntax)
simple_syntax_json = json.dumps(simple_syntax)
# Out:
# '{"B R>CJT BR> >LHJM >T H CMJM W >T H >RY": ["B R>CJT BR> >LHJM >T H CMJM W >T H >RY"], "W H >RY HJTH THW W BHW W XCK <L PNJ THWM W RWX >LHJM MRXPT <L PNJ H MJM": ["W H >RY HJTH THW W BHW", "W XCK <L PNJ THWM", "W RWX >LHJM MRXPT <L PNJ H MJM"], "W J>MR >LHJM JHJ >WR W JHJ >WR": ["W J>MR >LHJM", "JHJ >WR", "W JHJ >WR"], "W JR> >LHJM >T H >WR KJ VWB W JBDL >LHJM BJN H >WR W BJN H XCK": ["W JR> >LHJM >T H >WR", "KJ VWB", "W JBDL >LHJM BJN H >WR W BJN H XCK"], "W JQR> >LHJM L >WR JWM W L XCK QR> LJLH W JHJ <RB W JHJ BQR JWM >XD": ["W JQR> >LHJM L >WR JWM", "W L XCK QR> LJLH", "W JHJ <RB", "W JHJ BQR", "JWM >XD"], "W J>MR >LHJM JHJ RQJ< B TWK H MJM W JHJ MBDJL BJN MJM L MJM": ["W J>MR >LHJM", "JHJ RQJ< B TWK H MJM", "W JHJ MBDJL BJN MJM L MJM"], "W JQR> >LHJM L RQJ< CMJM W JHJ <RB W JHJ BQR JWM CNJ": ["W JQR> >LHJM L RQJ< CMJM", "W JHJ <RB", "W JHJ BQR", "JWM CNJ"], "W J>MR >LHJM JQWW H MJM M TXT H CMJM >L MQWM >XD W TR>H H JBCH W JHJ KN": ["W J>MR >LHJM", "JQWW H MJM M TXT H CMJM >L MQW
# ...

# %%
book = "Genesis"
chapter = "1"
verse_num = "12"
verse_bhsa = TFOb.section([book, chapter, verse_num], BHSA)

# %%
for clause in verse_bhsa.to_clauses:
    print(clause.text)
# Out:
# וַתֹּוצֵ֨א הָאָ֜רֶץ דֶּ֠שֶׁא עֵ֣שֶׂב וְעֵ֧ץ
# מַזְרִ֤יעַ זֶ֨רַע֙ לְמִינֵ֔הוּ
# עֹ֥שֶׂה פְּרִ֛י לְמִינֵ֑הוּ
# אֲשֶׁ֥ר זַרְעֹו־בֹ֖ו
# וַיַּ֥רְא אֱלֹהִ֖ים
# כִּי־טֹֽוב׃
