# %%
import pandas as pd

# %%
# Import csv file 

df = pd.read_csv("data/all_verbs_bhsa_bib_dss.csv")
pd.set_option("display.max_columns", False)

# %%
# Exploration

df[(df.book == "Exodus") & (df.chapter == "14") & (df.verse_num == 25)]
# Out:
#       verb_id   lex scroll    book chapter  ...  preposition_3 preposition_4 preposition_5 preposition_6 preposition_7
# 5653    36742  SWR[     MT  Exodus      14  ...            NaN           NaN           NaN           NaN           NaN
# 5654    36753  NWS[     MT  Exodus      14  ...            NaN           NaN           NaN           NaN           NaN
# 6183  1952089  NWS[   4Q18  Exodus      14  ...            NaN           NaN           NaN           NaN           NaN
# 6184  1955179  SWR[   4Q22  Exodus      14  ...            NaN           NaN           NaN           NaN           NaN
# 6185  1955190  NWS[   4Q22  Exodus      14  ...            NaN           NaN           NaN           NaN           NaN
#
# [5 rows x 29 columns]

# %%
df[(df.book == "Exodus") & (df.chapter == "14")]
# Out:
#       verb_id   lex scroll    book chapter  verse_num gcons_verb  \
# 5634    36244  CWB[     MT  Exodus      14          2       JCBW
# 5635    36310  BRX[     MT  Exodus      14          5        BRX
# 5636    36372  JY>[     MT  Exodus      14          8      JY>JM
# 5637    36402  QRB[     MT  Exodus      14         10      HQRJB
# 5638    36412  NS<[     MT  Exodus      14         10        NS<
# 5639    36445  JY>[     MT  Exodus      14         11    HWYJ>NW
# 5640    36529  NS<[     MT  Exodus      14         15       JS<W
# 5641    36545  BW>[     MT  Exodus      14         16       JB>W
# 5642    36563  BW>[     MT  Exodus      14         17       JB>W
# 5643    36594  NS<[     MT  Exodus      14         19        JS<
# 5644    36599  HLK[     MT  Exodus      14         19        HLK
# 5645    36605  HLK[     MT  Exodus      14         19        JLK
# 5646    36609  NS<[     MT  Exodus      14         19        JS<
# ...
