# %%
import pandas as pd

# %%
df = pd.read_csv("data/full_isaiah_dataset.csv")

# %%
df.fillna("")
# Out:
#       verb_id   lex  scroll    book  chapter  verse_num gcons_verb  \
# 0      212256  BW>[      MT  Isaiah        1         12       TB>W
# 1     1895059  BW>[  1Qisaa  Isaiah        1         12       TB>W
# 2      212269  BW>[      MT  Isaiah        1         13       HBJ>
# 3     1895075  BW>[  1Qisaa  Isaiah        1         13       HBJ>
# 4      212315  SWR[      MT  Isaiah        1         16      HSJRW
# ...       ...   ...     ...     ...      ...        ...        ...
# 1399  1918901  BW>[  1Qisaa  Isaiah       66         23       JBW>
# 1400  1927678  BW>[     1Q8  Isaiah       66         23       JBW>
# 1401   234980  JY>[      MT  Isaiah       66         24       JY>W
# 1402  1918913  JY>[  1Qisaa  Isaiah       66         24       JY>W
# 1403  1927689  JY>[     1Q8  Isaiah       66         24       JY>W
#
#                                             gcons_verse  \
# 0         KJ TB>W L R>WT PNJ MJ BQC Z>T M JDKM RMS XYRJ
# ...

# %%
df_mt_cmpl = df[(df.scroll == "MT") & (df.complement != "no complement")].fillna("")

# %%
pd.set_option('display.max_columns', None)
df_mt_cmpl
# Out:
#       verb_id   lex scroll    book  chapter  verse_num gcons_verb  \
# 4      212315  SWR[     MT  Isaiah        1         16      HSJRW
# 8      212418  BW>[     MT  Isaiah        1         23       JBW>
# 10     212437  CWB[     MT  Isaiah        1         25      >CJBH
# 18     212564  NHR[     MT  Isaiah        2          2       NHRW
# 20     212577  <LH[     MT  Isaiah        2          3       N<LH
# ...       ...   ...    ...     ...      ...        ...        ...
# 1362   234239  NWX[     MT  Isaiah       65         15      HNXTM
# 1364   234301  <LH[     MT  Isaiah       65         17     T<LJNH
# 1373   234608  BW>[     MT  Isaiah       66          7       JBW>
# 1392   234871  BW>[     MT  Isaiah       66         20      HBJ>W
# 1393   234909  BW>[     MT  Isaiah       66         20      JBJ>W
#
#                                             gcons_verse  \
# 4        RXYW HZKW HSJRW R< M<LLJKM M NGD <JNJ XDLW HR<
# 8     FRJK SWRRJM W XBRJ GNBJM KLW >HB CXD W RDP CLM...
# ...

# %%
df_mt.columns
# Out:
# Index(['verb_id', 'lex', 'scroll', 'book', 'chapter', 'verse_num',
#        'gcons_verb', 'gcons_verse', 'gcons_clause', 'subject', 'complement',
#        'dir_he', 'dir_he_dss', 'sign_info', 'stem', 'tense', 'preposition_1',
#        'preposition_2', 'preposition_3', 'preposition_4', 'cmpl_lex',
#        'cmpl_constr', 'cmpl_nt', 'cmpl_anim', 'cmpl_det', 'cmpl_indiv',
#        'motion_type'],
#       dtype='object')

# %%
df_mt_cmpl[['verb_id', 
    'lex', 
    'scroll', 
    'book', 
    'chapter', 
    'verse_num',
    'gcons_verb', 
    'gcons_verse', 
    'gcons_clause', 
    'subject', 
    'complement', 
    "cmpl_lex",
    'dir_he', 
    'dir_he_dss', 
    'sign_info', 
    'stem', 
    'tense', 
    'preposition_1',
    'preposition_2', 
    'preposition_3', 
    'preposition_4',
    'cmpl_constr', 
    'cmpl_nt', 
    'cmpl_anim', 
    'cmpl_det', 
    'cmpl_indiv',
    'motion_type']]

df_mt_cmpl["dir_he"] = df_mt_cmpl["dir_he"].astype(str)
df_mt_cmpl["dir_he"] = df_mt_cmpl["dir_he"].replace("1.0", "1").replace("0.0", "0")

# %%
df_mt_cmpl
# Out:
#       verb_id   lex scroll    book  chapter  verse_num gcons_verb  \
# 4      212315  SWR[     MT  Isaiah        1         16      HSJRW
# 8      212418  BW>[     MT  Isaiah        1         23       JBW>
# 10     212437  CWB[     MT  Isaiah        1         25      >CJBH
# 18     212564  NHR[     MT  Isaiah        2          2       NHRW
# 20     212577  <LH[     MT  Isaiah        2          3       N<LH
# ...       ...   ...    ...     ...      ...        ...        ...
# 1362   234239  NWX[     MT  Isaiah       65         15      HNXTM
# 1364   234301  <LH[     MT  Isaiah       65         17     T<LJNH
# 1373   234608  BW>[     MT  Isaiah       66          7       JBW>
# 1392   234871  BW>[     MT  Isaiah       66         20      HBJ>W
# 1393   234909  BW>[     MT  Isaiah       66         20      JBJ>W
#
#                                             gcons_verse  \
# 4        RXYW HZKW HSJRW R< M<LLJKM M NGD <JNJ XDLW HR<
# 8     FRJK SWRRJM W XBRJ GNBJM KLW >HB CXD W RDP CLM...
# ...
