# %%
import pandas as pd

# %%
df = pd.read_csv("data/isaiah_locatives_to_clean.csv").fillna("")

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
df.head(20)
# Out:
#     verb_id   lex  scroll    book  chapter  verse_num gcons_verb  \
# 0    212256  BW>[      MT  Isaiah        1         12       TB>W
# 1   1895059  BW>[  1Qisaa  Isaiah        1         12       TB>W
# 2   1895059  BW>[  1Qisaa  Isaiah        1         12       TB>W
# 3    212269  BW>[      MT  Isaiah        1         13       HBJ>
# 4   1895075  BW>[  1Qisaa  Isaiah        1         13       HBJ>
# 5   1895075  BW>[  1Qisaa  Isaiah        1         13       HBJ>
# 6    212315  SWR[      MT  Isaiah        1         16      HSJRW
# 7   1895129  SWR[  1Qisaa  Isaiah        1         16      HSJRW
# 8   1895129  SWR[  1Qisaa  Isaiah        1         16      HSJRW
# 9    212333  HLK[      MT  Isaiah        1         18        LKW
# 10  1895149  HLK[  1Qisaa  Isaiah        1         18        LKW
# 11  1895149  HLK[  1Qisaa  Isaiah        1         18        LKW
# 12  2026652  HLK[    4Q60  Isaiah        1         18        LKW
# ...

# %%
len(df)
# Out:
# 2214

# %%
set(df.cmpl_indiv)
# Out:
# {'', 'adj', 'adv', 'nmpr', 'ppin', 'prsf', 'subs'}

# %%
# Print data types
print(df.dtypes)

# Print unique values for a specific column that might have hidden issues, e.g., 'gcons_verse'
print(df['gcons_verse'].unique())
# Out:
# verb_id              int64
# lex                 object
# scroll              object
# book                object
# chapter              int64
# verse_num            int64
# gcons_verb          object
# gcons_verse         object
# sign_info           object
# stem                object
# tense               object
# gcons_clause        object
# subject             object
# complement          object
# cmpl_lex            object
# cmpl_translation    object
# dir_he              object
# cmpl_constr         object
# cmpl_nt             object
# cmpl_anim           object
# cmpl_det            object
# cmpl_indiv          object
# cmpl_complex        object
# motion_type         object
# preposition_1       object
# preposition_2       object
# preposition_3       object
# preposition_4       object
# comments            object
# dir_he_dss          object
# preposition_5       object
# preposition_6       object
# dtype: object
# ['KJ TB>W L R>WT PNJ MJ BQC Z>T M JDKM RMS XYRJ'
# ...

# %%
columns_to_compare = ['verb_id', 'lex', 'scroll', 'book', 'chapter', 'verse_num', 'gcons_verb', 'gcons_verse', "complement"]

# %%
duplicates = df.duplicated(subset=columns_to_compare, keep=False)

# %%
duplicate_rows = df[duplicates]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [verb_id, lex, scroll, book, chapter, verse_num, gcons_verb, gcons_verse, sign_info, stem, tense, gcons_clause, subject, complement, cmpl_lex, cmpl_translation, dir_he, cmpl_constr, cmpl_nt, cmpl_anim, cmpl_det, cmpl_indiv, cmpl_complex, motion_type, preposition_1, preposition_2, preposition_3, preposition_4, comments, dir_he_dss, preposition_5, preposition_6]
# Index: []

# %%
df_cleaned = df.drop_duplicates(subset=columns_to_compare, keep='first')

# %%
df_cleaned.head(10)
# Out:
#    verb_id   lex  scroll    book  chapter  verse_num gcons_verb  \
# 0   212256  BW>[      MT  Isaiah        1         12       TB>W
# 1  1895059  BW>[  1Qisaa  Isaiah        1         12       TB>W
# 2  1895059  BW>[  1Qisaa  Isaiah        1         12       TB>W
# 3   212269  BW>[      MT  Isaiah        1         13       HBJ>
# 4  1895075  BW>[  1Qisaa  Isaiah        1         13       HBJ>
# 5  1895075  BW>[  1Qisaa  Isaiah        1         13       HBJ>
# 6   212315  SWR[      MT  Isaiah        1         16      HSJRW
# 7  1895129  SWR[  1Qisaa  Isaiah        1         16      HSJRW
# 8  1895129  SWR[  1Qisaa  Isaiah        1         16      HSJRW
# 9   212333  HLK[      MT  Isaiah        1         18        LKW
#
#                                          gcons_verse  \
# 0      KJ TB>W L R>WT PNJ MJ BQC Z>T M JDKM RMS XYRJ
# 1  KJ> TB>W L R>WT PNJ MJ BQC ZW>T M JDKM L RMWS ...
# 2  KJ> TB>W L R>WT PNJ MJ BQC ZW>T M JDKM L RMWS ...
# ...

# %%
len(df_cleaned)
# Out:
# 2214

# %%
df = df[(df.scroll == "MT") | (df.scroll == "1Qisaa") | (df.scroll == "1Q8")]
len(df)
# Out:
# 1987

# %%
df.to_csv("data/partial_isaiah_locatives_to_annotate.csv", index=False)

# %%
set(df.scroll)
# Out:
# {'1Q8', '1Qisaa', 'MT'}
