# %%
import pandas as pd

# %%
pd.set_option("display.max_columns", None)

# %%
df_mt = pd.read_csv("data/biblical_datasets/Deuteronomy_dataset.csv").fillna("")

# %%
df_mt.head(5)
# Out:
#    verb_id   lex scroll         book  chapter  verse_num gcons_verb  \
# 0    92924  PNH[     MT  Deuteronomy        1          7        PNW
# 1    92926  NS<[     MT  Deuteronomy        1          7        S<W
# 2    92929  BW>[     MT  Deuteronomy        1          7        B>W
# 3  1985801  PNH[   4Q35  Deuteronomy        1          7        PNW
# 4  1985803  NS<[   4Q35  Deuteronomy        1          7        S<W
#
#                                          gcons_verse     gcons_clause subject  \
# 0  PNW W S<W LKM W B>W HR H >MRJ W >L KL CKNJW B ...              PNW
# 1  PNW W S<W LKM W B>W HR H >MRJ W >L KL CKNJW B ...        W S<W LKM
# 2  PNW W S<W LKM W B>W HR H >MRJ W >L KL CKNJW B ...  W B>W HR H >MRJ
# 3  PNW W S<W LKM W B>W HR H >MRJ W >L KL CKNJW B ...             None    None
# 4  PNW W S<W LKM W B>W HR H >MRJ W >L KL CKNJW B ...             None    None
#
#       complement       cmpl_lex dir_he cmpl_constr cmpl_nt cmpl_anim cmpl_det  \
# ...

# %%
len(df_mt)
# Out:
# 970

# %%
df_mt[df_mt.complement != "no complement"]
# Out:
#        verb_id   lex scroll          book  chapter  verse_num gcons_verb  \
# 0       391367  JY>[     MT  1_Chronicles        1         12       JY>W
# 1       396716  NWS[     MT  1_Chronicles       10          1        JNS
# 3       396944  BW>[     MT  1_Chronicles       10         12     JBJ>WM
# 4       396991  SBB[     MT  1_Chronicles       10         14        JSB
# 6       396802  NPL[     MT  1_Chronicles       10          4        JPL
# ...        ...   ...    ...           ...      ...        ...        ...
# 11229   303497  BW>[     MT     Zephaniah        2          2       JBW>
# 11230   303935  SWR[     MT     Zephaniah        3         11       >SJR
# 11231   303958  XSH[     MT     Zephaniah        3         12        XSW
# 11234   303776  QRB[     MT     Zephaniah        3          2       QRBH
# 11235   304089  BW>[     MT     Zephaniah        3         20       >BJ>
#
#                                              gcons_verse  \
# ...

# %%
df_bib_dss = pd.read_csv("data/bib_dss_all_verbs.csv").fillna("")

# %%
len(df_bib_dss)
# Out:
# 4365

# %%
df_bib_dss.head(5)
# Out:
#    verb_id   lex scroll     book chapter  verse_num gcons_verb  \
# 0  1889904  <WP[    1Q1  Genesis       1         20      J<WPP
# 1  1890016  HLK[    1Q1  Genesis       3         14        TLK
# 2  1890027  HLK[    1Q1  Genesis      22         13        JLK
# 3  1890035  <LH[    1Q1  Genesis      22         13      J<LHW
# 4  1890114  BW>[    1Q1  Genesis      23         18        B>J
#
#                                          gcons_verse  \
# 0  W J>MR >LHJM JCRWYW H MJM CRY NPC XJH W <WP J<...
# 1  W J>MR JHWH >LHJM >L H NXC KJ <FJT Z>T >RWR >T...
# 2  B QRNJW W JLK >BRHM W JQX >T H >JL W J<LHW L <...
# 3  B QRNJW W JLK >BRHM W JQX >T H >JL W J<LHW L <...
# 4    L >BRHM L MQNH L <JNJ BNJ XT B KWL B>J C<R <JRW
#
#                               gcons_clause  \
# 0  W <WP J<WPP <L H >RY <L PNJ RQJ< H CMJM
# 1                              <L GXNK TLK
# 2                                     None
# 3                                     None
# 4
#
# ...

# %%
df_bib_dss[df_bib_dss.complement != ""]
# Out:
#       verb_id   lex scroll     book chapter  verse_num gcons_verb  \
# 0     1889904  <WP[    1Q1  Genesis       1         20      J<WPP
# 1     1890016  HLK[    1Q1  Genesis       3         14        TLK
# 4     1890114  BW>[    1Q1  Genesis      23         18        B>J
# 11    1890408  JRD[    1Q2   Exodus      19         25        JRD
# 12    1890480  <LH[    1Q2   Exodus      20         26       T<LH
# ...       ...   ...    ...      ...     ...        ...        ...
# 4337  2106786  CWB[  Mas1e   Psalms      81         15       >CJB
# 4338  2106858  HLK[  Mas1e   Psalms      82          5     JTHLKW
# 4339  2107153  <BR[  Mas1e   Psalms      84          7       <BRJ
# 4340  2107165  HLK[  Mas1e   Psalms      84          8       JLKW
# 4342  2107263  CWB[  Mas1e   Psalms      85          4     HCJBWT
#
#                                             gcons_verse  \
# 0     W J>MR >LHJM JCRWYW H MJM CRY NPC XJH W <WP J<...
# 1     W J>MR JHWH >LHJM >L H NXC KJ <FJT Z>T >RWR >T...
# ...

# %%
df_xb = pd.read_csv("data/extrabiblical_all_verbs.csv").fillna("")
len(df_xb)
# Out:
# 369

# %%
df_xb.head(5)
# Out:
#    verb_id  lex scroll book  chapter  verse_num gcons_verb  \
# 0     3132  NPL    1QH  1QH       10         13       NPLW
# 1     3058  SBB    1QH  1QH       10          7       SBBW
# 2     3354  BW>    1QH  1QH       12          5        B>W
# 3     3376  GJX    1QH  1QH       12          6       JGJX
# 4     3393  XWC    1QH  1QH       12          8      HXJCW
#
#                                          gcons_verse  \
# 0                       W PXJM VMNW L NPC J NPLW B M
# 1  W >NJ >MRTJ XNW <LJ GBWRJM SBBW M B KL KLJ MLX...
# 2  KJ> B>W BNJM <D MCBRJ MWT W HRJT GBR HYRH B XB...
# 3  KJ> B MCBRJ MWT TMLJV ZKR W B XBLJ C>WL JGJX M...
# 4  HXJCW KWL MCBRJM W XBLJ MRY B MWLDJ HM W PLYWT...
#
#                                         gcons_clause              subject  \
# 0                                           NPLW B M
# 1                           SBBW M B KL KLJ MLXMWT M
# 2                          KJ> B>W BNJM <D MCBRJ MWT                 BNJM
# ...

# %%
df_xb[df_xb.complement != ""]
# Out:
#      verb_id  lex       scroll         book  chapter  verse_num gcons_verb  \
# 0       3132  NPL          1QH          1QH       10         13       NPLW
# 2       3354  BW>          1QH          1QH       12          5        B>W
# 3       3376  GJX          1QH          1QH       12          6       JGJX
# 6       3690  NPL          1QH          1QH       13         13       NPWL
# 7       3717  HLK          1QH          1QH       13         14       JLKW
# ..       ...  ...          ...          ...      ...        ...        ...
# 355    24072  BW>      Lachish      Lachish        5          1         J>
# 363    24636  JRD  Mesha_Stela  Mesha_Stela        1         38        >RD
# 364    24646  CWB  Mesha_Stela  Mesha_Stela        1         38        JCB
# 367    39838  HLK       Siloam       Siloam        1          1       JLKW
# 368    39838  HLK       Siloam       Siloam        1          1       JLKW
#
#                                            gcons_verse  \
# ...
