# %%
import pandas as pd

# %%
df = pd.read_csv("data/verb_file_stat.csv")
df.fillna("")
# Out:
#        verb_id   lex scroll          book  chapter  verse_num gcons_verb  \
# 0       391367  JY>[     MT  1_Chronicles        1         12       JY>W
# 1       396716  NWS[     MT  1_Chronicles       10          1        JNS
# 2       396723  NPL[     MT  1_Chronicles       10          1       JPLW
# 3       396944  BW>[     MT  1_Chronicles       10         12     JBJ>WM
# 4       396779  BW>[     MT  1_Chronicles       10          4       JB>W
# ...        ...   ...    ...           ...      ...        ...        ...
# 10140   303935  SWR[     MT     Zephaniah        3         11       >SJR
# 10141   303999  SWR[     MT     Zephaniah        3         15       HSJR
# 10142   303776  QRB[     MT     Zephaniah        3          2       QRBH
# 10143   304089  BW>[     MT     Zephaniah        3         20       >BJ>
# 10144   303832  <BR[     MT     Zephaniah        3          6       <WBR
#
#                                              gcons_verse  \
# ...

# %%
df_cmpl = df[df.complement != "no complement"]
df_cmpl
# Out:
#        verb_id   lex scroll          book  chapter  verse_num gcons_verb  \
# 0       391367  JY>[     MT  1_Chronicles        1         12       JY>W
# 1       396716  NWS[     MT  1_Chronicles       10          1        JNS
# 3       396944  BW>[     MT  1_Chronicles       10         12     JBJ>WM
# 5       396802  NPL[     MT  1_Chronicles       10          4        JPL
# 6       396812  NPL[     MT  1_Chronicles       10          5        JPL
# ...        ...   ...    ...           ...      ...        ...        ...
# 10138   303489  BW>[     MT     Zephaniah        2          2       JBW>
# 10139   303497  BW>[     MT     Zephaniah        2          2       JBW>
# 10140   303935  SWR[     MT     Zephaniah        3         11       >SJR
# 10142   303776  QRB[     MT     Zephaniah        3          2       QRBH
# 10143   304089  BW>[     MT     Zephaniah        3         20       >BJ>
#
#                                              gcons_verse  \
# ...

# %%
df_cont_table = pd.crosstab(df_cmpl.lex, df_cmpl.cmpl_constr)
df_cont_table
# Out:
# cmpl_constr  dir_he  prep  prep + dir_he  prep + prep   vc
# lex
# <BR[             23   237              4           19   26
# <LH[             30   463              6           34   97
# >TH[              0    12              0            1    2
# BW>[            146  1369             18           67  266
# CWB[             20   502              5           33   58
# GLH[             14    52              0            9    2
# HLK[             45   577              3           58  150
# HWH[              0    27              0            2    0
# JRD[             30   168              5           14   54
# JY>[             24   568              3           76   49
# NPL[             21   220              4           12   11
# NTK[              1    12              0            0    0
# NVP[              0     6              0            0    0
# NWS[             19    55              2            3    9
# NWX[              0    91              0            6    7
# ...

# %%
df_cont_table.columns
# Out:
# Index(['dir_he', 'prep', 'prep + dir_he', 'prep + prep', 'vc'], dtype='object', name='cmpl_constr')

# %%
df_cont_table
# Out:
# cmpl_constr  dir_he  prep   vc
# lex
# <BR[             23   237   26
# <LH[             30   463   97
# >TH[              0    12    2
# BW>[            146  1369  266
# CWB[             20   502   58
# GLH[             14    52    2
# HLK[             45   577  150
# HWH[              0    27    0
# JRD[             30   168   54
# JY>[             24   568   49
# NPL[             21   220   11
# NTK[              1    12    0
# NVP[              0     6    0
# NWS[             19    55    9
# NWX[              0    91    7
# NXT[              0     9    0
# QHL[              0    18    4
# QRB[              0   154    4
# SWR[              4   130    8
# T<H[              0    12    1
# VB<[              0     8    0

# %%
df_cont_table.to_csv("data/stat_cmpl.csv")
